# %%
# Import matplotlib for plotting purposes
import matplotlib
matplotlib.rcParams["text.usetex"] = False
import matplotlib.pyplot as plt

# Sometimes, we need Numpy, but wherever possible, we prefer torch.
import numpy as np

# Import PyTorch
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# Float (32 bit) or Double (64 bit) precision? Choose!
torch.set_default_dtype(torch.float32)#64)
torch.set_num_threads(4) # Use _maximally_ 4 CPU cores


device = torch.device("cpu")
# Choose a device for major calculations (if there is a special GPU card, you usually want that).
# My GPU is not very performant for double precision, so I stay on CPU
#device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
device = torch.device(device)

# File path for saving the trained NN later.
# If only providing the file name (like here), the file will be generated in the same folder as the Python script
model_file = "mymodel.torch"

## The following script shows a data-driven training of a Neural Network.
## The data is generated in this script, too, by sampling from a function.
## The variables below are used to control this sampling
samples = 16
sample_min = -5
sample_max = 5
sample_span = sample_max - sample_min

## These parameters are usual hyperparameters of the NN and its training.
batch_size = 8 # How many samples shall be presented to the NN, before running another optimizer step?
hidden_dim = 16 # How many neurons shall there be in the hidden layer(s)?
input_dim = 1 # Input dimension of the NN (i.e. how many neurons are in the input layer?)
output_dim = 1 # Some for output

epochs = 1600 # Number of training iterations to be performed
lr = 0.001 # Which learning rate is passed to the training algorithm?

## Choose a criterion to evaluate the results. Here, we choose Mean Square error.
## The term "loss" means about the same as "remaining error" or "residual".
criterion = nn.MSELoss(reduction="mean")

## Here, we create the training data. In this example, we draw samples within the sampling interval and then pass it to
## e.g. the sin function (choose other functions to experiment with this script)
train_x = (sample_span * torch.rand(samples, 1) + sample_min * torch.ones(samples, 1))
train_y = torch.sin(train_x) ##torch.pow(test_x, 2)
print ("train_x", train_x)
print ("train_y", train_y)

## Here, we create the test data. To show the effect of extrapolation and the detailed behavior of the NN,
## we choose points a bit outside the interval that we used for sampling training data. Also, we very dense points.
test_x = torch.zeros(20*samples, 1)
test_x[:, 0] = torch.linspace(sample_min - 0.5*sample_span, sample_max + 0.5*sample_span, test_x.size()[0])
test_y = torch.sin(test_x) ##torch.pow(test_x, 2)

## We want a DataLoader to handle batching and shuffling of the training data for us.
## The DataLoader needs a TensorDataset, hence we create one from the Training data.
train_data = TensorDataset(train_x, train_y)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, drop_last=False)


## This class creates the actual Neural Network.
class MLNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MLNet, self).__init__()
        self.hidden_dim = hidden_dim

        ## In this case, I decided to pack the layers into a single container of type nn.Sequential
        ## This container is useful for Fully Connected NNs, where the output of each layer is just fed into the following layer.
        self.fcnn1 = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            #nn.Tanh(),
            nn.ReLU(),
            #nn.Linear(hidden_dim, hidden_dim),
            #nn.ReLU(),
            #nn.Linear(hidden_dim, hidden_dim),
            #nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
        ) ## That network here has exactly 1 hidden layer (comment out some lines or write new ones to add more layers)
        ## nn.Linear is in the pictures represented by the arrows and has the weights (and biases) which are the
        ## parameters of the NN.
        ## nn.ReLU and Tanh are examples for activation functions - in the pictures, these are the bubbles / neurons.
        ## Usually, the pattern is interchanging between one linear layer, one activation function, one linear layer, one activation function and so on

    ## It is required to write a function that is executed when calling the NN model.
    ## Usually, it takes the input data and passes it through the layers.
    ## Here, it is sufficient to call the sequential container since this container does exactly this job.
    ## But this function "forward" could also be used to set up more complex NN architectures with more complex data flows
    def forward(self, x):
        out = self.fcnn1(x)
        return out

## This function performs a test run with the NN.
## It takes the NN model and the test data, passes the test inputs through the network and
## compares it with the target values = test outputs = targets
## and based on that calculates the loss value
def evaluate(model, test_x, test_y):
    ## For testing, we don't need the autograd feature/ protocol of all calculation steps
    ## So, save some time and disable grad tracking.
    with torch.no_grad():
        model.eval() ## Set the NN model into evaluation mode
        outputs = [] ## Create empty lists to store the results
        targets = []
        testlosses = []

        out = model(test_x.to(device)) ## Call the model, i.e. perform the actual inference

        ## Move the output quantities to the CPU, detach them from the tensor operation book-keeping and convert them to numpy arrays/ vectors.
        ## This is all necessary for plotting
        outputs.append(out.cpu().detach().numpy())
        targets.append(test_y.cpu().detach().numpy())
        testlosses.append(criterion(out, test_y.to(device)).item())

    ## Now return that in form of a triple of variables
    return outputs, targets, testlosses

## This calls the evaluate function and takes care of the plotting.
def eval_and_plot(model):
        ## matplotlib tries to be similar to the plot functions of matlab  (admittedly, the commands have to begin with "plt.", but the rest
        ## is quite similar.)
        plt.subplot(1, 1, 1)

        ## Call the network on the test data
        net_outputs_test, targets_test, testlosses = evaluate(model, test_x, test_y)
        # Plot the targets first in blue (which means to plot the actual function over the whole test interval)
        plt.plot(test_x, targets_test[0], "-x", color="b", label="Target")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.legend()

        ## Call the network on the training data
        net_outputs_train, targets_train, testlosses = evaluate(model, train_x, train_y)
        ## First, plot the targets in red, i.e. plot the training data set
        plt.plot(train_x, targets_train[0], "^", color="r", label="Target")

        ## Now, plot the output of the NN on the whole test interval in green
        ## This allows us to see how the NN performs for interpolation as well as for extrapolation
        plt.plot(test_x, net_outputs_test[0], "-o", color="g", label="Learned")

        ## All plotting is done, open the plot window
        plt.show()


## That function takes care of the whole training
def train(train_loader, learn_rate, EPOCHS):  # 10):

    # Instantiate the NN
    model = MLNet(input_dim, hidden_dim, output_dim)
    model.to(device) # and move it to the "device" (in case we use a GPU)

    ## Choose an optimizer. Adam is quite robust and thus very popular. Technically, it's based on
    ## gradient descent, but mixes in the gradient of the last time step to improve robustness.
    ## It is given the model parameters, which are the weights and biases of the Linear layers
    ## and the learn_rate.
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)
    print("Starting Training of the model")

    # We want to keep track of the losses averaged over each epoch, to plot them in those famous
    # decreasing graphs
    avg_losses = torch.zeros(EPOCHS)

    ## In the end, epoch is just another word for "training iteration", so we have a simple for loop.
    for epoch in range(EPOCHS):
        model.train() # Set the model into train mode
        avg_loss = 0. # initializations
        counter = 0

        ## DataLoader is iterable so that this for-loop loops over the batches of the training data set
        ## and the DataLoader gives us readily paired combinations of training inputs and targets (which are called x and label, here).
        ## The term "label" is more common in classification, but used for all supervised training tasks
        for x, label in train_loader:
            counter += 1 # We count, how many batches we did within the current epoch
            model.zero_grad() # Important: reset the gradients of the NN before passing the training inputs.
            # Otherwise, we would accumulate the gradient information which might ruin the results
            # or simply run into PyTorch exceptions

            ## Now, we can call the model on the training inputs.
            ## Therefor, we move that data to the device (just in case we use a GPU).
            out = model(x.to(device))
            loss = criterion(out, label.to(device)) # Now, calculate the loss value

            ## Here, the whole magic happens:
            ## PyTorch offers the autograd feature, i.e. calculations on tensors are tracked (there are exceptions, e.g.
            ## this is not possible for in-place operations). This allows to calculate the derivative of each output value
            ## w.r.t. all input values (its "gradient").
            ## In this case, we want to know the derivatives of the loss value w.r.t. all the NN parameters (weights and biases).
            ## Our optimizers are usually based on "Gradient Descent", so we need the gradients...
            loss.backward()
            ## Alright, now let the optimizer do the magic.
            ## We passed the optimizer the NN parameters by reference when we initialized the optimizer.
            ## And the gradient information is stored in the tensors of the parameters, too (not in the loss or so).
            ## That's why the step() function does not require any arguments.
            optimizer.step()

            ## For the plot at the end, save the loss values
            avg_loss += loss.item()

            if counter % 20 == 0:
                print("Epoch {}......Step: {}/{}....... Average Loss for Epoch: {} = {} + {}".format(epoch, counter,
                                                                                                len(train_loader),
                                                                                                avg_loss / counter, loss.item(), 0))
        print("Epoch {}/{} Done, Total Loss: {}".format(epoch, EPOCHS, avg_loss / len(train_loader)))
        ## It's an average loss, so divide by the number of samples/ size of the training data set
        avg_losses[epoch] = avg_loss / len(train_loader)

        ## To understand how the NN learns, all 500 epochs a plot is shown (Close the plot window and wait for the next plot)
        if epoch%500 == 0:
            eval_and_plot(model)

    ## This plots the loss curve
    plt.figure(figsize=(12, 8))
    plt.plot(avg_losses, "x-")
    plt.title("Train loss (MSE, reduction=mean, averaged over epoch)")
    plt.xlabel("Epoch")
    plt.ylabel("loss")
    plt.grid(visible=True, which='both', axis='both')
    plt.show()

    ## Now save the trained model with all its properties to the model_file
    torch.save(model, model_file)

    ## And return the model in case we want to use it for other tasks
    return model


## As the functions written before are just function definitions,
## those functions still have to be called.
## This is done here.
## Train the model
model = train(train_loader, lr, epochs)

## Test that saving the model worked: load it from file
model = torch.load(model_file)
## and evaluate and plot once
eval_and_plot(model)

print(model)

print("layer1, weights: ", model.fcnn1[0].weight) #a little promblem with this code, use fcnn1[0] instead of layer
print("layer1, bias: ", model.fcnn1[0].bias)
#print(model.layer2.weight)
#print(model.layer2.bias)
print("layer3, weights: ", model.fcnn1[2].weight)
print("layer3, bias: ", model.fcnn1[2].bias)
# Out:
# Using cpu device
# train_x tensor([[-0.8291],
#         [-2.5534],
#         [ 2.3074],
#         [-0.9674],
#         [ 4.5276],
#         [-3.5104],
#         [ 1.3472],
#         [-0.7050],
#         [-1.4709],
#         [ 0.4865],
#         [ 4.7541],
#         [ 1.5276],
#         [-2.7134],
#         [ 3.1621],
#         [-4.6018],
#         [-3.7129]])
# train_y tensor([[-0.7374],
#         [-0.5549],
#         [ 0.7407],
#         [-0.8234],
#         [-0.9830],
#         [ 0.3605],
#         [ 0.9751],
#         [-0.6481],
#         [-0.9950],
#         [ 0.4675],
#         [-0.9991],
#         [ 0.9991],
#         [-0.4152],
#         [-0.0205],
#         [ 0.9939],
#         [ 0.5407]])
# Starting Training of the model
# Epoch 0/1600 Done, Total Loss: 1.035586655139923
# Epoch 1/1600 Done, Total Loss: 1.0078712403774261
# Epoch 2/1600 Done, Total Loss: 0.9670191407203674
# Epoch 3/1600 Done, Total Loss: 0.9343004524707794
# Epoch 4/1600 Done, Total Loss: 0.9007022678852081
# Epoch 5/1600 Done, Total Loss: 0.8799832165241241
# Epoch 6/1600 Done, Total Loss: 0.8549812138080597
# Epoch 7/1600 Done, Total Loss: 0.8329813182353973
# Epoch 8/1600 Done, Total Loss: 0.8069253861904144
# Epoch 9/1600 Done, Total Loss: 0.7922433316707611
# Epoch 10/1600 Done, Total Loss: 0.761867344379425
# Epoch 11/1600 Done, Total Loss: 0.7492507994174957
# Epoch 12/1600 Done, Total Loss: 0.7340088188648224
# Epoch 13/1600 Done, Total Loss: 0.7261368036270142
# Epoch 14/1600 Done, Total Loss: 0.7034623771905899
# Epoch 15/1600 Done, Total Loss: 0.6959838569164276
# Epoch 16/1600 Done, Total Loss: 0.6856302917003632
# Epoch 17/1600 Done, Total Loss: 0.6741330921649933
# Epoch 18/1600 Done, Total Loss: 0.6709356009960175
# Epoch 19/1600 Done, Total Loss: 0.6568772196769714
# Epoch 20/1600 Done, Total Loss: 0.6504916846752167
# Epoch 21/1600 Done, Total Loss: 0.6449621915817261
# Epoch 22/1600 Done, Total Loss: 0.6424212455749512
# Epoch 23/1600 Done, Total Loss: 0.6321201175451279
# Epoch 24/1600 Done, Total Loss: 0.6290543973445892
# Epoch 25/1600 Done, Total Loss: 0.6272812485694885
# Epoch 26/1600 Done, Total Loss: 0.6213293969631195
# Epoch 27/1600 Done, Total Loss: 0.6183680295944214
# Epoch 28/1600 Done, Total Loss: 0.6148598492145538
# Epoch 29/1600 Done, Total Loss: 0.615540623664856
# Epoch 30/1600 Done, Total Loss: 0.6102576553821564
# Epoch 31/1600 Done, Total Loss: 0.6074594557285309
# Epoch 32/1600 Done, Total Loss: 0.6067371070384979
# Epoch 33/1600 Done, Total Loss: 0.6057025194168091
# Epoch 34/1600 Done, Total Loss: 0.6021868586540222
# Epoch 35/1600 Done, Total Loss: 0.6018336117267609
# Epoch 36/1600 Done, Total Loss: 0.5985495448112488
# Epoch 37/1600 Done, Total Loss: 0.5990698933601379
# Epoch 38/1600 Done, Total Loss: 0.5958954989910126
# Epoch 39/1600 Done, Total Loss: 0.5937605202198029
# Epoch 40/1600 Done, Total Loss: 0.5923060327768326
# Epoch 41/1600 Done, Total Loss: 0.5915593206882477
# Epoch 42/1600 Done, Total Loss: 0.5892578065395355
# Epoch 43/1600 Done, Total Loss: 0.5877187699079514
# Epoch 44/1600 Done, Total Loss: 0.5862966328859329
# Epoch 45/1600 Done, Total Loss: 0.5846852660179138
# Epoch 46/1600 Done, Total Loss: 0.583493635058403
# Epoch 47/1600 Done, Total Loss: 0.5827750861644745
# Epoch 48/1600 Done, Total Loss: 0.5803345143795013
# Epoch 49/1600 Done, Total Loss: 0.5787199437618256
# Epoch 50/1600 Done, Total Loss: 0.5773526728153229
# Epoch 51/1600 Done, Total Loss: 0.5758073329925537
# Epoch 52/1600 Done, Total Loss: 0.574921041727066
# Epoch 53/1600 Done, Total Loss: 0.5728986263275146
# Epoch 54/1600 Done, Total Loss: 0.572025328874588
# Epoch 55/1600 Done, Total Loss: 0.5698078125715256
# Epoch 56/1600 Done, Total Loss: 0.5685034096240997
# Epoch 57/1600 Done, Total Loss: 0.5673795342445374
# Epoch 58/1600 Done, Total Loss: 0.5655093789100647
# Epoch 59/1600 Done, Total Loss: 0.5641348212957382
# Epoch 60/1600 Done, Total Loss: 0.5624741613864899
# Epoch 61/1600 Done, Total Loss: 0.5610556900501251
# Epoch 62/1600 Done, Total Loss: 0.5594508945941925
# Epoch 63/1600 Done, Total Loss: 0.5584415197372437
# Epoch 64/1600 Done, Total Loss: 0.5564896911382675
# Epoch 65/1600 Done, Total Loss: 0.5553964525461197
# Epoch 66/1600 Done, Total Loss: 0.5543990731239319
# Epoch 67/1600 Done, Total Loss: 0.5521175712347031
# Epoch 68/1600 Done, Total Loss: 0.5507726818323135
# Epoch 69/1600 Done, Total Loss: 0.5495769679546356
# Epoch 70/1600 Done, Total Loss: 0.5479192286729813
# Epoch 71/1600 Done, Total Loss: 0.5469013750553131
# Epoch 72/1600 Done, Total Loss: 0.5453037172555923
# Epoch 73/1600 Done, Total Loss: 0.5437344014644623
# Epoch 74/1600 Done, Total Loss: 0.5418925285339355
# Epoch 75/1600 Done, Total Loss: 0.5410109758377075
# Epoch 76/1600 Done, Total Loss: 0.5400907695293427
# Epoch 77/1600 Done, Total Loss: 0.5383141338825226
# Epoch 78/1600 Done, Total Loss: 0.5363141447305679
# Epoch 79/1600 Done, Total Loss: 0.5349357575178146
# Epoch 80/1600 Done, Total Loss: 0.5335251688957214
# Epoch 81/1600 Done, Total Loss: 0.5320685058832169
# Epoch 82/1600 Done, Total Loss: 0.530863493680954
# Epoch 83/1600 Done, Total Loss: 0.5292967855930328
# Epoch 84/1600 Done, Total Loss: 0.5276699066162109
# Epoch 85/1600 Done, Total Loss: 0.5263305306434631
# Epoch 86/1600 Done, Total Loss: 0.5261146128177643
# Epoch 87/1600 Done, Total Loss: 0.5236077606678009
# Epoch 88/1600 Done, Total Loss: 0.5221225470304489
# Epoch 89/1600 Done, Total Loss: 0.5208489149808884
# Epoch 90/1600 Done, Total Loss: 0.5191694349050522
# Epoch 91/1600 Done, Total Loss: 0.517987847328186
# Epoch 92/1600 Done, Total Loss: 0.5163627564907074
# Epoch 93/1600 Done, Total Loss: 0.5153151750564575
# Epoch 94/1600 Done, Total Loss: 0.513594776391983
# Epoch 95/1600 Done, Total Loss: 0.5130636096000671
# Epoch 96/1600 Done, Total Loss: 0.5110458731651306
# Epoch 97/1600 Done, Total Loss: 0.5095456540584564
# Epoch 98/1600 Done, Total Loss: 0.5083000734448433
# Epoch 99/1600 Done, Total Loss: 0.506841242313385
# Epoch 100/1600 Done, Total Loss: 0.5052239745855331
# Epoch 101/1600 Done, Total Loss: 0.5037645697593689
# Epoch 102/1600 Done, Total Loss: 0.5025925040245056
# Epoch 103/1600 Done, Total Loss: 0.5016951560974121
# Epoch 104/1600 Done, Total Loss: 0.5000489503145218
# Epoch 105/1600 Done, Total Loss: 0.49840500950813293
# Epoch 106/1600 Done, Total Loss: 0.4972034692764282
# Epoch 107/1600 Done, Total Loss: 0.49556970596313477
# Epoch 108/1600 Done, Total Loss: 0.49392513930797577
# Epoch 109/1600 Done, Total Loss: 0.4925335645675659
# Epoch 110/1600 Done, Total Loss: 0.49153468012809753
# Epoch 111/1600 Done, Total Loss: 0.4900340586900711
# Epoch 112/1600 Done, Total Loss: 0.4888020008802414
# Epoch 113/1600 Done, Total Loss: 0.48787541687488556
# Epoch 114/1600 Done, Total Loss: 0.48631392419338226
# Epoch 115/1600 Done, Total Loss: 0.48495370149612427
# Epoch 116/1600 Done, Total Loss: 0.4832489341497421
# Epoch 117/1600 Done, Total Loss: 0.4820091873407364
# Epoch 118/1600 Done, Total Loss: 0.4807213544845581
# Epoch 119/1600 Done, Total Loss: 0.47903425991535187
# Epoch 120/1600 Done, Total Loss: 0.4788498133420944
# Epoch 121/1600 Done, Total Loss: 0.47664400935173035
# Epoch 122/1600 Done, Total Loss: 0.47534745931625366
# Epoch 123/1600 Done, Total Loss: 0.47407253086566925
# Epoch 124/1600 Done, Total Loss: 0.4726872742176056
# Epoch 125/1600 Done, Total Loss: 0.4719585180282593
# Epoch 126/1600 Done, Total Loss: 0.46978750824928284
# Epoch 127/1600 Done, Total Loss: 0.4685435891151428
# Epoch 128/1600 Done, Total Loss: 0.46732182800769806
# Epoch 129/1600 Done, Total Loss: 0.46585214138031006
# Epoch 130/1600 Done, Total Loss: 0.4648439437150955
# Epoch 131/1600 Done, Total Loss: 0.4632052034139633
# Epoch 132/1600 Done, Total Loss: 0.4626774787902832
# Epoch 133/1600 Done, Total Loss: 0.4612569808959961
# Epoch 134/1600 Done, Total Loss: 0.4592645764350891
# Epoch 135/1600 Done, Total Loss: 0.457815021276474
# Epoch 136/1600 Done, Total Loss: 0.45715372264385223
# Epoch 137/1600 Done, Total Loss: 0.45611506700515747
# Epoch 138/1600 Done, Total Loss: 0.4541907459497452
# Epoch 139/1600 Done, Total Loss: 0.4525616988539696
# Epoch 140/1600 Done, Total Loss: 0.45113755762577057
# Epoch 141/1600 Done, Total Loss: 0.44994764029979706
# Epoch 142/1600 Done, Total Loss: 0.4487511068582535
# Epoch 143/1600 Done, Total Loss: 0.4476282447576523
# Epoch 144/1600 Done, Total Loss: 0.446458637714386
# Epoch 145/1600 Done, Total Loss: 0.4446532726287842
# Epoch 146/1600 Done, Total Loss: 0.4433649033308029
# Epoch 147/1600 Done, Total Loss: 0.44219157099723816
# Epoch 148/1600 Done, Total Loss: 0.44166378676891327
# Epoch 149/1600 Done, Total Loss: 0.43929940462112427
# Epoch 150/1600 Done, Total Loss: 0.4384279251098633
# Epoch 151/1600 Done, Total Loss: 0.43718321621418
# Epoch 152/1600 Done, Total Loss: 0.4353078231215477
# Epoch 153/1600 Done, Total Loss: 0.43493176996707916
# Epoch 154/1600 Done, Total Loss: 0.4331071376800537
# Epoch 155/1600 Done, Total Loss: 0.43200160562992096
# Epoch 156/1600 Done, Total Loss: 0.4304589480161667
# Epoch 157/1600 Done, Total Loss: 0.42956677079200745
# Epoch 158/1600 Done, Total Loss: 0.42793509364128113
# Epoch 159/1600 Done, Total Loss: 0.42658771574497223
# Epoch 160/1600 Done, Total Loss: 0.42577607929706573
# Epoch 161/1600 Done, Total Loss: 0.42446179687976837
# Epoch 162/1600 Done, Total Loss: 0.4229321926832199
# Epoch 163/1600 Done, Total Loss: 0.4216242879629135
# Epoch 164/1600 Done, Total Loss: 0.42013468593358994
# Epoch 165/1600 Done, Total Loss: 0.41895338892936707
# Epoch 166/1600 Done, Total Loss: 0.41746073961257935
# Epoch 167/1600 Done, Total Loss: 0.41649653017520905
# Epoch 168/1600 Done, Total Loss: 0.41525430977344513
# Epoch 169/1600 Done, Total Loss: 0.4135442078113556
# Epoch 170/1600 Done, Total Loss: 0.41253262758255005
# Epoch 171/1600 Done, Total Loss: 0.41098031401634216
# Epoch 172/1600 Done, Total Loss: 0.41005153954029083
# Epoch 173/1600 Done, Total Loss: 0.40932902693748474
# Epoch 174/1600 Done, Total Loss: 0.4077066630125046
# Epoch 175/1600 Done, Total Loss: 0.40660659968852997
# Epoch 176/1600 Done, Total Loss: 0.405574768781662
# Epoch 177/1600 Done, Total Loss: 0.40367209911346436
# Epoch 178/1600 Done, Total Loss: 0.40278588235378265
# Epoch 179/1600 Done, Total Loss: 0.4012104868888855
# Epoch 180/1600 Done, Total Loss: 0.3997897654771805
# Epoch 181/1600 Done, Total Loss: 0.39866430312395096
# Epoch 182/1600 Done, Total Loss: 0.39779192209243774
# Epoch 183/1600 Done, Total Loss: 0.3965657502412796
# Epoch 184/1600 Done, Total Loss: 0.39521877467632294
# Epoch 185/1600 Done, Total Loss: 0.394172765314579
# Epoch 186/1600 Done, Total Loss: 0.3926638066768646
# Epoch 187/1600 Done, Total Loss: 0.3913329541683197
# Epoch 188/1600 Done, Total Loss: 0.3901827409863472
# Epoch 189/1600 Done, Total Loss: 0.3890717178583145
# Epoch 190/1600 Done, Total Loss: 0.38742999732494354
# Epoch 191/1600 Done, Total Loss: 0.38620300590991974
# Epoch 192/1600 Done, Total Loss: 0.38497135043144226
# Epoch 193/1600 Done, Total Loss: 0.38379041850566864
# Epoch 194/1600 Done, Total Loss: 0.3825971782207489
# Epoch 195/1600 Done, Total Loss: 0.381420835852623
# Epoch 196/1600 Done, Total Loss: 0.38003185391426086
# Epoch 197/1600 Done, Total Loss: 0.3789539188146591
# Epoch 198/1600 Done, Total Loss: 0.37858887016773224
# Epoch 199/1600 Done, Total Loss: 0.3764198273420334
# Epoch 200/1600 Done, Total Loss: 0.3753252699971199
# Epoch 201/1600 Done, Total Loss: 0.3746402859687805
# Epoch 202/1600 Done, Total Loss: 0.37262123823165894
# Epoch 203/1600 Done, Total Loss: 0.37158381938934326
# Epoch 204/1600 Done, Total Loss: 0.37051597237586975
# Epoch 205/1600 Done, Total Loss: 0.369378998875618
# Epoch 206/1600 Done, Total Loss: 0.3679063320159912
# Epoch 207/1600 Done, Total Loss: 0.3666524887084961
# Epoch 208/1600 Done, Total Loss: 0.36565758287906647
# Epoch 209/1600 Done, Total Loss: 0.36425764858722687
# Epoch 210/1600 Done, Total Loss: 0.3629269301891327
# Epoch 211/1600 Done, Total Loss: 0.3620839864015579
# Epoch 212/1600 Done, Total Loss: 0.36070990562438965
# Epoch 213/1600 Done, Total Loss: 0.3595358431339264
# Epoch 214/1600 Done, Total Loss: 0.3583945482969284
# Epoch 215/1600 Done, Total Loss: 0.3568631708621979
# Epoch 216/1600 Done, Total Loss: 0.3563532680273056
# Epoch 217/1600 Done, Total Loss: 0.3543720841407776
# Epoch 218/1600 Done, Total Loss: 0.35358990728855133
# Epoch 219/1600 Done, Total Loss: 0.35238127410411835
# Epoch 220/1600 Done, Total Loss: 0.3516744077205658
# Epoch 221/1600 Done, Total Loss: 0.34954842925071716
# Epoch 222/1600 Done, Total Loss: 0.3483603149652481
# Epoch 223/1600 Done, Total Loss: 0.3471917062997818
# Epoch 224/1600 Done, Total Loss: 0.3458426743745804
# Epoch 225/1600 Done, Total Loss: 0.3450290411710739
# Epoch 226/1600 Done, Total Loss: 0.34355373680591583
# Epoch 227/1600 Done, Total Loss: 0.3422710448503494
# Epoch 228/1600 Done, Total Loss: 0.3411121666431427
# Epoch 229/1600 Done, Total Loss: 0.33985404670238495
# Epoch 230/1600 Done, Total Loss: 0.3386363089084625
# Epoch 231/1600 Done, Total Loss: 0.33753645420074463
# Epoch 232/1600 Done, Total Loss: 0.3363867253065109
# Epoch 233/1600 Done, Total Loss: 0.33586470782756805
# Epoch 234/1600 Done, Total Loss: 0.33401140570640564
# Epoch 235/1600 Done, Total Loss: 0.332624226808548
# Epoch 236/1600 Done, Total Loss: 0.3314005881547928
# Epoch 237/1600 Done, Total Loss: 0.3302936851978302
# Epoch 238/1600 Done, Total Loss: 0.33022812753915787
# Epoch 239/1600 Done, Total Loss: 0.32780152559280396
# Epoch 240/1600 Done, Total Loss: 0.32674868404865265
# Epoch 241/1600 Done, Total Loss: 0.32534059882164
# Epoch 242/1600 Done, Total Loss: 0.32417988777160645
# Epoch 243/1600 Done, Total Loss: 0.32352472841739655
# Epoch 244/1600 Done, Total Loss: 0.32180608063936234
# Epoch 245/1600 Done, Total Loss: 0.3213787078857422
# Epoch 246/1600 Done, Total Loss: 0.31974394619464874
# Epoch 247/1600 Done, Total Loss: 0.3183380588889122
# Epoch 248/1600 Done, Total Loss: 0.3169706016778946
# Epoch 249/1600 Done, Total Loss: 0.3157758489251137
# Epoch 250/1600 Done, Total Loss: 0.314740389585495
# Epoch 251/1600 Done, Total Loss: 0.3133712559938431
# Epoch 252/1600 Done, Total Loss: 0.31224482506513596
# Epoch 253/1600 Done, Total Loss: 0.3115337938070297
# Epoch 254/1600 Done, Total Loss: 0.3101411312818527
# Epoch 255/1600 Done, Total Loss: 0.3091112822294235
# Epoch 256/1600 Done, Total Loss: 0.3075636625289917
# Epoch 257/1600 Done, Total Loss: 0.30629171431064606
# Epoch 258/1600 Done, Total Loss: 0.3055567145347595
# Epoch 259/1600 Done, Total Loss: 0.30431193113327026
# Epoch 260/1600 Done, Total Loss: 0.30320194363594055
# Epoch 261/1600 Done, Total Loss: 0.30160413682460785
# Epoch 262/1600 Done, Total Loss: 0.30049414932727814
# Epoch 263/1600 Done, Total Loss: 0.29933421313762665
# Epoch 264/1600 Done, Total Loss: 0.29819679260253906
# Epoch 265/1600 Done, Total Loss: 0.29700911045074463
# Epoch 266/1600 Done, Total Loss: 0.2959711477160454
# Epoch 267/1600 Done, Total Loss: 0.2946098670363426
# Epoch 268/1600 Done, Total Loss: 0.2941681146621704
# Epoch 269/1600 Done, Total Loss: 0.292402058839798
# Epoch 270/1600 Done, Total Loss: 0.2913624793291092
# Epoch 271/1600 Done, Total Loss: 0.29049140214920044
# Epoch 272/1600 Done, Total Loss: 0.28919878602027893
# Epoch 273/1600 Done, Total Loss: 0.28823430836200714
# Epoch 274/1600 Done, Total Loss: 0.2876744419336319
# Epoch 275/1600 Done, Total Loss: 0.2860831171274185
# Epoch 276/1600 Done, Total Loss: 0.2848137691617012
# Epoch 277/1600 Done, Total Loss: 0.2837062478065491
# Epoch 278/1600 Done, Total Loss: 0.2830803021788597
# Epoch 279/1600 Done, Total Loss: 0.28169310092926025
# Epoch 280/1600 Done, Total Loss: 0.2812085896730423
# Epoch 281/1600 Done, Total Loss: 0.27925634384155273
# Epoch 282/1600 Done, Total Loss: 0.27850477397441864
# Epoch 283/1600 Done, Total Loss: 0.2771320566534996
# Epoch 284/1600 Done, Total Loss: 0.2759274020791054
# Epoch 285/1600 Done, Total Loss: 0.27539052069187164
# Epoch 286/1600 Done, Total Loss: 0.2741553857922554
# Epoch 287/1600 Done, Total Loss: 0.2730242386460304
# Epoch 288/1600 Done, Total Loss: 0.2721558213233948
# Epoch 289/1600 Done, Total Loss: 0.27060311287641525
# Epoch 290/1600 Done, Total Loss: 0.26964469999074936
# Epoch 291/1600 Done, Total Loss: 0.2684364467859268
# Epoch 292/1600 Done, Total Loss: 0.2672477513551712
# Epoch 293/1600 Done, Total Loss: 0.2663041725754738
# Epoch 294/1600 Done, Total Loss: 0.2651863396167755
# Epoch 295/1600 Done, Total Loss: 0.2641383409500122
# Epoch 296/1600 Done, Total Loss: 0.26306892931461334
# Epoch 297/1600 Done, Total Loss: 0.26223793625831604
# Epoch 298/1600 Done, Total Loss: 0.2609028145670891
# Epoch 299/1600 Done, Total Loss: 0.26069358736276627
# Epoch 300/1600 Done, Total Loss: 0.2593553513288498
# Epoch 301/1600 Done, Total Loss: 0.257644459605217
# Epoch 302/1600 Done, Total Loss: 0.2565702125430107
# Epoch 303/1600 Done, Total Loss: 0.2556353956460953
# Epoch 304/1600 Done, Total Loss: 0.2543717920780182
# Epoch 305/1600 Done, Total Loss: 0.25388846546411514
# Epoch 306/1600 Done, Total Loss: 0.25264575332403183
# Epoch 307/1600 Done, Total Loss: 0.25162430107593536
# Epoch 308/1600 Done, Total Loss: 0.25042495131492615
# Epoch 309/1600 Done, Total Loss: 0.24919681996107101
# Epoch 310/1600 Done, Total Loss: 0.2482842206954956
# Epoch 311/1600 Done, Total Loss: 0.24760659039020538
# Epoch 312/1600 Done, Total Loss: 0.24603115022182465
# Epoch 313/1600 Done, Total Loss: 0.2458329051733017
# Epoch 314/1600 Done, Total Loss: 0.24403055012226105
# Epoch 315/1600 Done, Total Loss: 0.24287988990545273
# Epoch 316/1600 Done, Total Loss: 0.2418001890182495
# Epoch 317/1600 Done, Total Loss: 0.2408103495836258
# Epoch 318/1600 Done, Total Loss: 0.23973234742879868
# Epoch 319/1600 Done, Total Loss: 0.2396199107170105
# Epoch 320/1600 Done, Total Loss: 0.23797286301851273
# Epoch 321/1600 Done, Total Loss: 0.236668661236763
# Epoch 322/1600 Done, Total Loss: 0.23582734912633896
# Epoch 323/1600 Done, Total Loss: 0.2347148284316063
# Epoch 324/1600 Done, Total Loss: 0.23356285691261292
# Epoch 325/1600 Done, Total Loss: 0.23252232000231743
# Epoch 326/1600 Done, Total Loss: 0.2317306026816368
# Epoch 327/1600 Done, Total Loss: 0.23047921061515808
# Epoch 328/1600 Done, Total Loss: 0.2299448847770691
# Epoch 329/1600 Done, Total Loss: 0.22853313386440277
# Epoch 330/1600 Done, Total Loss: 0.2279888167977333
# Epoch 331/1600 Done, Total Loss: 0.22669800370931625
# Epoch 332/1600 Done, Total Loss: 0.22537600994110107
# Epoch 333/1600 Done, Total Loss: 0.2246488258242607
# Epoch 334/1600 Done, Total Loss: 0.22349506616592407
# Epoch 335/1600 Done, Total Loss: 0.2222474291920662
# Epoch 336/1600 Done, Total Loss: 0.22129448503255844
# Epoch 337/1600 Done, Total Loss: 0.2203540951013565
# Epoch 338/1600 Done, Total Loss: 0.21934515237808228
# Epoch 339/1600 Done, Total Loss: 0.21856127306818962
# Epoch 340/1600 Done, Total Loss: 0.21793776005506516
# Epoch 341/1600 Done, Total Loss: 0.21621792018413544
# Epoch 342/1600 Done, Total Loss: 0.2153828963637352
# Epoch 343/1600 Done, Total Loss: 0.2143315076828003
# Epoch 344/1600 Done, Total Loss: 0.2132330983877182
# Epoch 345/1600 Done, Total Loss: 0.21251847594976425
# Epoch 346/1600 Done, Total Loss: 0.21131981909275055
# Epoch 347/1600 Done, Total Loss: 0.21044912189245224
# Epoch 348/1600 Done, Total Loss: 0.20934691280126572
# Epoch 349/1600 Done, Total Loss: 0.20821640640497208
# Epoch 350/1600 Done, Total Loss: 0.2072587013244629
# Epoch 351/1600 Done, Total Loss: 0.20647268742322922
# Epoch 352/1600 Done, Total Loss: 0.2056484967470169
# Epoch 353/1600 Done, Total Loss: 0.20430970937013626
# Epoch 354/1600 Done, Total Loss: 0.20342273265123367
# Epoch 355/1600 Done, Total Loss: 0.20236289501190186
# Epoch 356/1600 Done, Total Loss: 0.20170658826828003
# Epoch 357/1600 Done, Total Loss: 0.20077424496412277
# Epoch 358/1600 Done, Total Loss: 0.20004776865243912
# Epoch 359/1600 Done, Total Loss: 0.19852422177791595
# Epoch 360/1600 Done, Total Loss: 0.19779061526060104
# Epoch 361/1600 Done, Total Loss: 0.19660333544015884
# Epoch 362/1600 Done, Total Loss: 0.19621802866458893
# Epoch 363/1600 Done, Total Loss: 0.19482829421758652
# Epoch 364/1600 Done, Total Loss: 0.19367805123329163
# Epoch 365/1600 Done, Total Loss: 0.19273903965950012
# Epoch 366/1600 Done, Total Loss: 0.19215448200702667
# Epoch 367/1600 Done, Total Loss: 0.19112130627036095
# Epoch 368/1600 Done, Total Loss: 0.19001373648643494
# Epoch 369/1600 Done, Total Loss: 0.18933367729187012
# Epoch 370/1600 Done, Total Loss: 0.18808836489915848
# Epoch 371/1600 Done, Total Loss: 0.1870437189936638
# Epoch 372/1600 Done, Total Loss: 0.18615038692951202
# Epoch 373/1600 Done, Total Loss: 0.18517934530973434
# Epoch 374/1600 Done, Total Loss: 0.18448170274496078
# Epoch 375/1600 Done, Total Loss: 0.18334675580263138
# Epoch 376/1600 Done, Total Loss: 0.18237905204296112
# Epoch 377/1600 Done, Total Loss: 0.18147745728492737
# Epoch 378/1600 Done, Total Loss: 0.18056661635637283
# Epoch 379/1600 Done, Total Loss: 0.17963838577270508
# Epoch 380/1600 Done, Total Loss: 0.17855899035930634
# Epoch 381/1600 Done, Total Loss: 0.17777210474014282
# Epoch 382/1600 Done, Total Loss: 0.17677345871925354
# Epoch 383/1600 Done, Total Loss: 0.17579566687345505
# Epoch 384/1600 Done, Total Loss: 0.17517836391925812
# Epoch 385/1600 Done, Total Loss: 0.1740170493721962
# Epoch 386/1600 Done, Total Loss: 0.17314304411411285
# Epoch 387/1600 Done, Total Loss: 0.17256121337413788
# Epoch 388/1600 Done, Total Loss: 0.1717228889465332
# Epoch 389/1600 Done, Total Loss: 0.1704268753528595
# Epoch 390/1600 Done, Total Loss: 0.1700148656964302
# Epoch 391/1600 Done, Total Loss: 0.16861766576766968
# Epoch 392/1600 Done, Total Loss: 0.16773487254977226
# Epoch 393/1600 Done, Total Loss: 0.1669468656182289
# Epoch 394/1600 Done, Total Loss: 0.1660272441804409
# Epoch 395/1600 Done, Total Loss: 0.16498304903507233
# Epoch 396/1600 Done, Total Loss: 0.16406958550214767
# Epoch 397/1600 Done, Total Loss: 0.1634848266839981
# Epoch 398/1600 Done, Total Loss: 0.1623157449066639
# Epoch 399/1600 Done, Total Loss: 0.161379374563694
# Epoch 400/1600 Done, Total Loss: 0.16056019812822342
# Epoch 401/1600 Done, Total Loss: 0.15967950969934464
# Epoch 402/1600 Done, Total Loss: 0.15884872153401375
# Epoch 403/1600 Done, Total Loss: 0.15819543600082397
# Epoch 404/1600 Done, Total Loss: 0.15697696805000305
# Epoch 405/1600 Done, Total Loss: 0.1562245488166809
# Epoch 406/1600 Done, Total Loss: 0.15527664124965668
# Epoch 407/1600 Done, Total Loss: 0.15451929718255997
# Epoch 408/1600 Done, Total Loss: 0.1534668765962124
# Epoch 409/1600 Done, Total Loss: 0.15266771242022514
# Epoch 410/1600 Done, Total Loss: 0.15176551416516304
# Epoch 411/1600 Done, Total Loss: 0.15099521726369858
# Epoch 412/1600 Done, Total Loss: 0.15024030208587646
# Epoch 413/1600 Done, Total Loss: 0.14943093061447144
# Epoch 414/1600 Done, Total Loss: 0.14878717809915543
# Epoch 415/1600 Done, Total Loss: 0.14755696803331375
# Epoch 416/1600 Done, Total Loss: 0.14666365087032318
# Epoch 417/1600 Done, Total Loss: 0.14587899297475815
# Epoch 418/1600 Done, Total Loss: 0.1448649764060974
# Epoch 419/1600 Done, Total Loss: 0.14440134167671204
# Epoch 420/1600 Done, Total Loss: 0.14351864159107208
# Epoch 421/1600 Done, Total Loss: 0.14239559322595596
# Epoch 422/1600 Done, Total Loss: 0.14163075760006905
# Epoch 423/1600 Done, Total Loss: 0.14069507643580437
# Epoch 424/1600 Done, Total Loss: 0.14017028734087944
# Epoch 425/1600 Done, Total Loss: 0.13913164660334587
# Epoch 426/1600 Done, Total Loss: 0.13846082612872124
# Epoch 427/1600 Done, Total Loss: 0.13751056045293808
# Epoch 428/1600 Done, Total Loss: 0.13657525554299355
# Epoch 429/1600 Done, Total Loss: 0.1358417198061943
# Epoch 430/1600 Done, Total Loss: 0.13560624793171883
# Epoch 431/1600 Done, Total Loss: 0.13426325842738152
# Epoch 432/1600 Done, Total Loss: 0.13343257457017899
# Epoch 433/1600 Done, Total Loss: 0.13263479806482792
# Epoch 434/1600 Done, Total Loss: 0.13180995360016823
# Epoch 435/1600 Done, Total Loss: 0.1311909519135952
# Epoch 436/1600 Done, Total Loss: 0.13072798028588295
# Epoch 437/1600 Done, Total Loss: 0.1300518661737442
# Epoch 438/1600 Done, Total Loss: 0.12864124029874802
# Epoch 439/1600 Done, Total Loss: 0.12818077951669693
# Epoch 440/1600 Done, Total Loss: 0.12711171805858612
# Epoch 441/1600 Done, Total Loss: 0.12646956741809845
# Epoch 442/1600 Done, Total Loss: 0.12549640610814095
# Epoch 443/1600 Done, Total Loss: 0.12493669055402279
# Epoch 444/1600 Done, Total Loss: 0.12403739616274834
# Epoch 445/1600 Done, Total Loss: 0.12354768812656403
# Epoch 446/1600 Done, Total Loss: 0.12286954745650291
# Epoch 447/1600 Done, Total Loss: 0.12186729535460472
# Epoch 448/1600 Done, Total Loss: 0.1214086003601551
# Epoch 449/1600 Done, Total Loss: 0.12037617713212967
# Epoch 450/1600 Done, Total Loss: 0.11961225792765617
# Epoch 451/1600 Done, Total Loss: 0.11907703056931496
# Epoch 452/1600 Done, Total Loss: 0.11807632818818092
# Epoch 453/1600 Done, Total Loss: 0.11721157282590866
# Epoch 454/1600 Done, Total Loss: 0.11653685569763184
# Epoch 455/1600 Done, Total Loss: 0.115758016705513
# Epoch 456/1600 Done, Total Loss: 0.11504001915454865
# Epoch 457/1600 Done, Total Loss: 0.11428366973996162
# Epoch 458/1600 Done, Total Loss: 0.11358793079853058
# Epoch 459/1600 Done, Total Loss: 0.11353256925940514
# Epoch 460/1600 Done, Total Loss: 0.11222702637314796
# Epoch 461/1600 Done, Total Loss: 0.11157570034265518
# Epoch 462/1600 Done, Total Loss: 0.11075102537870407
# Epoch 463/1600 Done, Total Loss: 0.10997046902775764
# Epoch 464/1600 Done, Total Loss: 0.10917798429727554
# Epoch 465/1600 Done, Total Loss: 0.1086684949696064
# Epoch 466/1600 Done, Total Loss: 0.10811850428581238
# Epoch 467/1600 Done, Total Loss: 0.10727924481034279
# Epoch 468/1600 Done, Total Loss: 0.10650857724249363
# Epoch 469/1600 Done, Total Loss: 0.10573526471853256
# Epoch 470/1600 Done, Total Loss: 0.1053006760776043
# Epoch 471/1600 Done, Total Loss: 0.10446263290941715
# Epoch 472/1600 Done, Total Loss: 0.103789072483778
# Epoch 473/1600 Done, Total Loss: 0.10298444330692291
# Epoch 474/1600 Done, Total Loss: 0.10263600200414658
# Epoch 475/1600 Done, Total Loss: 0.10174722597002983
# Epoch 476/1600 Done, Total Loss: 0.1011078916490078
# Epoch 477/1600 Done, Total Loss: 0.1004885733127594
# Epoch 478/1600 Done, Total Loss: 0.09964290261268616
# Epoch 479/1600 Done, Total Loss: 0.09944775328040123
# Epoch 480/1600 Done, Total Loss: 0.09829211980104446
# Epoch 481/1600 Done, Total Loss: 0.0977502092719078
# Epoch 482/1600 Done, Total Loss: 0.09736503288149834
# Epoch 483/1600 Done, Total Loss: 0.09650181606411934
# Epoch 484/1600 Done, Total Loss: 0.09571104124188423
# Epoch 485/1600 Done, Total Loss: 0.0954606719315052
# Epoch 486/1600 Done, Total Loss: 0.09474952332675457
# Epoch 487/1600 Done, Total Loss: 0.09396770969033241
# Epoch 488/1600 Done, Total Loss: 0.09312764927744865
# Epoch 489/1600 Done, Total Loss: 0.09253142029047012
# Epoch 490/1600 Done, Total Loss: 0.09204543940722942
# Epoch 491/1600 Done, Total Loss: 0.0913003422319889
# Epoch 492/1600 Done, Total Loss: 0.09075754508376122
# Epoch 493/1600 Done, Total Loss: 0.0899922251701355
# Epoch 494/1600 Done, Total Loss: 0.08933112770318985
# Epoch 495/1600 Done, Total Loss: 0.08887123316526413
# Epoch 496/1600 Done, Total Loss: 0.0880995150655508
# Epoch 497/1600 Done, Total Loss: 0.08765925094485283
# Epoch 498/1600 Done, Total Loss: 0.08725683763623238
# Epoch 499/1600 Done, Total Loss: 0.0863187201321125
# Epoch 500/1600 Done, Total Loss: 0.08574793115258217
# Epoch 501/1600 Done, Total Loss: 0.08523048087954521
# Epoch 502/1600 Done, Total Loss: 0.08469590172171593
# Epoch 503/1600 Done, Total Loss: 0.08383961021900177
# Epoch 504/1600 Done, Total Loss: 0.08341166749596596
# Epoch 505/1600 Done, Total Loss: 0.08281361684203148
# Epoch 506/1600 Done, Total Loss: 0.08216841891407967
# Epoch 507/1600 Done, Total Loss: 0.08182750269770622
# Epoch 508/1600 Done, Total Loss: 0.08100012131035328
# Epoch 509/1600 Done, Total Loss: 0.08049050718545914
# Epoch 510/1600 Done, Total Loss: 0.07981672883033752
# Epoch 511/1600 Done, Total Loss: 0.07924136705696583
# Epoch 512/1600 Done, Total Loss: 0.07872452400624752
# Epoch 513/1600 Done, Total Loss: 0.07827037759125233
# Epoch 514/1600 Done, Total Loss: 0.07759252842515707
# Epoch 515/1600 Done, Total Loss: 0.07705826312303543
# Epoch 516/1600 Done, Total Loss: 0.07657271064817905
# Epoch 517/1600 Done, Total Loss: 0.07606330141425133
# Epoch 518/1600 Done, Total Loss: 0.07562709227204323
# Epoch 519/1600 Done, Total Loss: 0.07493325136601925
# Epoch 520/1600 Done, Total Loss: 0.07432669959962368
# Epoch 521/1600 Done, Total Loss: 0.07392467930912971
# Epoch 522/1600 Done, Total Loss: 0.07333947531878948
# Epoch 523/1600 Done, Total Loss: 0.07273968681693077
# Epoch 524/1600 Done, Total Loss: 0.07217926904559135
# Epoch 525/1600 Done, Total Loss: 0.07160371541976929
# Epoch 526/1600 Done, Total Loss: 0.07120016030967236
# Epoch 527/1600 Done, Total Loss: 0.07059224508702755
# Epoch 528/1600 Done, Total Loss: 0.07022837176918983
# Epoch 529/1600 Done, Total Loss: 0.06976582109928131
# Epoch 530/1600 Done, Total Loss: 0.06918895617127419
# Epoch 531/1600 Done, Total Loss: 0.06850910559296608
# Epoch 532/1600 Done, Total Loss: 0.06813401915133
# Epoch 533/1600 Done, Total Loss: 0.0675275381654501
# Epoch 534/1600 Done, Total Loss: 0.06703098490834236
# Epoch 535/1600 Done, Total Loss: 0.06665228307247162
# Epoch 536/1600 Done, Total Loss: 0.06610164511948824
# Epoch 537/1600 Done, Total Loss: 0.06546422094106674
# Epoch 538/1600 Done, Total Loss: 0.06511540710926056
# Epoch 539/1600 Done, Total Loss: 0.06462472304701805
# Epoch 540/1600 Done, Total Loss: 0.06400318816304207
# Epoch 541/1600 Done, Total Loss: 0.06356650218367577
# Epoch 542/1600 Done, Total Loss: 0.06317031010985374
# Epoch 543/1600 Done, Total Loss: 0.06264469027519226
# Epoch 544/1600 Done, Total Loss: 0.062132641673088074
# Epoch 545/1600 Done, Total Loss: 0.06180728506296873
# Epoch 546/1600 Done, Total Loss: 0.06119084917008877
# Epoch 547/1600 Done, Total Loss: 0.06073128059506416
# Epoch 548/1600 Done, Total Loss: 0.0603267140686512
# Epoch 549/1600 Done, Total Loss: 0.05988217517733574
# Epoch 550/1600 Done, Total Loss: 0.05949306860566139
# Epoch 551/1600 Done, Total Loss: 0.05890968441963196
# Epoch 552/1600 Done, Total Loss: 0.05860551446676254
# Epoch 553/1600 Done, Total Loss: 0.058081479743123055
# Epoch 554/1600 Done, Total Loss: 0.05753331631422043
# Epoch 555/1600 Done, Total Loss: 0.05713747814297676
# Epoch 556/1600 Done, Total Loss: 0.05668801628053188
# Epoch 557/1600 Done, Total Loss: 0.056260038167238235
# Epoch 558/1600 Done, Total Loss: 0.05583186075091362
# Epoch 559/1600 Done, Total Loss: 0.05547723360359669
# Epoch 560/1600 Done, Total Loss: 0.055160222575068474
# Epoch 561/1600 Done, Total Loss: 0.05460212379693985
# Epoch 562/1600 Done, Total Loss: 0.05422138515859842
# Epoch 563/1600 Done, Total Loss: 0.05373932048678398
# Epoch 564/1600 Done, Total Loss: 0.053268805146217346
# Epoch 565/1600 Done, Total Loss: 0.05289311986416578
# Epoch 566/1600 Done, Total Loss: 0.05249069258570671
# Epoch 567/1600 Done, Total Loss: 0.05208326131105423
# Epoch 568/1600 Done, Total Loss: 0.05167645402252674
# Epoch 569/1600 Done, Total Loss: 0.0512655321508646
# Epoch 570/1600 Done, Total Loss: 0.05092776380479336
# Epoch 571/1600 Done, Total Loss: 0.0504550039768219
# Epoch 572/1600 Done, Total Loss: 0.0500150378793478
# Epoch 573/1600 Done, Total Loss: 0.04972483590245247
# Epoch 574/1600 Done, Total Loss: 0.04924708418548107
# Epoch 575/1600 Done, Total Loss: 0.04895874857902527
# Epoch 576/1600 Done, Total Loss: 0.04847153089940548
# Epoch 577/1600 Done, Total Loss: 0.04818945936858654
# Epoch 578/1600 Done, Total Loss: 0.04775731731206179
# Epoch 579/1600 Done, Total Loss: 0.04737347178161144
# Epoch 580/1600 Done, Total Loss: 0.04699746519327164
# Epoch 581/1600 Done, Total Loss: 0.046577912755310535
# Epoch 582/1600 Done, Total Loss: 0.0464005209505558
# Epoch 583/1600 Done, Total Loss: 0.04610529635101557
# Epoch 584/1600 Done, Total Loss: 0.04549468867480755
# Epoch 585/1600 Done, Total Loss: 0.045131742022931576
# Epoch 586/1600 Done, Total Loss: 0.04473119601607323
# Epoch 587/1600 Done, Total Loss: 0.04443186428397894
# Epoch 588/1600 Done, Total Loss: 0.04408607445657253
# Epoch 589/1600 Done, Total Loss: 0.0437174066901207
# Epoch 590/1600 Done, Total Loss: 0.043542006984353065
# Epoch 591/1600 Done, Total Loss: 0.04299941845238209
# Epoch 592/1600 Done, Total Loss: 0.04273059032857418
# Epoch 593/1600 Done, Total Loss: 0.042350408621132374
# Epoch 594/1600 Done, Total Loss: 0.04204016551375389
# Epoch 595/1600 Done, Total Loss: 0.04168323799967766
# Epoch 596/1600 Done, Total Loss: 0.04132586158812046
# Epoch 597/1600 Done, Total Loss: 0.04111385904252529
# Epoch 598/1600 Done, Total Loss: 0.04070058465003967
# Epoch 599/1600 Done, Total Loss: 0.04042196832597256
# Epoch 600/1600 Done, Total Loss: 0.040013862773776054
# Epoch 601/1600 Done, Total Loss: 0.03987113945186138
# Epoch 602/1600 Done, Total Loss: 0.039479510858654976
# Epoch 603/1600 Done, Total Loss: 0.03916202578693628
# Epoch 604/1600 Done, Total Loss: 0.038783466443419456
# Epoch 605/1600 Done, Total Loss: 0.038453961722552776
# Epoch 606/1600 Done, Total Loss: 0.038172295317053795
# Epoch 607/1600 Done, Total Loss: 0.03782010171562433
# Epoch 608/1600 Done, Total Loss: 0.03762201964855194
# Epoch 609/1600 Done, Total Loss: 0.03730472829192877
# Epoch 610/1600 Done, Total Loss: 0.03693540021777153
# Epoch 611/1600 Done, Total Loss: 0.03666376229375601
# Epoch 612/1600 Done, Total Loss: 0.03651516977697611
# Epoch 613/1600 Done, Total Loss: 0.03606954403221607
# Epoch 614/1600 Done, Total Loss: 0.035781774669885635
# Epoch 615/1600 Done, Total Loss: 0.035562679171562195
# Epoch 616/1600 Done, Total Loss: 0.03543031681329012
# Epoch 617/1600 Done, Total Loss: 0.03503880649805069
# Epoch 618/1600 Done, Total Loss: 0.03462818777188659
# Epoch 619/1600 Done, Total Loss: 0.03443264774978161
# Epoch 620/1600 Done, Total Loss: 0.03411271795630455
# Epoch 621/1600 Done, Total Loss: 0.03400601353496313
# Epoch 622/1600 Done, Total Loss: 0.03351474041119218
# Epoch 623/1600 Done, Total Loss: 0.03341087978333235
# Epoch 624/1600 Done, Total Loss: 0.033055154606699944
# Epoch 625/1600 Done, Total Loss: 0.03279709629714489
# Epoch 626/1600 Done, Total Loss: 0.03260405920445919
# Epoch 627/1600 Done, Total Loss: 0.03233954403549433
# Epoch 628/1600 Done, Total Loss: 0.032018957659602165
# Epoch 629/1600 Done, Total Loss: 0.03192330431193113
# Epoch 630/1600 Done, Total Loss: 0.03148758411407471
# Epoch 631/1600 Done, Total Loss: 0.031354925595223904
# Epoch 632/1600 Done, Total Loss: 0.031063773669302464
# Epoch 633/1600 Done, Total Loss: 0.030897739343345165
# Epoch 634/1600 Done, Total Loss: 0.03053223341703415
# Epoch 635/1600 Done, Total Loss: 0.03037242777645588
# Epoch 636/1600 Done, Total Loss: 0.03003134299069643
# Epoch 637/1600 Done, Total Loss: 0.02980855479836464
# Epoch 638/1600 Done, Total Loss: 0.029592822305858135
# Epoch 639/1600 Done, Total Loss: 0.029387779533863068
# Epoch 640/1600 Done, Total Loss: 0.029334825463593006
# Epoch 641/1600 Done, Total Loss: 0.028972983360290527
# Epoch 642/1600 Done, Total Loss: 0.028674762696027756
# Epoch 643/1600 Done, Total Loss: 0.028552808798849583
# Epoch 644/1600 Done, Total Loss: 0.028263459913432598
# Epoch 645/1600 Done, Total Loss: 0.02807018719613552
# Epoch 646/1600 Done, Total Loss: 0.027808740735054016
# Epoch 647/1600 Done, Total Loss: 0.02762068109586835
# Epoch 648/1600 Done, Total Loss: 0.027402697596699
# Epoch 649/1600 Done, Total Loss: 0.027171341702342033
# Epoch 650/1600 Done, Total Loss: 0.026949583552777767
# Epoch 651/1600 Done, Total Loss: 0.026846074499189854
# Epoch 652/1600 Done, Total Loss: 0.02657423075288534
# Epoch 653/1600 Done, Total Loss: 0.02640911191701889
# Epoch 654/1600 Done, Total Loss: 0.026170424185693264
# Epoch 655/1600 Done, Total Loss: 0.025939704850316048
# Epoch 656/1600 Done, Total Loss: 0.025780614465475082
# Epoch 657/1600 Done, Total Loss: 0.025589735247194767
# Epoch 658/1600 Done, Total Loss: 0.0253886254504323
# Epoch 659/1600 Done, Total Loss: 0.025194799061864614
# Epoch 660/1600 Done, Total Loss: 0.024979107081890106
# Epoch 661/1600 Done, Total Loss: 0.024817105382680893
# Epoch 662/1600 Done, Total Loss: 0.02459643967449665
# Epoch 663/1600 Done, Total Loss: 0.02444050833582878
# Epoch 664/1600 Done, Total Loss: 0.024272299371659756
# Epoch 665/1600 Done, Total Loss: 0.024123867973685265
# Epoch 666/1600 Done, Total Loss: 0.02387929428368807
# Epoch 667/1600 Done, Total Loss: 0.02368083130568266
# Epoch 668/1600 Done, Total Loss: 0.023567636497318745
# Epoch 669/1600 Done, Total Loss: 0.02338238013908267
# Epoch 670/1600 Done, Total Loss: 0.023206629790365696
# Epoch 671/1600 Done, Total Loss: 0.023060842417180538
# Epoch 672/1600 Done, Total Loss: 0.02282138168811798
# Epoch 673/1600 Done, Total Loss: 0.022689812816679478
# Epoch 674/1600 Done, Total Loss: 0.0225461283698678
# Epoch 675/1600 Done, Total Loss: 0.02238487359136343
# Epoch 676/1600 Done, Total Loss: 0.02220666967332363
# Epoch 677/1600 Done, Total Loss: 0.022115853615105152
# Epoch 678/1600 Done, Total Loss: 0.021880540996789932
# Epoch 679/1600 Done, Total Loss: 0.021745486184954643
# Epoch 680/1600 Done, Total Loss: 0.021727386862039566
# Epoch 681/1600 Done, Total Loss: 0.021426681894809008
# Epoch 682/1600 Done, Total Loss: 0.02128940261900425
# Epoch 683/1600 Done, Total Loss: 0.021177916787564754
# Epoch 684/1600 Done, Total Loss: 0.020999756641685963
# Epoch 685/1600 Done, Total Loss: 0.020868267863988876
# Epoch 686/1600 Done, Total Loss: 0.020695621613413095
# Epoch 687/1600 Done, Total Loss: 0.020544755272567272
# Epoch 688/1600 Done, Total Loss: 0.020462035201489925
# Epoch 689/1600 Done, Total Loss: 0.020303694531321526
# Epoch 690/1600 Done, Total Loss: 0.020140505395829678
# Epoch 691/1600 Done, Total Loss: 0.019970832392573357
# Epoch 692/1600 Done, Total Loss: 0.019818618893623352
# Epoch 693/1600 Done, Total Loss: 0.01968525629490614
# Epoch 694/1600 Done, Total Loss: 0.019633160904049873
# Epoch 695/1600 Done, Total Loss: 0.01949324319139123
# Epoch 696/1600 Done, Total Loss: 0.019336257129907608
# Epoch 697/1600 Done, Total Loss: 0.019191455328837037
# Epoch 698/1600 Done, Total Loss: 0.01912435842677951
# Epoch 699/1600 Done, Total Loss: 0.019052298739552498
# Epoch 700/1600 Done, Total Loss: 0.018814025446772575
# Epoch 701/1600 Done, Total Loss: 0.01866785204038024
# Epoch 702/1600 Done, Total Loss: 0.018606418278068304
# Epoch 703/1600 Done, Total Loss: 0.01842225296422839
# Epoch 704/1600 Done, Total Loss: 0.0183849660679698
# Epoch 705/1600 Done, Total Loss: 0.018256927374750376
# Epoch 706/1600 Done, Total Loss: 0.018116865307092667
# Epoch 707/1600 Done, Total Loss: 0.017969305394217372
# Epoch 708/1600 Done, Total Loss: 0.01783110247924924
# Epoch 709/1600 Done, Total Loss: 0.017881850246340036
# Epoch 710/1600 Done, Total Loss: 0.017671433044597507
# Epoch 711/1600 Done, Total Loss: 0.017539269756525755
# Epoch 712/1600 Done, Total Loss: 0.01742162276059389
# Epoch 713/1600 Done, Total Loss: 0.01734616793692112
# Epoch 714/1600 Done, Total Loss: 0.01725820521824062
# Epoch 715/1600 Done, Total Loss: 0.017048251582309604
# Epoch 716/1600 Done, Total Loss: 0.017055019736289978
# Epoch 717/1600 Done, Total Loss: 0.016899563372135162
# Epoch 718/1600 Done, Total Loss: 0.016767304856330156
# Epoch 719/1600 Done, Total Loss: 0.016659447457641363
# Epoch 720/1600 Done, Total Loss: 0.01657673600129783
# Epoch 721/1600 Done, Total Loss: 0.016443426720798016
# Epoch 722/1600 Done, Total Loss: 0.016421154141426086
# Epoch 723/1600 Done, Total Loss: 0.016251669265329838
# Epoch 724/1600 Done, Total Loss: 0.016195466741919518
# Epoch 725/1600 Done, Total Loss: 0.01614668359979987
# Epoch 726/1600 Done, Total Loss: 0.01599126635119319
# Epoch 727/1600 Done, Total Loss: 0.016022329684346914
# Epoch 728/1600 Done, Total Loss: 0.01582316029816866
# Epoch 729/1600 Done, Total Loss: 0.015744908712804317
# Epoch 730/1600 Done, Total Loss: 0.015673188026994467
# Epoch 731/1600 Done, Total Loss: 0.015539272455498576
# Epoch 732/1600 Done, Total Loss: 0.015438158065080643
# Epoch 733/1600 Done, Total Loss: 0.01544012688100338
# Epoch 734/1600 Done, Total Loss: 0.015291029354557395
# Epoch 735/1600 Done, Total Loss: 0.015181989874690771
# Epoch 736/1600 Done, Total Loss: 0.015119864139705896
# Epoch 737/1600 Done, Total Loss: 0.015081624034792185
# Epoch 738/1600 Done, Total Loss: 0.0149321174249053
# Epoch 739/1600 Done, Total Loss: 0.014899516478180885
# Epoch 740/1600 Done, Total Loss: 0.0149231543764472
# Epoch 741/1600 Done, Total Loss: 0.014761619735509157
# Epoch 742/1600 Done, Total Loss: 0.014696392230689526
# Epoch 743/1600 Done, Total Loss: 0.014605487696826458
# Epoch 744/1600 Done, Total Loss: 0.0144711434841156
# Epoch 745/1600 Done, Total Loss: 0.014404907589778304
# Epoch 746/1600 Done, Total Loss: 0.014337556436657906
# Epoch 747/1600 Done, Total Loss: 0.014279256807640195
# Epoch 748/1600 Done, Total Loss: 0.014169694390147924
# Epoch 749/1600 Done, Total Loss: 0.014125577174127102
# Epoch 750/1600 Done, Total Loss: 0.014039518777281046
# Epoch 751/1600 Done, Total Loss: 0.013999161310493946
# Epoch 752/1600 Done, Total Loss: 0.013943477533757687
# Epoch 753/1600 Done, Total Loss: 0.013906427193433046
# Epoch 754/1600 Done, Total Loss: 0.013781977351754904
# Epoch 755/1600 Done, Total Loss: 0.013709442224353552
# Epoch 756/1600 Done, Total Loss: 0.013638732954859734
# Epoch 757/1600 Done, Total Loss: 0.013616804499179125
# Epoch 758/1600 Done, Total Loss: 0.013494741404429078
# Epoch 759/1600 Done, Total Loss: 0.013494477607309818
# Epoch 760/1600 Done, Total Loss: 0.013452468905597925
# Epoch 761/1600 Done, Total Loss: 0.013341915793716908
# Epoch 762/1600 Done, Total Loss: 0.01326512498781085
# Epoch 763/1600 Done, Total Loss: 0.013250202406197786
# Epoch 764/1600 Done, Total Loss: 0.013149720150977373
# Epoch 765/1600 Done, Total Loss: 0.013089045882225037
# Epoch 766/1600 Done, Total Loss: 0.013026227708905935
# Epoch 767/1600 Done, Total Loss: 0.012948565650731325
# Epoch 768/1600 Done, Total Loss: 0.01291630882769823
# Epoch 769/1600 Done, Total Loss: 0.012850741855800152
# Epoch 770/1600 Done, Total Loss: 0.012826865538954735
# Epoch 771/1600 Done, Total Loss: 0.01282557612285018
# Epoch 772/1600 Done, Total Loss: 0.012692810967564583
# Epoch 773/1600 Done, Total Loss: 0.012612872524186969
# Epoch 774/1600 Done, Total Loss: 0.012563496828079224
# Epoch 775/1600 Done, Total Loss: 0.012529370374977589
# Epoch 776/1600 Done, Total Loss: 0.01250901073217392
# Epoch 777/1600 Done, Total Loss: 0.01243378478102386
# Epoch 778/1600 Done, Total Loss: 0.012348814634606242
# Epoch 779/1600 Done, Total Loss: 0.01229738350957632
# Epoch 780/1600 Done, Total Loss: 0.012262575328350067
# Epoch 781/1600 Done, Total Loss: 0.012273023370653391
# Epoch 782/1600 Done, Total Loss: 0.012242674361914396
# Epoch 783/1600 Done, Total Loss: 0.012112135998904705
# Epoch 784/1600 Done, Total Loss: 0.012072384124621749
# Epoch 785/1600 Done, Total Loss: 0.012042518006637692
# Epoch 786/1600 Done, Total Loss: 0.012031727470457554
# Epoch 787/1600 Done, Total Loss: 0.011957356240600348
# Epoch 788/1600 Done, Total Loss: 0.011874440591782331
# Epoch 789/1600 Done, Total Loss: 0.011832691030576825
# Epoch 790/1600 Done, Total Loss: 0.01178114046342671
# Epoch 791/1600 Done, Total Loss: 0.011739216512069106
# Epoch 792/1600 Done, Total Loss: 0.011764157097786665
# Epoch 793/1600 Done, Total Loss: 0.011687006102874875
# Epoch 794/1600 Done, Total Loss: 0.011631818721070886
# Epoch 795/1600 Done, Total Loss: 0.011570942588150501
# Epoch 796/1600 Done, Total Loss: 0.011561294086277485
# Epoch 797/1600 Done, Total Loss: 0.01151747046969831
# Epoch 798/1600 Done, Total Loss: 0.011433379957452416
# Epoch 799/1600 Done, Total Loss: 0.011451923754066229
# Epoch 800/1600 Done, Total Loss: 0.011382894590497017
# Epoch 801/1600 Done, Total Loss: 0.011309872381389141
# Epoch 802/1600 Done, Total Loss: 0.011345876147970557
# Epoch 803/1600 Done, Total Loss: 0.01127284998074174
# Epoch 804/1600 Done, Total Loss: 0.011281956918537617
# Epoch 805/1600 Done, Total Loss: 0.011205493472516537
# Epoch 806/1600 Done, Total Loss: 0.011151417624205351
# Epoch 807/1600 Done, Total Loss: 0.011135440319776535
# Epoch 808/1600 Done, Total Loss: 0.011055639013648033
# Epoch 809/1600 Done, Total Loss: 0.011103060794994235
# Epoch 810/1600 Done, Total Loss: 0.011087165214121342
# Epoch 811/1600 Done, Total Loss: 0.01099686324596405
# Epoch 812/1600 Done, Total Loss: 0.010908596683293581
# Epoch 813/1600 Done, Total Loss: 0.010899731889367104
# Epoch 814/1600 Done, Total Loss: 0.010888287564739585
# Epoch 815/1600 Done, Total Loss: 0.010826971847563982
# Epoch 816/1600 Done, Total Loss: 0.010809859726577997
# Epoch 817/1600 Done, Total Loss: 0.010765878716483712
# Epoch 818/1600 Done, Total Loss: 0.010703597450628877
# Epoch 819/1600 Done, Total Loss: 0.010709245223551989
# Epoch 820/1600 Done, Total Loss: 0.010718037839978933
# Epoch 821/1600 Done, Total Loss: 0.010634662583470345
# Epoch 822/1600 Done, Total Loss: 0.010595626197755337
# Epoch 823/1600 Done, Total Loss: 0.0105516801122576
# Epoch 824/1600 Done, Total Loss: 0.010527719743549824
# Epoch 825/1600 Done, Total Loss: 0.01049750647507608
# Epoch 826/1600 Done, Total Loss: 0.01044533820822835
# Epoch 827/1600 Done, Total Loss: 0.01046397304162383
# Epoch 828/1600 Done, Total Loss: 0.010382386855781078
# Epoch 829/1600 Done, Total Loss: 0.010409878566861153
# Epoch 830/1600 Done, Total Loss: 0.010330042336136103
# Epoch 831/1600 Done, Total Loss: 0.010324168484658003
# Epoch 832/1600 Done, Total Loss: 0.01031238166615367
# Epoch 833/1600 Done, Total Loss: 0.010235154302790761
# Epoch 834/1600 Done, Total Loss: 0.010222835466265678
# Epoch 835/1600 Done, Total Loss: 0.01018847175873816
# Epoch 836/1600 Done, Total Loss: 0.01015010429546237
# Epoch 837/1600 Done, Total Loss: 0.010171941248700023
# Epoch 838/1600 Done, Total Loss: 0.010133356554433703
# Epoch 839/1600 Done, Total Loss: 0.010081810876727104
# Epoch 840/1600 Done, Total Loss: 0.010084823705255985
# Epoch 841/1600 Done, Total Loss: 0.010042556328698993
# Epoch 842/1600 Done, Total Loss: 0.010013910941779613
# Epoch 843/1600 Done, Total Loss: 0.010017259512096643
# Epoch 844/1600 Done, Total Loss: 0.00993406306952238
# Epoch 845/1600 Done, Total Loss: 0.009928908897563815
# Epoch 846/1600 Done, Total Loss: 0.009921834105625749
# Epoch 847/1600 Done, Total Loss: 0.009878010489046574
# Epoch 848/1600 Done, Total Loss: 0.009877954609692097
# Epoch 849/1600 Done, Total Loss: 0.00984437856823206
# Epoch 850/1600 Done, Total Loss: 0.009849139489233494
# Epoch 851/1600 Done, Total Loss: 0.009782104403711855
# Epoch 852/1600 Done, Total Loss: 0.009825449669733644
# Epoch 853/1600 Done, Total Loss: 0.009756605373695493
# Epoch 854/1600 Done, Total Loss: 0.009793855715543032
# Epoch 855/1600 Done, Total Loss: 0.009704263880848885
# Epoch 856/1600 Done, Total Loss: 0.00971326557919383
# Epoch 857/1600 Done, Total Loss: 0.009662015363574028
# Epoch 858/1600 Done, Total Loss: 0.009625414153560996
# Epoch 859/1600 Done, Total Loss: 0.009630866814404726
# Epoch 860/1600 Done, Total Loss: 0.009583225240930915
# Epoch 861/1600 Done, Total Loss: 0.009547876892611384
# Epoch 862/1600 Done, Total Loss: 0.009520430117845535
# Epoch 863/1600 Done, Total Loss: 0.009540074039250612
# Epoch 864/1600 Done, Total Loss: 0.00948911253362894
# Epoch 865/1600 Done, Total Loss: 0.009490300435572863
# Epoch 866/1600 Done, Total Loss: 0.009452439844608307
# Epoch 867/1600 Done, Total Loss: 0.009473971091210842
# Epoch 868/1600 Done, Total Loss: 0.009419785114005208
# Epoch 869/1600 Done, Total Loss: 0.009394598193466663
# Epoch 870/1600 Done, Total Loss: 0.009388033300638199
# Epoch 871/1600 Done, Total Loss: 0.009339262964203954
# Epoch 872/1600 Done, Total Loss: 0.00933148106560111
# Epoch 873/1600 Done, Total Loss: 0.009317119605839252
# Epoch 874/1600 Done, Total Loss: 0.009312669280916452
# Epoch 875/1600 Done, Total Loss: 0.009291068650782108
# Epoch 876/1600 Done, Total Loss: 0.009270301554352045
# Epoch 877/1600 Done, Total Loss: 0.009291770868003368
# Epoch 878/1600 Done, Total Loss: 0.009198878426104784
# Epoch 879/1600 Done, Total Loss: 0.009186712792143226
# Epoch 880/1600 Done, Total Loss: 0.009200432104989886
# Epoch 881/1600 Done, Total Loss: 0.009194809710606933
# Epoch 882/1600 Done, Total Loss: 0.00913064880296588
# Epoch 883/1600 Done, Total Loss: 0.009110062383115292
# Epoch 884/1600 Done, Total Loss: 0.009183264337480068
# Epoch 885/1600 Done, Total Loss: 0.009107703808695078
# Epoch 886/1600 Done, Total Loss: 0.0091346874833107
# Epoch 887/1600 Done, Total Loss: 0.009038498625159264
# Epoch 888/1600 Done, Total Loss: 0.009033418027684093
# Epoch 889/1600 Done, Total Loss: 0.009023956023156643
# Epoch 890/1600 Done, Total Loss: 0.009013037197291851
# Epoch 891/1600 Done, Total Loss: 0.009046084014698863
# Epoch 892/1600 Done, Total Loss: 0.009025875013321638
# Epoch 893/1600 Done, Total Loss: 0.008967802161350846
# Epoch 894/1600 Done, Total Loss: 0.008972276467829943
# Epoch 895/1600 Done, Total Loss: 0.008910818258300424
# ...
# Epoch 1329/1600 Done, Total Loss: 0.006001497386023402
# Epoch 1330/1600 Done, Total Loss: 0.005977649241685867
# Epoch 1331/1600 Done, Total Loss: 0.006005717907100916
# Epoch 1332/1600 Done, Total Loss: 0.006079835235141218
# Epoch 1333/1600 Done, Total Loss: 0.005998893175274134
# Epoch 1334/1600 Done, Total Loss: 0.005989446071907878
# Epoch 1335/1600 Done, Total Loss: 0.005953777581453323
# Epoch 1336/1600 Done, Total Loss: 0.00595992140006274
# Epoch 1337/1600 Done, Total Loss: 0.005943417316302657
# Epoch 1338/1600 Done, Total Loss: 0.005946768680587411
# Epoch 1339/1600 Done, Total Loss: 0.005955420318059623
# Epoch 1340/1600 Done, Total Loss: 0.006061892490833998
# Epoch 1341/1600 Done, Total Loss: 0.005964199197478592
# Epoch 1342/1600 Done, Total Loss: 0.005937871756032109
# Epoch 1343/1600 Done, Total Loss: 0.005995102226734161
# Epoch 1344/1600 Done, Total Loss: 0.006052544340491295
# Epoch 1345/1600 Done, Total Loss: 0.005946850869804621
# Epoch 1346/1600 Done, Total Loss: 0.0059185482095927
# Epoch 1347/1600 Done, Total Loss: 0.0060067197773605585
# Epoch 1348/1600 Done, Total Loss: 0.005925153149291873
# Epoch 1349/1600 Done, Total Loss: 0.005949981277808547
# Epoch 1350/1600 Done, Total Loss: 0.005916761350817978
# Epoch 1351/1600 Done, Total Loss: 0.0058995254803448915
# Epoch 1352/1600 Done, Total Loss: 0.006002184934914112
# Epoch 1353/1600 Done, Total Loss: 0.005974797066301107
# Epoch 1354/1600 Done, Total Loss: 0.005945061566308141
# Epoch 1355/1600 Done, Total Loss: 0.005905896192416549
# Epoch 1356/1600 Done, Total Loss: 0.005897995783016086
# Epoch 1357/1600 Done, Total Loss: 0.005894843488931656
# Epoch 1358/1600 Done, Total Loss: 0.005891404813155532
# Epoch 1359/1600 Done, Total Loss: 0.005885106045752764
# Epoch 1360/1600 Done, Total Loss: 0.005863687954843044
# Epoch 1361/1600 Done, Total Loss: 0.005892268382012844
# Epoch 1362/1600 Done, Total Loss: 0.005945018958300352
# Epoch 1363/1600 Done, Total Loss: 0.005847862455993891
# Epoch 1364/1600 Done, Total Loss: 0.005879529053345323
# Epoch 1365/1600 Done, Total Loss: 0.005842382088303566
# Epoch 1366/1600 Done, Total Loss: 0.005835709045641124
# Epoch 1367/1600 Done, Total Loss: 0.005858209216967225
# Epoch 1368/1600 Done, Total Loss: 0.0059041285421699286
# Epoch 1369/1600 Done, Total Loss: 0.005874459398910403
# Epoch 1370/1600 Done, Total Loss: 0.005839142249897122
# Epoch 1371/1600 Done, Total Loss: 0.0058535507414489985
# Epoch 1372/1600 Done, Total Loss: 0.005825474101584405
# Epoch 1373/1600 Done, Total Loss: 0.005882481578737497
# Epoch 1374/1600 Done, Total Loss: 0.005829020286910236
# Epoch 1375/1600 Done, Total Loss: 0.005889412364922464
# Epoch 1376/1600 Done, Total Loss: 0.0058019880671054125
# Epoch 1377/1600 Done, Total Loss: 0.0058322083204984665
# Epoch 1378/1600 Done, Total Loss: 0.00579665950499475
# Epoch 1379/1600 Done, Total Loss: 0.005797927733510733
# Epoch 1380/1600 Done, Total Loss: 0.0057959784753620625
# Epoch 1381/1600 Done, Total Loss: 0.005804289132356644
# Epoch 1382/1600 Done, Total Loss: 0.0057937102392315865
# Epoch 1383/1600 Done, Total Loss: 0.005784003878943622
# Epoch 1384/1600 Done, Total Loss: 0.005778533639386296
# Epoch 1385/1600 Done, Total Loss: 0.005826202454045415
# Epoch 1386/1600 Done, Total Loss: 0.005797820398584008
# Epoch 1387/1600 Done, Total Loss: 0.0058331408072263
# Epoch 1388/1600 Done, Total Loss: 0.005789557471871376
# Epoch 1389/1600 Done, Total Loss: 0.005745191825553775
# Epoch 1390/1600 Done, Total Loss: 0.005849406123161316
# Epoch 1391/1600 Done, Total Loss: 0.005763401626609266
# Epoch 1392/1600 Done, Total Loss: 0.0057624210603535175
# Epoch 1393/1600 Done, Total Loss: 0.005770855583250523
# Epoch 1394/1600 Done, Total Loss: 0.005838045850396156
# Epoch 1395/1600 Done, Total Loss: 0.005735985701903701
# Epoch 1396/1600 Done, Total Loss: 0.005785752786323428
# Epoch 1397/1600 Done, Total Loss: 0.005734405014663935
# Epoch 1398/1600 Done, Total Loss: 0.005731521639972925
# Epoch 1399/1600 Done, Total Loss: 0.00571251311339438
# Epoch 1400/1600 Done, Total Loss: 0.005733874160796404
# Epoch 1401/1600 Done, Total Loss: 0.005706049967557192
# Epoch 1402/1600 Done, Total Loss: 0.005785529618151486
# Epoch 1403/1600 Done, Total Loss: 0.0057175299152731895
# Epoch 1404/1600 Done, Total Loss: 0.005732473451644182
# Epoch 1405/1600 Done, Total Loss: 0.005799978971481323
# Epoch 1406/1600 Done, Total Loss: 0.005709002492949367
# Epoch 1407/1600 Done, Total Loss: 0.005683742230758071
# Epoch 1408/1600 Done, Total Loss: 0.005696966778486967
# Epoch 1409/1600 Done, Total Loss: 0.005704771960154176
# Epoch 1410/1600 Done, Total Loss: 0.0058042812161147594
# Epoch 1411/1600 Done, Total Loss: 0.005735239596106112
# Epoch 1412/1600 Done, Total Loss: 0.0057096658274531364
# Epoch 1413/1600 Done, Total Loss: 0.005718080792576075
# Epoch 1414/1600 Done, Total Loss: 0.005722257075831294
# Epoch 1415/1600 Done, Total Loss: 0.005676683969795704
# Epoch 1416/1600 Done, Total Loss: 0.005653751082718372
# Epoch 1417/1600 Done, Total Loss: 0.005772651871666312
# Epoch 1418/1600 Done, Total Loss: 0.005756257800385356
# Epoch 1419/1600 Done, Total Loss: 0.005732826190069318
# Epoch 1420/1600 Done, Total Loss: 0.005653403466567397
# Epoch 1421/1600 Done, Total Loss: 0.005668062251061201
# Epoch 1422/1600 Done, Total Loss: 0.00563980988226831
# Epoch 1423/1600 Done, Total Loss: 0.005716267973184586
# Epoch 1424/1600 Done, Total Loss: 0.00562663609161973
# Epoch 1425/1600 Done, Total Loss: 0.005660949042066932
# Epoch 1426/1600 Done, Total Loss: 0.005647194106131792
# Epoch 1427/1600 Done, Total Loss: 0.005631695268675685
# Epoch 1428/1600 Done, Total Loss: 0.005691333906725049
# Epoch 1429/1600 Done, Total Loss: 0.0057155657559633255
# Epoch 1430/1600 Done, Total Loss: 0.005632353946566582
# Epoch 1431/1600 Done, Total Loss: 0.005611958215013146
# Epoch 1432/1600 Done, Total Loss: 0.00563280307687819
# Epoch 1433/1600 Done, Total Loss: 0.005607681930996478
# Epoch 1434/1600 Done, Total Loss: 0.005607526516541839
# Epoch 1435/1600 Done, Total Loss: 0.00566883001010865
# Epoch 1436/1600 Done, Total Loss: 0.005628351587802172
# Epoch 1437/1600 Done, Total Loss: 0.005634573521092534
# Epoch 1438/1600 Done, Total Loss: 0.005615283967927098
# Epoch 1439/1600 Done, Total Loss: 0.005608889274299145
# Epoch 1440/1600 Done, Total Loss: 0.005582473706454039
# Epoch 1441/1600 Done, Total Loss: 0.0056200496619567275
# Epoch 1442/1600 Done, Total Loss: 0.005662749521434307
# Epoch 1443/1600 Done, Total Loss: 0.005595883587375283
# Epoch 1444/1600 Done, Total Loss: 0.005576868774369359
# Epoch 1445/1600 Done, Total Loss: 0.005621045827865601
# Epoch 1446/1600 Done, Total Loss: 0.005617487942799926
# Epoch 1447/1600 Done, Total Loss: 0.0055880623403936625
# Epoch 1448/1600 Done, Total Loss: 0.005550340982154012
# Epoch 1449/1600 Done, Total Loss: 0.0057233721017837524
# Epoch 1450/1600 Done, Total Loss: 0.005566679406911135
# Epoch 1451/1600 Done, Total Loss: 0.00562686356715858
# Epoch 1452/1600 Done, Total Loss: 0.005548906279727817
# Epoch 1453/1600 Done, Total Loss: 0.005610408377833664
# Epoch 1454/1600 Done, Total Loss: 0.005535776959732175
# Epoch 1455/1600 Done, Total Loss: 0.005546056665480137
# Epoch 1456/1600 Done, Total Loss: 0.0055414431262761354
# Epoch 1457/1600 Done, Total Loss: 0.005573318572714925
# Epoch 1458/1600 Done, Total Loss: 0.005568187916651368
# Epoch 1459/1600 Done, Total Loss: 0.005540943704545498
# Epoch 1460/1600 Done, Total Loss: 0.005528992973268032
# Epoch 1461/1600 Done, Total Loss: 0.00556826195679605
# Epoch 1462/1600 Done, Total Loss: 0.0055032523814588785
# Epoch 1463/1600 Done, Total Loss: 0.005497808684594929
# Epoch 1464/1600 Done, Total Loss: 0.005514036864042282
# Epoch 1465/1600 Done, Total Loss: 0.0055578944738954306
# Epoch 1466/1600 Done, Total Loss: 0.005615923088043928
# Epoch 1467/1600 Done, Total Loss: 0.0055168624967336655
# Epoch 1468/1600 Done, Total Loss: 0.00549416255671531
# Epoch 1469/1600 Done, Total Loss: 0.005487346556037664
# Epoch 1470/1600 Done, Total Loss: 0.005482061067596078
# Epoch 1471/1600 Done, Total Loss: 0.005472729331813753
# Epoch 1472/1600 Done, Total Loss: 0.005473957862704992
# Epoch 1473/1600 Done, Total Loss: 0.005522372201085091
# Epoch 1474/1600 Done, Total Loss: 0.005493000731803477
# Epoch 1475/1600 Done, Total Loss: 0.005510442424565554
# Epoch 1476/1600 Done, Total Loss: 0.005473093595355749
# Epoch 1477/1600 Done, Total Loss: 0.005467634880915284
# Epoch 1478/1600 Done, Total Loss: 0.005474467820022255
# Epoch 1479/1600 Done, Total Loss: 0.005512376548722386
# Epoch 1480/1600 Done, Total Loss: 0.005466239992529154
# Epoch 1481/1600 Done, Total Loss: 0.00554446829482913
# Epoch 1482/1600 Done, Total Loss: 0.00552594824694097
# Epoch 1483/1600 Done, Total Loss: 0.005463652894832194
# Epoch 1484/1600 Done, Total Loss: 0.005503950407728553
# Epoch 1485/1600 Done, Total Loss: 0.005601034266874194
# Epoch 1486/1600 Done, Total Loss: 0.0055749567691236734
# Epoch 1487/1600 Done, Total Loss: 0.005427211872301996
# Epoch 1488/1600 Done, Total Loss: 0.005447429255582392
# Epoch 1489/1600 Done, Total Loss: 0.005420443834736943
# Epoch 1490/1600 Done, Total Loss: 0.005427347728982568
# Epoch 1491/1600 Done, Total Loss: 0.005465830909088254
# Epoch 1492/1600 Done, Total Loss: 0.005484772613272071
# Epoch 1493/1600 Done, Total Loss: 0.005553254624828696
# Epoch 1494/1600 Done, Total Loss: 0.005472134333103895
# Epoch 1495/1600 Done, Total Loss: 0.005459390114992857
# Epoch 1496/1600 Done, Total Loss: 0.005418071756139398
# Epoch 1497/1600 Done, Total Loss: 0.005413954146206379
# Epoch 1498/1600 Done, Total Loss: 0.005420702742412686
# Epoch 1499/1600 Done, Total Loss: 0.005464211921207607
# Epoch 1500/1600 Done, Total Loss: 0.005425284616649151
# Epoch 1501/1600 Done, Total Loss: 0.005391527432948351
# Epoch 1502/1600 Done, Total Loss: 0.005533873452804983
# Epoch 1503/1600 Done, Total Loss: 0.0053876962047070265
# Epoch 1504/1600 Done, Total Loss: 0.0053970105946063995
# Epoch 1505/1600 Done, Total Loss: 0.005474457750096917
# Epoch 1506/1600 Done, Total Loss: 0.005399457411840558
# Epoch 1507/1600 Done, Total Loss: 0.0054010068997740746
# Epoch 1508/1600 Done, Total Loss: 0.005369790131226182
# Epoch 1509/1600 Done, Total Loss: 0.005426806630566716
# Epoch 1510/1600 Done, Total Loss: 0.005380742019042373
# Epoch 1511/1600 Done, Total Loss: 0.005370472266804427
# Epoch 1512/1600 Done, Total Loss: 0.005405077477917075
# Epoch 1513/1600 Done, Total Loss: 0.005361946066841483
# Epoch 1514/1600 Done, Total Loss: 0.005353565094992518
# Epoch 1515/1600 Done, Total Loss: 0.005388939520344138
# Epoch 1516/1600 Done, Total Loss: 0.005379919428378344
# Epoch 1517/1600 Done, Total Loss: 0.005389742087572813
# Epoch 1518/1600 Done, Total Loss: 0.005345110781490803
# Epoch 1519/1600 Done, Total Loss: 0.00541351642459631
# Epoch 1520/1600 Done, Total Loss: 0.00539382454007864
# Epoch 1521/1600 Done, Total Loss: 0.005353276152163744
# Epoch 1522/1600 Done, Total Loss: 0.005344297853298485
# Epoch 1523/1600 Done, Total Loss: 0.005354035645723343
# Epoch 1524/1600 Done, Total Loss: 0.005349575541913509
# Epoch 1525/1600 Done, Total Loss: 0.005370617611333728
# Epoch 1526/1600 Done, Total Loss: 0.005380992544814944
# Epoch 1527/1600 Done, Total Loss: 0.005335413618013263
# Epoch 1528/1600 Done, Total Loss: 0.005329053848981857
# Epoch 1529/1600 Done, Total Loss: 0.0053830749820917845
# Epoch 1530/1600 Done, Total Loss: 0.005332631175406277
# Epoch 1531/1600 Done, Total Loss: 0.005338210379704833
# Epoch 1532/1600 Done, Total Loss: 0.005355005851015449
# Epoch 1533/1600 Done, Total Loss: 0.0053335262928158045
# Epoch 1534/1600 Done, Total Loss: 0.0053221236448735
# Epoch 1535/1600 Done, Total Loss: 0.0053431252017617226
# Epoch 1536/1600 Done, Total Loss: 0.005416012601926923
# Epoch 1537/1600 Done, Total Loss: 0.005334580084308982
# Epoch 1538/1600 Done, Total Loss: 0.00537750287912786
# Epoch 1539/1600 Done, Total Loss: 0.005350959952920675
# Epoch 1540/1600 Done, Total Loss: 0.005469308467581868
# Epoch 1541/1600 Done, Total Loss: 0.005378690082579851
# Epoch 1542/1600 Done, Total Loss: 0.0054024094715714455
# Epoch 1543/1600 Done, Total Loss: 0.005322843324393034
# Epoch 1544/1600 Done, Total Loss: 0.005387385142967105
# Epoch 1545/1600 Done, Total Loss: 0.005319701740518212
# Epoch 1546/1600 Done, Total Loss: 0.005373734049499035
# Epoch 1547/1600 Done, Total Loss: 0.005346642341464758
# Epoch 1548/1600 Done, Total Loss: 0.005337122129276395
# Epoch 1549/1600 Done, Total Loss: 0.00530522724147886
# Epoch 1550/1600 Done, Total Loss: 0.005313034984283149
# Epoch 1551/1600 Done, Total Loss: 0.005372842773795128
# Epoch 1552/1600 Done, Total Loss: 0.0053157799411565065
# Epoch 1553/1600 Done, Total Loss: 0.005403741030022502
# Epoch 1554/1600 Done, Total Loss: 0.005351894535124302
# Epoch 1555/1600 Done, Total Loss: 0.005322183365933597
# Epoch 1556/1600 Done, Total Loss: 0.005304079735651612
# Epoch 1557/1600 Done, Total Loss: 0.00534242088906467
# Epoch 1558/1600 Done, Total Loss: 0.005341445794329047
# Epoch 1559/1600 Done, Total Loss: 0.005302352132275701
# Epoch 1560/1600 Done, Total Loss: 0.00533808080945164
# Epoch 1561/1600 Done, Total Loss: 0.005310959881171584
# Epoch 1562/1600 Done, Total Loss: 0.005408944096416235
# Epoch 1563/1600 Done, Total Loss: 0.005437566200271249
# Epoch 1564/1600 Done, Total Loss: 0.005397670669481158
# Epoch 1565/1600 Done, Total Loss: 0.005334688583388925
# Epoch 1566/1600 Done, Total Loss: 0.005352081265300512
# Epoch 1567/1600 Done, Total Loss: 0.0053268123883754015
# Epoch 1568/1600 Done, Total Loss: 0.005379257723689079
# Epoch 1569/1600 Done, Total Loss: 0.005290371598675847
# Epoch 1570/1600 Done, Total Loss: 0.005310584791004658
# Epoch 1571/1600 Done, Total Loss: 0.005307206069119275
# Epoch 1572/1600 Done, Total Loss: 0.005288777407258749
# Epoch 1573/1600 Done, Total Loss: 0.00528295966796577
# Epoch 1574/1600 Done, Total Loss: 0.005282848025672138
# Epoch 1575/1600 Done, Total Loss: 0.005285672144964337
# Epoch 1576/1600 Done, Total Loss: 0.0052887494675815105
# Epoch 1577/1600 Done, Total Loss: 0.005300050834193826
# Epoch 1578/1600 Done, Total Loss: 0.005343104945495725
# Epoch 1579/1600 Done, Total Loss: 0.005403245100751519
# Epoch 1580/1600 Done, Total Loss: 0.005332866450771689
# Epoch 1581/1600 Done, Total Loss: 0.0053404688369482756
# Epoch 1582/1600 Done, Total Loss: 0.005292691057547927
# Epoch 1583/1600 Done, Total Loss: 0.005307517014443874
# Epoch 1584/1600 Done, Total Loss: 0.005337103153578937
# Epoch 1585/1600 Done, Total Loss: 0.005300890421494842
# Epoch 1586/1600 Done, Total Loss: 0.005280053475871682
# Epoch 1587/1600 Done, Total Loss: 0.005276790354400873
# Epoch 1588/1600 Done, Total Loss: 0.005314456066116691
# Epoch 1589/1600 Done, Total Loss: 0.005334116984158754
# Epoch 1590/1600 Done, Total Loss: 0.005362401716411114
# Epoch 1591/1600 Done, Total Loss: 0.00528777576982975
# Epoch 1592/1600 Done, Total Loss: 0.005329021951183677
# Epoch 1593/1600 Done, Total Loss: 0.0052730420138686895
# Epoch 1594/1600 Done, Total Loss: 0.005279235541820526
# Epoch 1595/1600 Done, Total Loss: 0.005337712354958057
# Epoch 1596/1600 Done, Total Loss: 0.005404279101639986
# Epoch 1597/1600 Done, Total Loss: 0.005296218208968639
# Epoch 1598/1600 Done, Total Loss: 0.005297482013702393
# Epoch 1599/1600 Done, Total Loss: 0.005295623966958374
# MLNet(
#   (fcnn1): Sequential(
#     (0): Linear(in_features=1, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=1, bias=True)
#   )
# )
# layer1, weights:  Parameter containing:
# tensor([[ 0.1367],
#         [-0.6499],
#         [-0.5875],
#         [-0.9921],
#         [ 0.8121],
#         [ 0.5064],
#         [ 0.9574],
#         [-1.0497],
#         [-0.4616],
#         [-0.4534],
#         [ 0.7945],
#         [ 0.1453],
#         [ 0.6901],
#         [ 0.5021],
#         [ 0.5487],
#         [ 0.5811]], requires_grad=True)
# layer1, bias:  Parameter containing:
# tensor([ 0.4806, -1.0818, -1.0259,  1.3088, -0.9680,  1.0100,  0.1682, -1.0702,
#         -0.3253, -0.8320,  0.8329, -0.9016, -0.9026, -0.4638,  1.2158, -1.3407],
#        requires_grad=True)
# layer3, weights:  Parameter containing:
# tensor([[-0.1148,  0.5072,  0.4861, -0.5753, -0.4429,  0.3039, -0.0987,  0.4158,
#           0.1925,  0.4447,  0.2292, -0.1683, -0.4744, -0.1588,  0.1082, -0.3409]],
#        requires_grad=True)
# layer3, bias:  Parameter containing:
# tensor([0.2300], requires_grad=True)
