# %%
###############################################Original Code#####################################################
# Import matplotlib for plotting purposes
import matplotlib
matplotlib.rcParams["text.usetex"] = True
import matplotlib.pyplot as plt

# Sometimes, we need Numpy, but wherever possible, we prefer torch.
import numpy as np

# Import PyTorch
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# Float (32 bit) or Double (64 bit) precision? Choose!
torch.set_default_dtype(torch.float32)#64)
torch.set_num_threads(4) # Use _maximally_ 4 CPU cores


#device = torch.device("cpu")
# Choose a device for major calculations (if there is a special GPU card, you usually want that).
# My GPU is not very performant for double precision, so I stay on CPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
device = torch.device(device)

# File path for saving the trained NN later.
# If only providing the file name (like here), the file will be generated in the same folder as the Python script
model_file = "mymodel.torch"

## The following script shows a data-driven training of a Neural Network.
## The data is generated in this script, too, by sampling from a function.
## The variables below are used to control this sampling
samples = 16
sample_min = -5
sample_max = 5
sample_span = sample_max - sample_min

## These parameters are usual hyperparameters of the NN and its training.
batch_size = 8 # How many samples shall be presented to the NN, before running another optimizer step?
hidden_dim = 16 # How many neurons shall there be in the hidden layer(s)?
input_dim = 1 # Input dimension of the NN (i.e. how many neurons are in the input layer?)
output_dim = 1 # Some for output

epochs = 1600 # Number of training iterations to be performed
lr = 0.001 # Which learning rate is passed to the training algorithm?

## Choose a criterion to evaluate the results. Here, we choose Mean Square error.
## The term "loss" means about the same as "remaining error" or "residual".
criterion = nn.MSELoss(reduction="mean")

## Here, we create the training data. In this example, we draw samples within the sampling interval and then pass it to
## e.g. the sin function (choose other functions to experiment with this script)
train_x = (sample_span * torch.rand(samples, 1) + sample_min * torch.ones(samples, 1))
train_y = torch.sin(train_x) ##torch.pow(test_x, 2)
print ("train_x", train_x)
print ("train_y", train_y)

## Here, we create the test data. To show the effect of extrapolation and the detailed behavior of the NN,
## we choose points a bit outside the interval that we used for sampling training data. Also, we very dense points.
test_x = torch.zeros(20*samples, 1)
test_x[:, 0] = torch.linspace(sample_min - 0.5*sample_span, sample_max + 0.5*sample_span, test_x.size()[0])
test_y = torch.sin(test_x) ##torch.pow(test_x, 2)

## We want a DataLoader to handle batching and shuffling of the training data for us.
## The DataLoader needs a TensorDataset, hence we create one from the Training data.
train_data = TensorDataset(train_x, train_y)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, drop_last=False)


## This class creates the actual Neural Network.
class MLNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MLNet, self).__init__()
        self.hidden_dim = hidden_dim

        ## In this case, I decided to pack the layers into a single container of type nn.Sequential
        ## This container is useful for Fully Connected NNs, where the output of each layer is just fed into the following layer.
        self.fcnn1 = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            #nn.Tanh(),
            nn.ReLU(),
            #nn.Linear(hidden_dim, hidden_dim),
            #nn.ReLU(),
            #nn.Linear(hidden_dim, hidden_dim),
            #nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
        ) ## That network here has exactly 1 hidden layer (comment out some lines or write new ones to add more layers)
        ## nn.Linear is in the pictures represented by the arrows and has the weights (and biases) which are the
        ## parameters of the NN.
        ## nn.ReLU and Tanh are examples for activation functions - in the pictures, these are the bubbles / neurons.
        ## Usually, the pattern is interchanging between one linear layer, one activation function, one linear layer, one activation function and so on

    ## It is required to write a function that is executed when calling the NN model.
    ## Usually, it takes the input data and passes it through the layers.
    ## Here, it is sufficient to call the sequential container since this container does exactly this job.
    ## But this function "forward" could also be used to set up more complex NN architectures with more complex data flows
    def forward(self, x):
        out = self.fcnn1(x)
        return out

## This function performs a test run with the NN.
## It takes the NN model and the test data, passes the test inputs through the network and
## compares it with the target values = test outputs = targets
## and based on that calculates the loss value
def evaluate(model, test_x, test_y):
    ## For testing, we don't need the autograd feature/ protocol of all calculation steps
    ## So, save some time and disable grad tracking.
    with torch.no_grad():
        model.eval() ## Set the NN model into evaluation mode
        outputs = [] ## Create empty lists to store the results
        targets = []
        testlosses = []

        out = model(test_x.to(device)) ## Call the model, i.e. perform the actual inference

        ## Move the output quantities to the CPU, detach them from the tensor operation book-keeping and convert them to numpy arrays/ vectors.
        ## This is all necessary for plotting
        outputs.append(out.cpu().detach().numpy())
        targets.append(test_y.cpu().detach().numpy())
        testlosses.append(criterion(out, test_y.to(device)).item())

    ## Now return that in form of a triple of variables
    return outputs, targets, testlosses

## This calls the evaluate function and takes care of the plotting.
def eval_and_plot(model):
        ## matplotlib tries to be similar to the plot functions of matlab  (admittedly, the commands have to begin with "plt.", but the rest
        ## is quite similar.)
        plt.subplot(1, 1, 1)

        ## Call the network on the test data
        net_outputs_test, targets_test, testlosses = evaluate(model, test_x, test_y)
        # Plot the targets first in blue (which means to plot the actual function over the whole test interval)
        plt.plot(test_x, targets_test[0], "-x", color="b", label="Target")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.legend()

        ## Call the network on the training data
        net_outputs_train, targets_train, testlosses = evaluate(model, train_x, train_y)
        ## First, plot the targets in red, i.e. plot the training data set
        plt.plot(train_x, targets_train[0], "^", color="r", label="Target")

        ## Now, plot the output of the NN on the whole test interval in green
        ## This allows us to see how the NN performs for interpolation as well as for extrapolation
        plt.plot(test_x, net_outputs_test[0], "-o", color="g", label="Learned")

        ## All plotting is done, open the plot window
        plt.show()


## That function takes care of the whole training
def train(train_loader, learn_rate, EPOCHS):  # 10):

    # Instantiate the NN
    model = MLNet(input_dim, hidden_dim, output_dim)
    model.to(device) # and move it to the "device" (in case we use a GPU)

    ## Choose an optimizer. Adam is quite robust and thus very popular. Technically, it's based on
    ## gradient descent, but mixes in the gradient of the last time step to improve robustness.
    ## It is given the model parameters, which are the weights and biases of the Linear layers
    ## and the learn_rate.
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)
    print("Starting Training of the model")

    # We want to keep track of the losses averaged over each epoch, to plot them in those famous
    # decreasing graphs
    avg_losses = torch.zeros(EPOCHS)

    ## In the end, epoch is just another word for "training iteration", so we have a simple for loop.
    for epoch in range(EPOCHS):
        model.train() # Set the model into train mode
        avg_loss = 0. # initializations
        counter = 0

        ## DataLoader is iterable so that this for-loop loops over the batches of the training data set
        ## and the DataLoader gives us readily paired combinations of training inputs and targets (which are called x and label, here).
        ## The term "label" is more common in classification, but used for all supervised training tasks
        for x, label in train_loader:
            counter += 1 # We count, how many batches we did within the current epoch
            model.zero_grad() # Important: reset the gradients of the NN before passing the training inputs.
            # Otherwise, we would accumulate the gradient information which might ruin the results
            # or simply run into PyTorch exceptions

            ## Now, we can call the model on the training inputs.
            ## Therefor, we move that data to the device (just in case we use a GPU).
            out = model(x.to(device))
            loss = criterion(out, label.to(device)) # Now, calculate the loss value

            ## Here, the whole magic happens:
            ## PyTorch offers the autograd feature, i.e. calculations on tensors are tracked (there are exceptions, e.g.
            ## this is not possible for in-place operations). This allows to calculate the derivative of each output value
            ## w.r.t. all input values (its "gradient").
            ## In this case, we want to know the derivatives of the loss value w.r.t. all the NN parameters (weights and biases).
            ## Our optimizers are usually based on "Gradient Descent", so we need the gradients...
            loss.backward()
            ## Alright, now let the optimizer do the magic.
            ## We passed the optimizer the NN parameters by reference when we initialized the optimizer.
            ## And the gradient information is stored in the tensors of the parameters, too (not in the loss or so).
            ## That's why the step() function does not require any arguments.
            optimizer.step()

            ## For the plot at the end, save the loss values
            avg_loss += loss.item()

            if counter % 20 == 0:
                print("Epoch {}......Step: {}/{}....... Average Loss for Epoch: {} = {} + {}".format(epoch, counter,
                                                                                                len(train_loader),
                                                                                                avg_loss / counter, loss.item(), 0))
        print("Epoch {}/{} Done, Total Loss: {}".format(epoch, EPOCHS, avg_loss / len(train_loader)))
        ## It's an average loss, so divide by the number of samples/ size of the training data set
        avg_losses[epoch] = avg_loss / len(train_loader)

        ## To understand how the NN learns, all 500 epochs a plot is shown (Close the plot window and wait for the next plot)
        if epoch%500 == 0:
            eval_and_plot(model)

    ## This plots the loss curve
    plt.figure(figsize=(12, 8))
    plt.plot(avg_losses, "x-")
    plt.title("Train loss (MSE, reduction=mean, averaged over epoch)")
    plt.xlabel("Epoch")
    plt.ylabel("loss")
    plt.grid(visible=True, which='both', axis='both')
    plt.show()

    ## Now save the trained model with all its properties to the model_file
    torch.save(model, model_file)

    ## And return the model in case we want to use it for other tasks
    return model


## As the functions written before are just function definitions,
## those functions still have to be called.
## This is done here.
## Train the model
model = train(train_loader, lr, epochs)

## Test that saving the model worked: load it from file
model = torch.load(model_file)
## and evaluate and plot once
eval_and_plot(model)

print(model)
'''
print("layer1, weights: ", model.layer1.weight)
print("layer1, bias: ", model.layer1.bias)
#print(model.layer2.weight)
#print(model.layer2.bias)
print("layer3, weights: ", model.layer3.weight)
print("layer3, bias: ", model.layer3.bias)
'''

print("layer1, weights: ", model.fcnn1[0].weight)
print("layer1, bias: ", model.fcnn1[0].bias)
# Uncomment and adapt these for additional layers if needed
# print("layer2, weights: ", model.fcnn1[2].weight)
# print("layer2, bias: ", model.fcnn1[2].bias)
print("layer3, weights: ", model.fcnn1[-1].weight)
print("layer3, bias: ", model.fcnn1[-1].bias)
# Out:
# Using cpu device
# train_x tensor([[ 0.7438],
#         [-2.6362],
#         [ 2.5047],
#         [-1.7664],
#         [ 1.0452],
#         [ 2.6285],
#         [-2.1804],
#         [ 2.1256],
#         [ 3.1147],
#         [-3.2634],
#         [ 3.5416],
#         [-1.0465],
#         [ 3.6436],
#         [ 4.1925],
#         [ 4.2580],
#         [-0.0818]])
# train_y tensor([[ 0.6771],
#         [-0.4842],
#         [ 0.5947],
#         [-0.9809],
#         [ 0.8650],
#         [ 0.4909],
#         [-0.8199],
#         [ 0.8500],
#         [ 0.0269],
#         [ 0.1215],
#         [-0.3894],
#         [-0.8657],
#         [-0.4812],
#         [-0.8679],
#         [-0.8985],
#         [-0.0817]])
# Starting Training of the model
# Epoch 0/1600 Done, Total Loss: 0.5188000351190567
# Epoch 1/1600 Done, Total Loss: 0.506886750459671
# Epoch 2/1600 Done, Total Loss: 0.49170973896980286
# Epoch 3/1600 Done, Total Loss: 0.4731032997369766
# Epoch 4/1600 Done, Total Loss: 0.46182993054389954
# Epoch 5/1600 Done, Total Loss: 0.44848692417144775
# Epoch 6/1600 Done, Total Loss: 0.4385162889957428
# Epoch 7/1600 Done, Total Loss: 0.42632821202278137
# Epoch 8/1600 Done, Total Loss: 0.41867397725582123
# Epoch 9/1600 Done, Total Loss: 0.40765051543712616
# Epoch 10/1600 Done, Total Loss: 0.4010205715894699
# Epoch 11/1600 Done, Total Loss: 0.39219672977924347
# Epoch 12/1600 Done, Total Loss: 0.38547851890325546
# Epoch 13/1600 Done, Total Loss: 0.380423903465271
# Epoch 14/1600 Done, Total Loss: 0.37275007367134094
# Epoch 15/1600 Done, Total Loss: 0.3708360493183136
# Epoch 16/1600 Done, Total Loss: 0.36422038078308105
# Epoch 17/1600 Done, Total Loss: 0.3604412227869034
# Epoch 18/1600 Done, Total Loss: 0.3575003147125244
# Epoch 19/1600 Done, Total Loss: 0.3528340756893158
# Epoch 20/1600 Done, Total Loss: 0.351986788213253
# Epoch 21/1600 Done, Total Loss: 0.3483560383319855
# Epoch 22/1600 Done, Total Loss: 0.34808821976184845
# Epoch 23/1600 Done, Total Loss: 0.344191737473011
# Epoch 24/1600 Done, Total Loss: 0.3432760462164879
# Epoch 25/1600 Done, Total Loss: 0.34206722676754
# Epoch 26/1600 Done, Total Loss: 0.33952316641807556
# Epoch 27/1600 Done, Total Loss: 0.33869893848896027
# Epoch 28/1600 Done, Total Loss: 0.33743439614772797
# Epoch 29/1600 Done, Total Loss: 0.33559034764766693
# Epoch 30/1600 Done, Total Loss: 0.3351258635520935
# Epoch 31/1600 Done, Total Loss: 0.3341920077800751
# Epoch 32/1600 Done, Total Loss: 0.332584872841835
# Epoch 33/1600 Done, Total Loss: 0.33194634318351746
# Epoch 34/1600 Done, Total Loss: 0.3305419385433197
# Epoch 35/1600 Done, Total Loss: 0.33000020682811737
# Epoch 36/1600 Done, Total Loss: 0.32885250449180603
# Epoch 37/1600 Done, Total Loss: 0.3276609554886818
# Epoch 38/1600 Done, Total Loss: 0.3270671218633652
# Epoch 39/1600 Done, Total Loss: 0.32595790922641754
# Epoch 40/1600 Done, Total Loss: 0.3253813832998276
# Epoch 41/1600 Done, Total Loss: 0.3240624815225601
# Epoch 42/1600 Done, Total Loss: 0.32343845069408417
# Epoch 43/1600 Done, Total Loss: 0.3222068250179291
# Epoch 44/1600 Done, Total Loss: 0.32125314325094223
# Epoch 45/1600 Done, Total Loss: 0.32057902216911316
# Epoch 46/1600 Done, Total Loss: 0.3194771111011505
# Epoch 47/1600 Done, Total Loss: 0.3186325132846832
# Epoch 48/1600 Done, Total Loss: 0.3177982419729233
# Epoch 49/1600 Done, Total Loss: 0.316892147064209
# Epoch 50/1600 Done, Total Loss: 0.3159000799059868
# Epoch 51/1600 Done, Total Loss: 0.31530967354774475
# Epoch 52/1600 Done, Total Loss: 0.31427013874053955
# Epoch 53/1600 Done, Total Loss: 0.3133148103952408
# Epoch 54/1600 Done, Total Loss: 0.31233498454093933
# Epoch 55/1600 Done, Total Loss: 0.3114635497331619
# Epoch 56/1600 Done, Total Loss: 0.31083565205335617
# Epoch 57/1600 Done, Total Loss: 0.30978238582611084
# Epoch 58/1600 Done, Total Loss: 0.3090174198150635
# Epoch 59/1600 Done, Total Loss: 0.30813074111938477
# Epoch 60/1600 Done, Total Loss: 0.30760277807712555
# Epoch 61/1600 Done, Total Loss: 0.3062477260828018
# Epoch 62/1600 Done, Total Loss: 0.3054344058036804
# Epoch 63/1600 Done, Total Loss: 0.30450373888015747
# Epoch 64/1600 Done, Total Loss: 0.30372294783592224
# Epoch 65/1600 Done, Total Loss: 0.3031228259205818
# Epoch 66/1600 Done, Total Loss: 0.3019556254148483
# Epoch 67/1600 Done, Total Loss: 0.3012520968914032
# Epoch 68/1600 Done, Total Loss: 0.30024683475494385
# Epoch 69/1600 Done, Total Loss: 0.29954802989959717
# Epoch 70/1600 Done, Total Loss: 0.29855118691921234
# Epoch 71/1600 Done, Total Loss: 0.29778848588466644
# Epoch 72/1600 Done, Total Loss: 0.29698020219802856
# Epoch 73/1600 Done, Total Loss: 0.29591114819049835
# Epoch 74/1600 Done, Total Loss: 0.29527436196804047
# Epoch 75/1600 Done, Total Loss: 0.29432597756385803
# Epoch 76/1600 Done, Total Loss: 0.29396816343069077
# Epoch 77/1600 Done, Total Loss: 0.2925603985786438
# Epoch 78/1600 Done, Total Loss: 0.29173605144023895
# Epoch 79/1600 Done, Total Loss: 0.2911725640296936
# Epoch 80/1600 Done, Total Loss: 0.2900935858488083
# Epoch 81/1600 Done, Total Loss: 0.2894023731350899
# Epoch 82/1600 Done, Total Loss: 0.28856783360242844
# Epoch 83/1600 Done, Total Loss: 0.287616029381752
# Epoch 84/1600 Done, Total Loss: 0.28667937219142914
# Epoch 85/1600 Done, Total Loss: 0.2860535755753517
# Epoch 86/1600 Done, Total Loss: 0.28507351875305176
# Epoch 87/1600 Done, Total Loss: 0.2842133194208145
# Epoch 88/1600 Done, Total Loss: 0.28345902264118195
# Epoch 89/1600 Done, Total Loss: 0.2825787663459778
# Epoch 90/1600 Done, Total Loss: 0.28177186101675034
# Epoch 91/1600 Done, Total Loss: 0.28089403361082077
# Epoch 92/1600 Done, Total Loss: 0.2799283564090729
# Epoch 93/1600 Done, Total Loss: 0.2792239487171173
# Epoch 94/1600 Done, Total Loss: 0.2785167023539543
# Epoch 95/1600 Done, Total Loss: 0.2778058797121048
# Epoch 96/1600 Done, Total Loss: 0.2769612744450569
# Epoch 97/1600 Done, Total Loss: 0.27594588696956635
# Epoch 98/1600 Done, Total Loss: 0.27503710985183716
# Epoch 99/1600 Done, Total Loss: 0.27439017593860626
# Epoch 100/1600 Done, Total Loss: 0.273781456053257
# Epoch 101/1600 Done, Total Loss: 0.27263736724853516
# Epoch 102/1600 Done, Total Loss: 0.2719944417476654
# Epoch 103/1600 Done, Total Loss: 0.27144261449575424
# Epoch 104/1600 Done, Total Loss: 0.2703758478164673
# Epoch 105/1600 Done, Total Loss: 0.26955991238355637
# Epoch 106/1600 Done, Total Loss: 0.26887480914592743
# Epoch 107/1600 Done, Total Loss: 0.2682826519012451
# Epoch 108/1600 Done, Total Loss: 0.26737697422504425
# Epoch 109/1600 Done, Total Loss: 0.26668543368577957
# Epoch 110/1600 Done, Total Loss: 0.26616063714027405
# Epoch 111/1600 Done, Total Loss: 0.2648300752043724
# Epoch 112/1600 Done, Total Loss: 0.2645009607076645
# Epoch 113/1600 Done, Total Loss: 0.2633209377527237
# Epoch 114/1600 Done, Total Loss: 0.2626143917441368
# Epoch 115/1600 Done, Total Loss: 0.26145801693201065
# Epoch 116/1600 Done, Total Loss: 0.26056912541389465
# Epoch 117/1600 Done, Total Loss: 0.259834423661232
# Epoch 118/1600 Done, Total Loss: 0.25863945484161377
# Epoch 119/1600 Done, Total Loss: 0.2579808086156845
# Epoch 120/1600 Done, Total Loss: 0.25685517489910126
# Epoch 121/1600 Done, Total Loss: 0.2559579014778137
# Epoch 122/1600 Done, Total Loss: 0.2549997568130493
# Epoch 123/1600 Done, Total Loss: 0.2542000710964203
# Epoch 124/1600 Done, Total Loss: 0.25326380133628845
# Epoch 125/1600 Done, Total Loss: 0.2523106336593628
# Epoch 126/1600 Done, Total Loss: 0.2513516768813133
# Epoch 127/1600 Done, Total Loss: 0.25083310157060623
# Epoch 128/1600 Done, Total Loss: 0.2494083046913147
# Epoch 129/1600 Done, Total Loss: 0.24826380610466003
# Epoch 130/1600 Done, Total Loss: 0.24737510830163956
# Epoch 131/1600 Done, Total Loss: 0.24633295834064484
# Epoch 132/1600 Done, Total Loss: 0.24535922706127167
# Epoch 133/1600 Done, Total Loss: 0.24384815245866776
# Epoch 134/1600 Done, Total Loss: 0.24275710433721542
# Epoch 135/1600 Done, Total Loss: 0.241548091173172
# Epoch 136/1600 Done, Total Loss: 0.24029521644115448
# Epoch 137/1600 Done, Total Loss: 0.23844356834888458
# Epoch 138/1600 Done, Total Loss: 0.23707008361816406
# Epoch 139/1600 Done, Total Loss: 0.23562949895858765
# Epoch 140/1600 Done, Total Loss: 0.2340480238199234
# Epoch 141/1600 Done, Total Loss: 0.23263593763113022
# Epoch 142/1600 Done, Total Loss: 0.23122429847717285
# Epoch 143/1600 Done, Total Loss: 0.22994612157344818
# Epoch 144/1600 Done, Total Loss: 0.22807827591896057
# Epoch 145/1600 Done, Total Loss: 0.22666384279727936
# Epoch 146/1600 Done, Total Loss: 0.2255549058318138
# Epoch 147/1600 Done, Total Loss: 0.22360382974147797
# Epoch 148/1600 Done, Total Loss: 0.22232015430927277
# Epoch 149/1600 Done, Total Loss: 0.22097743302583694
# Epoch 150/1600 Done, Total Loss: 0.21946098655462265
# Epoch 151/1600 Done, Total Loss: 0.2179749682545662
# Epoch 152/1600 Done, Total Loss: 0.2166731283068657
# Epoch 153/1600 Done, Total Loss: 0.21554003655910492
# Epoch 154/1600 Done, Total Loss: 0.21443107724189758
# Epoch 155/1600 Done, Total Loss: 0.2133164331316948
# Epoch 156/1600 Done, Total Loss: 0.21220549196004868
# Epoch 157/1600 Done, Total Loss: 0.21152519434690475
# Epoch 158/1600 Done, Total Loss: 0.21033132821321487
# Epoch 159/1600 Done, Total Loss: 0.20923586189746857
# Epoch 160/1600 Done, Total Loss: 0.20810021460056305
# Epoch 161/1600 Done, Total Loss: 0.2070699781179428
# Epoch 162/1600 Done, Total Loss: 0.20651958882808685
# Epoch 163/1600 Done, Total Loss: 0.20553072541952133
# Epoch 164/1600 Done, Total Loss: 0.20496395975351334
# Epoch 165/1600 Done, Total Loss: 0.2041558027267456
# Epoch 166/1600 Done, Total Loss: 0.20340771228075027
# Epoch 167/1600 Done, Total Loss: 0.20263636857271194
# Epoch 168/1600 Done, Total Loss: 0.2021646946668625
# Epoch 169/1600 Done, Total Loss: 0.2014492079615593
# Epoch 170/1600 Done, Total Loss: 0.20081617683172226
# Epoch 171/1600 Done, Total Loss: 0.2001490518450737
# Epoch 172/1600 Done, Total Loss: 0.19926466047763824
# Epoch 173/1600 Done, Total Loss: 0.1984676718711853
# Epoch 174/1600 Done, Total Loss: 0.19797229766845703
# Epoch 175/1600 Done, Total Loss: 0.19741426408290863
# Epoch 176/1600 Done, Total Loss: 0.19640345126390457
# Epoch 177/1600 Done, Total Loss: 0.19580908864736557
# Epoch 178/1600 Done, Total Loss: 0.19511765986680984
# Epoch 179/1600 Done, Total Loss: 0.19437309354543686
# Epoch 180/1600 Done, Total Loss: 0.19409321248531342
# Epoch 181/1600 Done, Total Loss: 0.1931268870830536
# Epoch 182/1600 Done, Total Loss: 0.19281775504350662
# Epoch 183/1600 Done, Total Loss: 0.19195443391799927
# Epoch 184/1600 Done, Total Loss: 0.1911957636475563
# Epoch 185/1600 Done, Total Loss: 0.190431609749794
# Epoch 186/1600 Done, Total Loss: 0.18979554623365402
# Epoch 187/1600 Done, Total Loss: 0.18916505575180054
# Epoch 188/1600 Done, Total Loss: 0.18856512010097504
# Epoch 189/1600 Done, Total Loss: 0.18793676048517227
# Epoch 190/1600 Done, Total Loss: 0.18740134686231613
# Epoch 191/1600 Done, Total Loss: 0.1865067183971405
# Epoch 192/1600 Done, Total Loss: 0.18615447729825974
# Epoch 193/1600 Done, Total Loss: 0.1854356750845909
# Epoch 194/1600 Done, Total Loss: 0.184507817029953
# Epoch 195/1600 Done, Total Loss: 0.1842719092965126
# Epoch 196/1600 Done, Total Loss: 0.18322066962718964
# Epoch 197/1600 Done, Total Loss: 0.18267881870269775
# Epoch 198/1600 Done, Total Loss: 0.1820424720644951
# Epoch 199/1600 Done, Total Loss: 0.18144215643405914
# Epoch 200/1600 Done, Total Loss: 0.18074902147054672
# Epoch 201/1600 Done, Total Loss: 0.18013647198677063
# Epoch 202/1600 Done, Total Loss: 0.1794673651456833
# Epoch 203/1600 Done, Total Loss: 0.17892633378505707
# Epoch 204/1600 Done, Total Loss: 0.1780220866203308
# Epoch 205/1600 Done, Total Loss: 0.17747880518436432
# Epoch 206/1600 Done, Total Loss: 0.1770293340086937
# Epoch 207/1600 Done, Total Loss: 0.1761544719338417
# Epoch 208/1600 Done, Total Loss: 0.17551631480455399
# Epoch 209/1600 Done, Total Loss: 0.17498932406306267
# Epoch 210/1600 Done, Total Loss: 0.17434720695018768
# Epoch 211/1600 Done, Total Loss: 0.17391347140073776
# Epoch 212/1600 Done, Total Loss: 0.17328204959630966
# Epoch 213/1600 Done, Total Loss: 0.17266955226659775
# Epoch 214/1600 Done, Total Loss: 0.17194122076034546
# Epoch 215/1600 Done, Total Loss: 0.17119039595127106
# Epoch 216/1600 Done, Total Loss: 0.17059452831745148
# Epoch 217/1600 Done, Total Loss: 0.1698354408144951
# Epoch 218/1600 Done, Total Loss: 0.169512078166008
# Epoch 219/1600 Done, Total Loss: 0.16857098788022995
# Epoch 220/1600 Done, Total Loss: 0.1682123914361
# Epoch 221/1600 Done, Total Loss: 0.16732588410377502
# Epoch 222/1600 Done, Total Loss: 0.1667512133717537
# Epoch 223/1600 Done, Total Loss: 0.16626116633415222
# Epoch 224/1600 Done, Total Loss: 0.16548293828964233
# Epoch 225/1600 Done, Total Loss: 0.16489176452159882
# Epoch 226/1600 Done, Total Loss: 0.16426927223801613
# Epoch 227/1600 Done, Total Loss: 0.16364384070038795
# Epoch 228/1600 Done, Total Loss: 0.1631481684744358
# Epoch 229/1600 Done, Total Loss: 0.16255483776330948
# Epoch 230/1600 Done, Total Loss: 0.16201329231262207
# Epoch 231/1600 Done, Total Loss: 0.16130032390356064
# Epoch 232/1600 Done, Total Loss: 0.16062499210238457
# Epoch 233/1600 Done, Total Loss: 0.16021203994750977
# Epoch 234/1600 Done, Total Loss: 0.15944182127714157
# Epoch 235/1600 Done, Total Loss: 0.15892455726861954
# Epoch 236/1600 Done, Total Loss: 0.15834254771471024
# Epoch 237/1600 Done, Total Loss: 0.1575264260172844
# Epoch 238/1600 Done, Total Loss: 0.15737707912921906
# Epoch 239/1600 Done, Total Loss: 0.15648451820015907
# Epoch 240/1600 Done, Total Loss: 0.15591837465763092
# Epoch 241/1600 Done, Total Loss: 0.15547426044940948
# Epoch 242/1600 Done, Total Loss: 0.1547888070344925
# Epoch 243/1600 Done, Total Loss: 0.15428973734378815
# Epoch 244/1600 Done, Total Loss: 0.15342289954423904
# Epoch 245/1600 Done, Total Loss: 0.15286410599946976
# Epoch 246/1600 Done, Total Loss: 0.15245427191257477
# Epoch 247/1600 Done, Total Loss: 0.1516527682542801
# Epoch 248/1600 Done, Total Loss: 0.1511794552206993
# Epoch 249/1600 Done, Total Loss: 0.15061189234256744
# Epoch 250/1600 Done, Total Loss: 0.1500253677368164
# Epoch 251/1600 Done, Total Loss: 0.14925740659236908
# Epoch 252/1600 Done, Total Loss: 0.1487366035580635
# Epoch 253/1600 Done, Total Loss: 0.14808811619877815
# Epoch 254/1600 Done, Total Loss: 0.14757736027240753
# Epoch 255/1600 Done, Total Loss: 0.14707480370998383
# Epoch 256/1600 Done, Total Loss: 0.14638658240437508
# Epoch 257/1600 Done, Total Loss: 0.14591466635465622
# Epoch 258/1600 Done, Total Loss: 0.14527234435081482
# Epoch 259/1600 Done, Total Loss: 0.14471391588449478
# Epoch 260/1600 Done, Total Loss: 0.14428551495075226
# Epoch 261/1600 Done, Total Loss: 0.14350149780511856
# Epoch 262/1600 Done, Total Loss: 0.14298072457313538
# Epoch 263/1600 Done, Total Loss: 0.14245619997382164
# Epoch 264/1600 Done, Total Loss: 0.14177263155579567
# Epoch 265/1600 Done, Total Loss: 0.1415100172162056
# Epoch 266/1600 Done, Total Loss: 0.1407652609050274
# Epoch 267/1600 Done, Total Loss: 0.1400136537849903
# Epoch 268/1600 Done, Total Loss: 0.13987015187740326
# Epoch 269/1600 Done, Total Loss: 0.13905999809503555
# Epoch 270/1600 Done, Total Loss: 0.13847872987389565
# Epoch 271/1600 Done, Total Loss: 0.1379496306180954
# Epoch 272/1600 Done, Total Loss: 0.13742395490407944
# Epoch 273/1600 Done, Total Loss: 0.13668715208768845
# Epoch 274/1600 Done, Total Loss: 0.13610095530748367
# Epoch 275/1600 Done, Total Loss: 0.1357436254620552
# Epoch 276/1600 Done, Total Loss: 0.13509078323841095
# Epoch 277/1600 Done, Total Loss: 0.134648397564888
# Epoch 278/1600 Done, Total Loss: 0.13425415009260178
# Epoch 279/1600 Done, Total Loss: 0.1336863823235035
# Epoch 280/1600 Done, Total Loss: 0.1328367292881012
# Epoch 281/1600 Done, Total Loss: 0.13226203620433807
# Epoch 282/1600 Done, Total Loss: 0.1317119225859642
# Epoch 283/1600 Done, Total Loss: 0.13145826756954193
# Epoch 284/1600 Done, Total Loss: 0.1307906024158001
# Epoch 285/1600 Done, Total Loss: 0.13026979565620422
# Epoch 286/1600 Done, Total Loss: 0.12974310293793678
# Epoch 287/1600 Done, Total Loss: 0.12905804812908173
# Epoch 288/1600 Done, Total Loss: 0.12870973348617554
# Epoch 289/1600 Done, Total Loss: 0.12789219617843628
# Epoch 290/1600 Done, Total Loss: 0.1274634748697281
# Epoch 291/1600 Done, Total Loss: 0.12677370011806488
# Epoch 292/1600 Done, Total Loss: 0.12629197910428047
# Epoch 293/1600 Done, Total Loss: 0.12591470777988434
# Epoch 294/1600 Done, Total Loss: 0.12527265399694443
# Epoch 295/1600 Done, Total Loss: 0.12466928735375404
# Epoch 296/1600 Done, Total Loss: 0.12420416623353958
# Epoch 297/1600 Done, Total Loss: 0.12402205541729927
# Epoch 298/1600 Done, Total Loss: 0.12306247651576996
# Epoch 299/1600 Done, Total Loss: 0.12262827157974243
# Epoch 300/1600 Done, Total Loss: 0.12204184010624886
# Epoch 301/1600 Done, Total Loss: 0.12145379185676575
# Epoch 302/1600 Done, Total Loss: 0.12129400297999382
# Epoch 303/1600 Done, Total Loss: 0.12072009220719337
# Epoch 304/1600 Done, Total Loss: 0.1198936402797699
# Epoch 305/1600 Done, Total Loss: 0.11939815431833267
# Epoch 306/1600 Done, Total Loss: 0.11886828020215034
# Epoch 307/1600 Done, Total Loss: 0.11839066445827484
# Epoch 308/1600 Done, Total Loss: 0.11782223731279373
# Epoch 309/1600 Done, Total Loss: 0.11731045693159103
# Epoch 310/1600 Done, Total Loss: 0.11687174439430237
# Epoch 311/1600 Done, Total Loss: 0.11625314131379128
# Epoch 312/1600 Done, Total Loss: 0.11576060950756073
# Epoch 313/1600 Done, Total Loss: 0.11524981632828712
# Epoch 314/1600 Done, Total Loss: 0.11469775065779686
# Epoch 315/1600 Done, Total Loss: 0.11445356160402298
# Epoch 316/1600 Done, Total Loss: 0.11401047557592392
# Epoch 317/1600 Done, Total Loss: 0.11347315460443497
# Epoch 318/1600 Done, Total Loss: 0.11275537312030792
# Epoch 319/1600 Done, Total Loss: 0.11224905401468277
# Epoch 320/1600 Done, Total Loss: 0.11176035553216934
# Epoch 321/1600 Done, Total Loss: 0.11128582432866096
# Epoch 322/1600 Done, Total Loss: 0.11066574603319168
# Epoch 323/1600 Done, Total Loss: 0.11022376641631126
# Epoch 324/1600 Done, Total Loss: 0.1096324659883976
# Epoch 325/1600 Done, Total Loss: 0.10912003740668297
# Epoch 326/1600 Done, Total Loss: 0.1087023951113224
# Epoch 327/1600 Done, Total Loss: 0.10840212926268578
# Epoch 328/1600 Done, Total Loss: 0.10776996985077858
# Epoch 329/1600 Done, Total Loss: 0.10714558139443398
# Epoch 330/1600 Done, Total Loss: 0.10703567415475845
# Epoch 331/1600 Done, Total Loss: 0.10617054626345634
# Epoch 332/1600 Done, Total Loss: 0.10565824806690216
# Epoch 333/1600 Done, Total Loss: 0.10517275705933571
# Epoch 334/1600 Done, Total Loss: 0.10477112606167793
# Epoch 335/1600 Done, Total Loss: 0.10415107384324074
# Epoch 336/1600 Done, Total Loss: 0.10385422222316265
# Epoch 337/1600 Done, Total Loss: 0.10317589156329632
# Epoch 338/1600 Done, Total Loss: 0.10290483012795448
# Epoch 339/1600 Done, Total Loss: 0.10253595933318138
# Epoch 340/1600 Done, Total Loss: 0.101898904889822
# Epoch 341/1600 Done, Total Loss: 0.10131865367293358
# Epoch 342/1600 Done, Total Loss: 0.10071299597620964
# Epoch 343/1600 Done, Total Loss: 0.1005333885550499
# Epoch 344/1600 Done, Total Loss: 0.10007510706782341
# Epoch 345/1600 Done, Total Loss: 0.09949341043829918
# Epoch 346/1600 Done, Total Loss: 0.098993469029665
# Epoch 347/1600 Done, Total Loss: 0.09848373383283615
# Epoch 348/1600 Done, Total Loss: 0.09805252403020859
# Epoch 349/1600 Done, Total Loss: 0.09766451641917229
# Epoch 350/1600 Done, Total Loss: 0.09712114930152893
# Epoch 351/1600 Done, Total Loss: 0.09656170755624771
# Epoch 352/1600 Done, Total Loss: 0.09629189968109131
# Epoch 353/1600 Done, Total Loss: 0.09587115421891212
# Epoch 354/1600 Done, Total Loss: 0.09509201720356941
# Epoch 355/1600 Done, Total Loss: 0.09490437060594559
# Epoch 356/1600 Done, Total Loss: 0.09428119100630283
# Epoch 357/1600 Done, Total Loss: 0.09370816498994827
# Epoch 358/1600 Done, Total Loss: 0.09336381405591965
# Epoch 359/1600 Done, Total Loss: 0.09284555539488792
# Epoch 360/1600 Done, Total Loss: 0.09247966483235359
# Epoch 361/1600 Done, Total Loss: 0.09216856025159359
# Epoch 362/1600 Done, Total Loss: 0.09148438647389412
# Epoch 363/1600 Done, Total Loss: 0.09128030762076378
# Epoch 364/1600 Done, Total Loss: 0.09068524092435837
# Epoch 365/1600 Done, Total Loss: 0.09004751965403557
# Epoch 366/1600 Done, Total Loss: 0.08971007168292999
# Epoch 367/1600 Done, Total Loss: 0.08922122418880463
# Epoch 368/1600 Done, Total Loss: 0.08887987211346626
# Epoch 369/1600 Done, Total Loss: 0.08849717304110527
# Epoch 370/1600 Done, Total Loss: 0.08800755813717842
# Epoch 371/1600 Done, Total Loss: 0.08750986307859421
# Epoch 372/1600 Done, Total Loss: 0.08695883676409721
# Epoch 373/1600 Done, Total Loss: 0.08654936403036118
# Epoch 374/1600 Done, Total Loss: 0.08627836033701897
# Epoch 375/1600 Done, Total Loss: 0.08564918860793114
# Epoch 376/1600 Done, Total Loss: 0.08534971252083778
# Epoch 377/1600 Done, Total Loss: 0.0848224014043808
# Epoch 378/1600 Done, Total Loss: 0.08445391058921814
# Epoch 379/1600 Done, Total Loss: 0.08385499007999897
# Epoch 380/1600 Done, Total Loss: 0.08348477818071842
# Epoch 381/1600 Done, Total Loss: 0.08308043330907822
# Epoch 382/1600 Done, Total Loss: 0.08258012309670448
# Epoch 383/1600 Done, Total Loss: 0.08225229755043983
# Epoch 384/1600 Done, Total Loss: 0.08181962370872498
# Epoch 385/1600 Done, Total Loss: 0.08135325275361538
# Epoch 386/1600 Done, Total Loss: 0.08092746883630753
# Epoch 387/1600 Done, Total Loss: 0.08065582811832428
# Epoch 388/1600 Done, Total Loss: 0.08033810555934906
# Epoch 389/1600 Done, Total Loss: 0.079740509390831
# Epoch 390/1600 Done, Total Loss: 0.07937844842672348
# Epoch 391/1600 Done, Total Loss: 0.07904625311493874
# Epoch 392/1600 Done, Total Loss: 0.07844582945108414
# Epoch 393/1600 Done, Total Loss: 0.07825026661157608
# Epoch 394/1600 Done, Total Loss: 0.0778404027223587
# Epoch 395/1600 Done, Total Loss: 0.07730866596102715
# Epoch 396/1600 Done, Total Loss: 0.07681900635361671
# Epoch 397/1600 Done, Total Loss: 0.07646463811397552
# Epoch 398/1600 Done, Total Loss: 0.07590584084391594
# Epoch 399/1600 Done, Total Loss: 0.07557616382837296
# Epoch 400/1600 Done, Total Loss: 0.07530530914664268
# Epoch 401/1600 Done, Total Loss: 0.07486087083816528
# Epoch 402/1600 Done, Total Loss: 0.07436974719166756
# Epoch 403/1600 Done, Total Loss: 0.07395142316818237
# Epoch 404/1600 Done, Total Loss: 0.07349400781095028
# Epoch 405/1600 Done, Total Loss: 0.07328977063298225
# Epoch 406/1600 Done, Total Loss: 0.07300321757793427
# Epoch 407/1600 Done, Total Loss: 0.07231050729751587
# Epoch 408/1600 Done, Total Loss: 0.07201414182782173
# Epoch 409/1600 Done, Total Loss: 0.07182381488382816
# Epoch 410/1600 Done, Total Loss: 0.0713418759405613
# Epoch 411/1600 Done, Total Loss: 0.07079127803444862
# Epoch 412/1600 Done, Total Loss: 0.07044972479343414
# Epoch 413/1600 Done, Total Loss: 0.07006579637527466
# Epoch 414/1600 Done, Total Loss: 0.06961451843380928
# Epoch 415/1600 Done, Total Loss: 0.06932841800153255
# Epoch 416/1600 Done, Total Loss: 0.06886139139533043
# Epoch 417/1600 Done, Total Loss: 0.06856351532042027
# Epoch 418/1600 Done, Total Loss: 0.06807942502200603
# Epoch 419/1600 Done, Total Loss: 0.06776753254234791
# Epoch 420/1600 Done, Total Loss: 0.06750322133302689
# Epoch 421/1600 Done, Total Loss: 0.06715676747262478
# Epoch 422/1600 Done, Total Loss: 0.06680795922875404
# Epoch 423/1600 Done, Total Loss: 0.06662216410040855
# Epoch 424/1600 Done, Total Loss: 0.06597541272640228
# Epoch 425/1600 Done, Total Loss: 0.06567720882594585
# Epoch 426/1600 Done, Total Loss: 0.0654715932905674
# Epoch 427/1600 Done, Total Loss: 0.06499912589788437
# Epoch 428/1600 Done, Total Loss: 0.064589723944664
# Epoch 429/1600 Done, Total Loss: 0.0642100889235735
# Epoch 430/1600 Done, Total Loss: 0.06384302303195
# Epoch 431/1600 Done, Total Loss: 0.06358843110501766
# Epoch 432/1600 Done, Total Loss: 0.06340864300727844
# Epoch 433/1600 Done, Total Loss: 0.06286652758717537
# Epoch 434/1600 Done, Total Loss: 0.06245567463338375
# Epoch 435/1600 Done, Total Loss: 0.062201956287026405
# Epoch 436/1600 Done, Total Loss: 0.06194353103637695
# Epoch 437/1600 Done, Total Loss: 0.06149599328637123
# Epoch 438/1600 Done, Total Loss: 0.06131969764828682
# Epoch 439/1600 Done, Total Loss: 0.06106612831354141
# Epoch 440/1600 Done, Total Loss: 0.060537753626704216
# Epoch 441/1600 Done, Total Loss: 0.06033369526267052
# Epoch 442/1600 Done, Total Loss: 0.05978637933731079
# Epoch 443/1600 Done, Total Loss: 0.059707997366786
# Epoch 444/1600 Done, Total Loss: 0.059205664321780205
# Epoch 445/1600 Done, Total Loss: 0.05888551287353039
# Epoch 446/1600 Done, Total Loss: 0.05854209512472153
# Epoch 447/1600 Done, Total Loss: 0.058330927044153214
# Epoch 448/1600 Done, Total Loss: 0.057816581800580025
# Epoch 449/1600 Done, Total Loss: 0.05749344080686569
# Epoch 450/1600 Done, Total Loss: 0.05716268718242645
# Epoch 451/1600 Done, Total Loss: 0.057060159742832184
# Epoch 452/1600 Done, Total Loss: 0.056609323248267174
# Epoch 453/1600 Done, Total Loss: 0.056240081787109375
# Epoch 454/1600 Done, Total Loss: 0.05588814616203308
# Epoch 455/1600 Done, Total Loss: 0.05584445036947727
# Epoch 456/1600 Done, Total Loss: 0.055492889136075974
# Epoch 457/1600 Done, Total Loss: 0.055056385695934296
# Epoch 458/1600 Done, Total Loss: 0.054750956594944
# Epoch 459/1600 Done, Total Loss: 0.05441981554031372
# Epoch 460/1600 Done, Total Loss: 0.054227497428655624
# Epoch 461/1600 Done, Total Loss: 0.05378510802984238
# Epoch 462/1600 Done, Total Loss: 0.05342933349311352
# Epoch 463/1600 Done, Total Loss: 0.053319673985242844
# Epoch 464/1600 Done, Total Loss: 0.05287116393446922
# Epoch 465/1600 Done, Total Loss: 0.05256212688982487
# Epoch 466/1600 Done, Total Loss: 0.05255955830216408
# Epoch 467/1600 Done, Total Loss: 0.05193787068128586
# Epoch 468/1600 Done, Total Loss: 0.05172310955822468
# Epoch 469/1600 Done, Total Loss: 0.05154634825885296
# Epoch 470/1600 Done, Total Loss: 0.05129370652139187
# Epoch 471/1600 Done, Total Loss: 0.050799621269106865
# Epoch 472/1600 Done, Total Loss: 0.05061620660126209
# Epoch 473/1600 Done, Total Loss: 0.0502125546336174
# Epoch 474/1600 Done, Total Loss: 0.04996834322810173
# Epoch 475/1600 Done, Total Loss: 0.04983081296086311
# Epoch 476/1600 Done, Total Loss: 0.04945915378630161
# Epoch 477/1600 Done, Total Loss: 0.04905791953206062
# Epoch 478/1600 Done, Total Loss: 0.04885806888341904
# Epoch 479/1600 Done, Total Loss: 0.04856165498495102
# Epoch 480/1600 Done, Total Loss: 0.04822659119963646
# Epoch 481/1600 Done, Total Loss: 0.04801204614341259
# Epoch 482/1600 Done, Total Loss: 0.04789143055677414
# Epoch 483/1600 Done, Total Loss: 0.04750587046146393
# Epoch 484/1600 Done, Total Loss: 0.047226086258888245
# Epoch 485/1600 Done, Total Loss: 0.04681258276104927
# Epoch 486/1600 Done, Total Loss: 0.0466894656419754
# Epoch 487/1600 Done, Total Loss: 0.046358559280633926
# Epoch 488/1600 Done, Total Loss: 0.04609096795320511
# Epoch 489/1600 Done, Total Loss: 0.04579669050872326
# Epoch 490/1600 Done, Total Loss: 0.04552049934864044
# Epoch 491/1600 Done, Total Loss: 0.045411042869091034
# Epoch 492/1600 Done, Total Loss: 0.04505727253854275
# Epoch 493/1600 Done, Total Loss: 0.044647304341197014
# Epoch 494/1600 Done, Total Loss: 0.04440038651227951
# Epoch 495/1600 Done, Total Loss: 0.044306693598628044
# Epoch 496/1600 Done, Total Loss: 0.0439684484153986
# Epoch 497/1600 Done, Total Loss: 0.0438461359590292
# Epoch 498/1600 Done, Total Loss: 0.0435048695653677
# Epoch 499/1600 Done, Total Loss: 0.04328765906393528
# Epoch 500/1600 Done, Total Loss: 0.043050557374954224
# Epoch 501/1600 Done, Total Loss: 0.042627131566405296
# Epoch 502/1600 Done, Total Loss: 0.04234337992966175
# Epoch 503/1600 Done, Total Loss: 0.04207523446530104
# Epoch 504/1600 Done, Total Loss: 0.0418230164796114
# Epoch 505/1600 Done, Total Loss: 0.041655924171209335
# Epoch 506/1600 Done, Total Loss: 0.04133255034685135
# Epoch 507/1600 Done, Total Loss: 0.041254209354519844
# Epoch 508/1600 Done, Total Loss: 0.04090272542089224
# Epoch 509/1600 Done, Total Loss: 0.04070710763335228
# Epoch 510/1600 Done, Total Loss: 0.04040021821856499
# Epoch 511/1600 Done, Total Loss: 0.04013045225292444
# Epoch 512/1600 Done, Total Loss: 0.03993513062596321
# Epoch 513/1600 Done, Total Loss: 0.03966749273240566
# Epoch 514/1600 Done, Total Loss: 0.03955447860062122
# Epoch 515/1600 Done, Total Loss: 0.039256760850548744
# Epoch 516/1600 Done, Total Loss: 0.03893580939620733
# Epoch 517/1600 Done, Total Loss: 0.03876728378236294
# Epoch 518/1600 Done, Total Loss: 0.03846023604273796
# Epoch 519/1600 Done, Total Loss: 0.0383004080504179
# Epoch 520/1600 Done, Total Loss: 0.038055019453167915
# Epoch 521/1600 Done, Total Loss: 0.03773076646029949
# Epoch 522/1600 Done, Total Loss: 0.03764376603066921
# Epoch 523/1600 Done, Total Loss: 0.037374780513346195
# Epoch 524/1600 Done, Total Loss: 0.037201233208179474
# Epoch 525/1600 Done, Total Loss: 0.03683726955205202
# Epoch 526/1600 Done, Total Loss: 0.036622900515794754
# Epoch 527/1600 Done, Total Loss: 0.03640201687812805
# Epoch 528/1600 Done, Total Loss: 0.03634302131831646
# Epoch 529/1600 Done, Total Loss: 0.036168637685477734
# Epoch 530/1600 Done, Total Loss: 0.03587174601852894
# Epoch 531/1600 Done, Total Loss: 0.03554754424840212
# Epoch 532/1600 Done, Total Loss: 0.03537333011627197
# Epoch 533/1600 Done, Total Loss: 0.03511482570320368
# Epoch 534/1600 Done, Total Loss: 0.03500029630959034
# Epoch 535/1600 Done, Total Loss: 0.034682474099099636
# Epoch 536/1600 Done, Total Loss: 0.03456603456288576
# Epoch 537/1600 Done, Total Loss: 0.03439517319202423
# Epoch 538/1600 Done, Total Loss: 0.03406895697116852
# Epoch 539/1600 Done, Total Loss: 0.03382363449782133
# Epoch 540/1600 Done, Total Loss: 0.033594416454434395
# Epoch 541/1600 Done, Total Loss: 0.03340400382876396
# Epoch 542/1600 Done, Total Loss: 0.03315576910972595
# Epoch 543/1600 Done, Total Loss: 0.03301495127379894
# Epoch 544/1600 Done, Total Loss: 0.03279489278793335
# Epoch 545/1600 Done, Total Loss: 0.03256511688232422
# Epoch 546/1600 Done, Total Loss: 0.03239237051457167
# Epoch 547/1600 Done, Total Loss: 0.03228424862027168
# Epoch 548/1600 Done, Total Loss: 0.03191837714985013
# Epoch 549/1600 Done, Total Loss: 0.03180332016199827
# Epoch 550/1600 Done, Total Loss: 0.03171824850142002
# Epoch 551/1600 Done, Total Loss: 0.03139526769518852
# Epoch 552/1600 Done, Total Loss: 0.03131465055048466
# Epoch 553/1600 Done, Total Loss: 0.031023377552628517
# Epoch 554/1600 Done, Total Loss: 0.03082016110420227
# Epoch 555/1600 Done, Total Loss: 0.030767321586608887
# Epoch 556/1600 Done, Total Loss: 0.030517236329615116
# Epoch 557/1600 Done, Total Loss: 0.0302589051425457
# Epoch 558/1600 Done, Total Loss: 0.030154635198414326
# Epoch 559/1600 Done, Total Loss: 0.029871980659663677
# Epoch 560/1600 Done, Total Loss: 0.0296919047832489
# Epoch 561/1600 Done, Total Loss: 0.02959475200623274
# Epoch 562/1600 Done, Total Loss: 0.029296252876520157
# Epoch 563/1600 Done, Total Loss: 0.02906985394656658
# Epoch 564/1600 Done, Total Loss: 0.02893001399934292
# Epoch 565/1600 Done, Total Loss: 0.028757469728589058
# Epoch 566/1600 Done, Total Loss: 0.028520564548671246
# Epoch 567/1600 Done, Total Loss: 0.028348331339657307
# Epoch 568/1600 Done, Total Loss: 0.02819700725376606
# Epoch 569/1600 Done, Total Loss: 0.027999332174658775
# Epoch 570/1600 Done, Total Loss: 0.027950704097747803
# Epoch 571/1600 Done, Total Loss: 0.02769159898161888
# Epoch 572/1600 Done, Total Loss: 0.02743955422192812
# Epoch 573/1600 Done, Total Loss: 0.027286983095109463
# Epoch 574/1600 Done, Total Loss: 0.02718689013272524
# Epoch 575/1600 Done, Total Loss: 0.02697732299566269
# Epoch 576/1600 Done, Total Loss: 0.026774351485073566
# Epoch 577/1600 Done, Total Loss: 0.026696174405515194
# Epoch 578/1600 Done, Total Loss: 0.026443607173860073
# Epoch 579/1600 Done, Total Loss: 0.02626533154398203
# Epoch 580/1600 Done, Total Loss: 0.026119413785636425
# Epoch 581/1600 Done, Total Loss: 0.026013240218162537
# Epoch 582/1600 Done, Total Loss: 0.025786887854337692
# Epoch 583/1600 Done, Total Loss: 0.025592824909836054
# Epoch 584/1600 Done, Total Loss: 0.025492684915661812
# Epoch 585/1600 Done, Total Loss: 0.02532456535845995
# Epoch 586/1600 Done, Total Loss: 0.02508633490651846
# Epoch 587/1600 Done, Total Loss: 0.02507668361067772
# Epoch 588/1600 Done, Total Loss: 0.024805735796689987
# Epoch 589/1600 Done, Total Loss: 0.02464516181498766
# Epoch 590/1600 Done, Total Loss: 0.024506951682269573
# Epoch 591/1600 Done, Total Loss: 0.024320505559444427
# Epoch 592/1600 Done, Total Loss: 0.024305465631186962
# Epoch 593/1600 Done, Total Loss: 0.024052957072854042
# Epoch 594/1600 Done, Total Loss: 0.02387438714504242
# Epoch 595/1600 Done, Total Loss: 0.02367974817752838
# Epoch 596/1600 Done, Total Loss: 0.02366707194596529
# Epoch 597/1600 Done, Total Loss: 0.02338977437466383
# Epoch 598/1600 Done, Total Loss: 0.023272450547665358
# Epoch 599/1600 Done, Total Loss: 0.023107618559151888
# Epoch 600/1600 Done, Total Loss: 0.022962301969528198
# Epoch 601/1600 Done, Total Loss: 0.022900874726474285
# Epoch 602/1600 Done, Total Loss: 0.022644820623099804
# Epoch 603/1600 Done, Total Loss: 0.022672093473374844
# Epoch 604/1600 Done, Total Loss: 0.02239005221053958
# Epoch 605/1600 Done, Total Loss: 0.02228766307234764
# Epoch 606/1600 Done, Total Loss: 0.022044564597308636
# Epoch 607/1600 Done, Total Loss: 0.021942622028291225
# Epoch 608/1600 Done, Total Loss: 0.021748356986790895
# Epoch 609/1600 Done, Total Loss: 0.021698578726500273
# Epoch 610/1600 Done, Total Loss: 0.02150811441242695
# Epoch 611/1600 Done, Total Loss: 0.02144748345017433
# Epoch 612/1600 Done, Total Loss: 0.021205994300544262
# Epoch 613/1600 Done, Total Loss: 0.021107444539666176
# Epoch 614/1600 Done, Total Loss: 0.02108333259820938
# Epoch 615/1600 Done, Total Loss: 0.020869055762887
# Epoch 616/1600 Done, Total Loss: 0.02070823172107339
# Epoch 617/1600 Done, Total Loss: 0.020573788788169622
# Epoch 618/1600 Done, Total Loss: 0.02039187354966998
# Epoch 619/1600 Done, Total Loss: 0.020415031351149082
# Epoch 620/1600 Done, Total Loss: 0.02015713043510914
# Epoch 621/1600 Done, Total Loss: 0.02000825386494398
# Epoch 622/1600 Done, Total Loss: 0.019975299015641212
# Epoch 623/1600 Done, Total Loss: 0.019785169512033463
# Epoch 624/1600 Done, Total Loss: 0.019650805741548538
# Epoch 625/1600 Done, Total Loss: 0.01946046925149858
# Epoch 626/1600 Done, Total Loss: 0.019383679144084454
# Epoch 627/1600 Done, Total Loss: 0.019439187366515398
# Epoch 628/1600 Done, Total Loss: 0.019232657738029957
# Epoch 629/1600 Done, Total Loss: 0.01904197270050645
# Epoch 630/1600 Done, Total Loss: 0.01887458935379982
# Epoch 631/1600 Done, Total Loss: 0.018736666068434715
# Epoch 632/1600 Done, Total Loss: 0.018597174435853958
# Epoch 633/1600 Done, Total Loss: 0.018520747311413288
# Epoch 634/1600 Done, Total Loss: 0.018369616009294987
# Epoch 635/1600 Done, Total Loss: 0.018327558878809214
# Epoch 636/1600 Done, Total Loss: 0.01819182699546218
# Epoch 637/1600 Done, Total Loss: 0.018076788634061813
# Epoch 638/1600 Done, Total Loss: 0.017887395806610584
# Epoch 639/1600 Done, Total Loss: 0.017894290387630463
# Epoch 640/1600 Done, Total Loss: 0.017686345614492893
# Epoch 641/1600 Done, Total Loss: 0.017681733705103397
# Epoch 642/1600 Done, Total Loss: 0.017479979898780584
# Epoch 643/1600 Done, Total Loss: 0.01745169796049595
# Epoch 644/1600 Done, Total Loss: 0.017345509957522154
# Epoch 645/1600 Done, Total Loss: 0.01719182962551713
# Epoch 646/1600 Done, Total Loss: 0.017137419432401657
# Epoch 647/1600 Done, Total Loss: 0.017005987465381622
# Epoch 648/1600 Done, Total Loss: 0.016807512380182743
# Epoch 649/1600 Done, Total Loss: 0.016806432977318764
# Epoch 650/1600 Done, Total Loss: 0.016652376390993595
# Epoch 651/1600 Done, Total Loss: 0.016548674553632736
# Epoch 652/1600 Done, Total Loss: 0.016404401510953903
# Epoch 653/1600 Done, Total Loss: 0.01625655498355627
# Epoch 654/1600 Done, Total Loss: 0.016162485349923372
# Epoch 655/1600 Done, Total Loss: 0.016074230894446373
# Epoch 656/1600 Done, Total Loss: 0.016004538163542747
# Epoch 657/1600 Done, Total Loss: 0.015906275250017643
# Epoch 658/1600 Done, Total Loss: 0.015785072464495897
# Epoch 659/1600 Done, Total Loss: 0.015613242983818054
# Epoch 660/1600 Done, Total Loss: 0.0156622426584363
# Epoch 661/1600 Done, Total Loss: 0.015450961887836456
# Epoch 662/1600 Done, Total Loss: 0.015395315364003181
# Epoch 663/1600 Done, Total Loss: 0.015313874930143356
# Epoch 664/1600 Done, Total Loss: 0.015294847078621387
# Epoch 665/1600 Done, Total Loss: 0.015083909500390291
# Epoch 666/1600 Done, Total Loss: 0.015003976877778769
# Epoch 667/1600 Done, Total Loss: 0.014878413639962673
# Epoch 668/1600 Done, Total Loss: 0.014736865414306521
# Epoch 669/1600 Done, Total Loss: 0.01471091527491808
# Epoch 670/1600 Done, Total Loss: 0.014570633647963405
# Epoch 671/1600 Done, Total Loss: 0.014455861411988735
# Epoch 672/1600 Done, Total Loss: 0.014415964018553495
# Epoch 673/1600 Done, Total Loss: 0.014396326150745153
# Epoch 674/1600 Done, Total Loss: 0.014215948060154915
# Epoch 675/1600 Done, Total Loss: 0.014126490335911512
# Epoch 676/1600 Done, Total Loss: 0.014052143786102533
# Epoch 677/1600 Done, Total Loss: 0.013957866933196783
# Epoch 678/1600 Done, Total Loss: 0.013843650929629803
# Epoch 679/1600 Done, Total Loss: 0.013830546289682388
# Epoch 680/1600 Done, Total Loss: 0.013666206039488316
# Epoch 681/1600 Done, Total Loss: 0.013559226412326097
# Epoch 682/1600 Done, Total Loss: 0.013627470005303621
# Epoch 683/1600 Done, Total Loss: 0.013451723381876945
# Epoch 684/1600 Done, Total Loss: 0.013453998137265444
# Epoch 685/1600 Done, Total Loss: 0.013231775723397732
# Epoch 686/1600 Done, Total Loss: 0.013181223999708891
# Epoch 687/1600 Done, Total Loss: 0.013108629267662764
# Epoch 688/1600 Done, Total Loss: 0.01300070807337761
# Epoch 689/1600 Done, Total Loss: 0.012900543166324496
# Epoch 690/1600 Done, Total Loss: 0.012924409937113523
# Epoch 691/1600 Done, Total Loss: 0.01274566538631916
# Epoch 692/1600 Done, Total Loss: 0.012686761328950524
# Epoch 693/1600 Done, Total Loss: 0.012721019331365824
# Epoch 694/1600 Done, Total Loss: 0.012520605698227882
# Epoch 695/1600 Done, Total Loss: 0.01242087921127677
# Epoch 696/1600 Done, Total Loss: 0.012365611037239432
# Epoch 697/1600 Done, Total Loss: 0.012289469363167882
# Epoch 698/1600 Done, Total Loss: 0.012225288432091475
# Epoch 699/1600 Done, Total Loss: 0.012231866829097271
# Epoch 700/1600 Done, Total Loss: 0.012133890762925148
# Epoch 701/1600 Done, Total Loss: 0.011993134394288063
# Epoch 702/1600 Done, Total Loss: 0.011905219405889511
# Epoch 703/1600 Done, Total Loss: 0.011920842807739973
# Epoch 704/1600 Done, Total Loss: 0.011745840078219771
# Epoch 705/1600 Done, Total Loss: 0.01173641555942595
# Epoch 706/1600 Done, Total Loss: 0.011593623086810112
# Epoch 707/1600 Done, Total Loss: 0.011535319965332747
# Epoch 708/1600 Done, Total Loss: 0.011520632077008486
# Epoch 709/1600 Done, Total Loss: 0.01141273882240057
# Epoch 710/1600 Done, Total Loss: 0.011324461083859205
# Epoch 711/1600 Done, Total Loss: 0.011267462745308876
# Epoch 712/1600 Done, Total Loss: 0.011230656877160072
# Epoch 713/1600 Done, Total Loss: 0.011159542016685009
# Epoch 714/1600 Done, Total Loss: 0.011046797502785921
# Epoch 715/1600 Done, Total Loss: 0.011081696022301912
# Epoch 716/1600 Done, Total Loss: 0.010908123571425676
# Epoch 717/1600 Done, Total Loss: 0.010845666285604239
# Epoch 718/1600 Done, Total Loss: 0.010885054245591164
# Epoch 719/1600 Done, Total Loss: 0.010749973123893142
# Epoch 720/1600 Done, Total Loss: 0.010651745251379907
# Epoch 721/1600 Done, Total Loss: 0.010588252451270819
# Epoch 722/1600 Done, Total Loss: 0.010546094737946987
# Epoch 723/1600 Done, Total Loss: 0.010551080107688904
# Epoch 724/1600 Done, Total Loss: 0.010387073270976543
# Epoch 725/1600 Done, Total Loss: 0.010346158174797893
# Epoch 726/1600 Done, Total Loss: 0.01025342894718051
# Epoch 727/1600 Done, Total Loss: 0.010194980539381504
# Epoch 728/1600 Done, Total Loss: 0.010127401212230325
# Epoch 729/1600 Done, Total Loss: 0.010073497891426086
# Epoch 730/1600 Done, Total Loss: 0.010011455160565674
# Epoch 731/1600 Done, Total Loss: 0.00999443233013153
# Epoch 732/1600 Done, Total Loss: 0.009906342485919595
# Epoch 733/1600 Done, Total Loss: 0.009854205185547471
# Epoch 734/1600 Done, Total Loss: 0.009788576979190111
# Epoch 735/1600 Done, Total Loss: 0.009771749377250671
# Epoch 736/1600 Done, Total Loss: 0.009701024973765016
# Epoch 737/1600 Done, Total Loss: 0.009586053201928735
# Epoch 738/1600 Done, Total Loss: 0.009537081699818373
# Epoch 739/1600 Done, Total Loss: 0.009491951204836369
# Epoch 740/1600 Done, Total Loss: 0.009492887649685144
# Epoch 741/1600 Done, Total Loss: 0.009419390466064215
# Epoch 742/1600 Done, Total Loss: 0.009324041660875082
# Epoch 743/1600 Done, Total Loss: 0.009271573042497039
# Epoch 744/1600 Done, Total Loss: 0.009294516406953335
# Epoch 745/1600 Done, Total Loss: 0.009151565609499812
# Epoch 746/1600 Done, Total Loss: 0.009098173584789038
# Epoch 747/1600 Done, Total Loss: 0.009124748408794403
# Epoch 748/1600 Done, Total Loss: 0.009006832842715085
# Epoch 749/1600 Done, Total Loss: 0.009011589456349611
# Epoch 750/1600 Done, Total Loss: 0.008934822864830494
# Epoch 751/1600 Done, Total Loss: 0.008842721348628402
# Epoch 752/1600 Done, Total Loss: 0.008838847512379289
# Epoch 753/1600 Done, Total Loss: 0.008738504024222493
# Epoch 754/1600 Done, Total Loss: 0.00868780561722815
# Epoch 755/1600 Done, Total Loss: 0.008737699594348669
# Epoch 756/1600 Done, Total Loss: 0.008653546683490276
# Epoch 757/1600 Done, Total Loss: 0.00859592529013753
# Epoch 758/1600 Done, Total Loss: 0.008597882930189371
# Epoch 759/1600 Done, Total Loss: 0.008473733672872186
# Epoch 760/1600 Done, Total Loss: 0.008409836096689105
# Epoch 761/1600 Done, Total Loss: 0.008343522204086185
# Epoch 762/1600 Done, Total Loss: 0.008313212543725967
# Epoch 763/1600 Done, Total Loss: 0.00825162511318922
# Epoch 764/1600 Done, Total Loss: 0.008243001764640212
# Epoch 765/1600 Done, Total Loss: 0.00819085817784071
# Epoch 766/1600 Done, Total Loss: 0.008182075340300798
# Epoch 767/1600 Done, Total Loss: 0.008101916173473
# Epoch 768/1600 Done, Total Loss: 0.008082768647000194
# Epoch 769/1600 Done, Total Loss: 0.007986983517184854
# Epoch 770/1600 Done, Total Loss: 0.00794396665878594
# Epoch 771/1600 Done, Total Loss: 0.007900772616267204
# Epoch 772/1600 Done, Total Loss: 0.007854076568037271
# Epoch 773/1600 Done, Total Loss: 0.00789494113996625
# Epoch 774/1600 Done, Total Loss: 0.007778743747621775
# Epoch 775/1600 Done, Total Loss: 0.0078037152998149395
# Epoch 776/1600 Done, Total Loss: 0.0076892070937901735
# Epoch 777/1600 Done, Total Loss: 0.007628837833181024
# Epoch 778/1600 Done, Total Loss: 0.007616645423695445
# Epoch 779/1600 Done, Total Loss: 0.007637270959094167
# Epoch 780/1600 Done, Total Loss: 0.007516355253756046
# Epoch 781/1600 Done, Total Loss: 0.007521403254941106
# Epoch 782/1600 Done, Total Loss: 0.007419847068376839
# Epoch 783/1600 Done, Total Loss: 0.007484229281544685
# Epoch 784/1600 Done, Total Loss: 0.007431922014802694
# Epoch 785/1600 Done, Total Loss: 0.007323290221393108
# Epoch 786/1600 Done, Total Loss: 0.007256823475472629
# Epoch 787/1600 Done, Total Loss: 0.007325169164687395
# Epoch 788/1600 Done, Total Loss: 0.007269296096637845
# Epoch 789/1600 Done, Total Loss: 0.007233052747324109
# Epoch 790/1600 Done, Total Loss: 0.007145737879909575
# Epoch 791/1600 Done, Total Loss: 0.007115831831470132
# Epoch 792/1600 Done, Total Loss: 0.007078312803059816
# Epoch 793/1600 Done, Total Loss: 0.007106541423127055
# Epoch 794/1600 Done, Total Loss: 0.006974171963520348
# Epoch 795/1600 Done, Total Loss: 0.0069383615627884865
# Epoch 796/1600 Done, Total Loss: 0.006903426139615476
# Epoch 797/1600 Done, Total Loss: 0.006890516262501478
# Epoch 798/1600 Done, Total Loss: 0.006825244869105518
# Epoch 799/1600 Done, Total Loss: 0.006901026936247945
# Epoch 800/1600 Done, Total Loss: 0.0067566122161224484
# Epoch 801/1600 Done, Total Loss: 0.0067328112199902534
# Epoch 802/1600 Done, Total Loss: 0.0067148597445338964
# Epoch 803/1600 Done, Total Loss: 0.00663902738597244
# Epoch 804/1600 Done, Total Loss: 0.006617122911848128
# Epoch 805/1600 Done, Total Loss: 0.006611644057556987
# Epoch 806/1600 Done, Total Loss: 0.00654385460074991
# Epoch 807/1600 Done, Total Loss: 0.0065086387330666184
# Epoch 808/1600 Done, Total Loss: 0.006478132214397192
# Epoch 809/1600 Done, Total Loss: 0.0064842430874705315
# Epoch 810/1600 Done, Total Loss: 0.006448531523346901
# Epoch 811/1600 Done, Total Loss: 0.006387001019902527
# Epoch 812/1600 Done, Total Loss: 0.0063438210636377335
# Epoch 813/1600 Done, Total Loss: 0.006351358839310706
# Epoch 814/1600 Done, Total Loss: 0.006370331393554807
# Epoch 815/1600 Done, Total Loss: 0.00629818276502192
# Epoch 816/1600 Done, Total Loss: 0.006220722454600036
# Epoch 817/1600 Done, Total Loss: 0.006233342457562685
# Epoch 818/1600 Done, Total Loss: 0.006192164262756705
# Epoch 819/1600 Done, Total Loss: 0.006136806448921561
# Epoch 820/1600 Done, Total Loss: 0.006096952478401363
# Epoch 821/1600 Done, Total Loss: 0.00612798728980124
# Epoch 822/1600 Done, Total Loss: 0.006046055816113949
# Epoch 823/1600 Done, Total Loss: 0.006030254298821092
# Epoch 824/1600 Done, Total Loss: 0.006039737723767757
# Epoch 825/1600 Done, Total Loss: 0.005953513900749385
# Epoch 826/1600 Done, Total Loss: 0.005938055808655918
# Epoch 827/1600 Done, Total Loss: 0.005940921837463975
# Epoch 828/1600 Done, Total Loss: 0.005925158970057964
# Epoch 829/1600 Done, Total Loss: 0.005844371393322945
# Epoch 830/1600 Done, Total Loss: 0.005834209267050028
# Epoch 831/1600 Done, Total Loss: 0.00578586698975414
# Epoch 832/1600 Done, Total Loss: 0.005752157303504646
# Epoch 833/1600 Done, Total Loss: 0.005737789208069444
# Epoch 834/1600 Done, Total Loss: 0.005700140725821257
# Epoch 835/1600 Done, Total Loss: 0.0056959668872877955
# Epoch 836/1600 Done, Total Loss: 0.005656830850057304
# Epoch 837/1600 Done, Total Loss: 0.005698628257960081
# Epoch 838/1600 Done, Total Loss: 0.005614162073470652
# Epoch 839/1600 Done, Total Loss: 0.005608653649687767
# Epoch 840/1600 Done, Total Loss: 0.005550924455747008
# Epoch 841/1600 Done, Total Loss: 0.005606987746432424
# Epoch 842/1600 Done, Total Loss: 0.005528639070689678
# Epoch 843/1600 Done, Total Loss: 0.005508511210791767
# Epoch 844/1600 Done, Total Loss: 0.005484947934746742
# Epoch 845/1600 Done, Total Loss: 0.00542981387116015
# Epoch 846/1600 Done, Total Loss: 0.005414661252871156
# Epoch 847/1600 Done, Total Loss: 0.0053882134379819036
# Epoch 848/1600 Done, Total Loss: 0.0053744560573250055
# Epoch 849/1600 Done, Total Loss: 0.005320685217157006
# Epoch 850/1600 Done, Total Loss: 0.005375476321205497
# Epoch 851/1600 Done, Total Loss: 0.005325885256752372
# Epoch 852/1600 Done, Total Loss: 0.005264031235128641
# Epoch 853/1600 Done, Total Loss: 0.005237290868535638
# Epoch 854/1600 Done, Total Loss: 0.005210462375544012
# Epoch 855/1600 Done, Total Loss: 0.0051954323425889015
# Epoch 856/1600 Done, Total Loss: 0.005230191629379988
# Epoch 857/1600 Done, Total Loss: 0.005177914630621672
# Epoch 858/1600 Done, Total Loss: 0.005126216448843479
# Epoch 1590/1600 Done, Total Loss: 0.0012276690686121583
# Epoch 1591/1600 Done, Total Loss: 0.001212318951729685
# Epoch 1592/1600 Done, Total Loss: 0.001207052730023861
# Epoch 1593/1600 Done, Total Loss: 0.0012053238460794091
# Epoch 1594/1600 Done, Total Loss: 0.0012045538169331849
# Epoch 1595/1600 Done, Total Loss: 0.0012000533461105078
# Epoch 1596/1600 Done, Total Loss: 0.0012117382430005819
# Epoch 1597/1600 Done, Total Loss: 0.0012075272388756275
# Epoch 1598/1600 Done, Total Loss: 0.0012192220310680568
# Epoch 1599/1600 Done, Total Loss: 0.0011935791990254074
# MLNet(
#   (fcnn1): Sequential(
#     (0): Linear(in_features=1, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=1, bias=True)
#   )
# )
# layer1, weights:  Parameter containing:
# tensor([[ 0.7223],
#         [-1.0996],
#         [ 0.1966],
#         [-0.0359],
#         [-1.0216],
#         [-0.8025],
#         [-0.0603],
#         [-0.8868],
#         [ 0.7485],
#         [-0.6691],
#         [ 0.3332],
#         [-0.2228],
#         [-0.2053],
#         [-0.8618],
#         [ 0.6655],
#         [-0.8423]], requires_grad=True)
# layer1, bias:  Parameter containing:
# tensor([-1.6061, -1.4094, -0.9499,  0.7656,  1.1969, -0.7315,  0.8053,  0.7009,
#         -1.5750, -1.3115, -0.5623, -0.7397, -0.8742,  1.1129, -0.3452,  1.0163],
#        requires_grad=True)
# layer3, weights:  Parameter containing:
# tensor([[-0.6276,  0.5951,  0.0781,  0.3392, -0.3326,  0.3472,  0.4042, -0.1512,
#          -0.3474,  1.1299, -0.1493, -0.0763, -0.0572, -0.1560, -0.1001, -0.3677]],
#        requires_grad=True)
# layer3, bias:  Parameter containing:
# tensor([0.4788], requires_grad=True)

# %%
###############################################Modified Code to 3D#####################################################
# Import matplotlib for plotting purposes
import matplotlib
matplotlib.rcParams["text.usetex"] = True
import matplotlib.pyplot as plt

# Sometimes, we need Numpy, but wherever possible, we prefer torch.
import numpy as np

# Import PyTorch
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# Float (32 bit) or Double (64 bit) precision? Choose!
torch.set_default_dtype(torch.float32)#64)
torch.set_num_threads(4) # Use _maximally_ 4 CPU cores


#device = torch.device("cpu")
# Choose a device for major calculations (if there is a special GPU card, you usually want that).
# My GPU is not very performant for double precision, so I stay on CPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
device = torch.device(device)

# File path for saving the trained NN later.
# If only providing the file name (like here), the file will be generated in the same folder as the Python script
model_file = "mymodel.torch"

## The following script shows a data-driven training of a Neural Network.
## The data is generated in this script, too, by sampling from a function.
## The variables below are used to control this sampling
samples = 16
sample_min = -5
sample_max = 5
sample_span = sample_max - sample_min

## These parameters are usual hyperparameters of the NN and its training.
batch_size = 8 # How many samples shall be presented to the NN, before running another optimizer step?
hidden_dim = 16 # How many neurons shall there be in the hidden layer(s)?
input_dim = 2 # Input dimension of the NN (i.e. how many neurons are in the input layer?)
output_dim = 1 # Some for output

epochs = 1600 # Number of training iterations to be performed
lr = 0.001 # Which learning rate is passed to the training algorithm?

## Choose a criterion to evaluate the results. Here, we choose Mean Square error.
## The term "loss" means about the same as "remaining error" or "residual".
criterion = nn.MSELoss(reduction="mean")

## Here, we create the training data. In this example, we draw samples within the sampling interval and then pass it to
## e.g. the sin function (choose other functions to experiment with this script)
train_x = (sample_span * torch.rand(samples, 2) + sample_min * torch.ones(samples, 2))
train_y = torch.sin(train_x[:, 0]) + torch.cos(train_x[:, 1]) ##torch.pow(test_x, 2)

print ("train_x", train_x)
print ("train_y", train_y)

## Here, we create the test data. To show the effect of extrapolation and the detailed behavior of the NN,
## we choose points a bit outside the interval that we used for sampling training data. Also, we very dense points.
# test_x = torch.zeros(20*samples, 2)
# test_x[:, 0] = torch.linspace(sample_min - 0.5*sample_span, sample_max + 0.5*sample_span, test_x.size()[0])
# test_x[:, 1] = torch.linspace(sample_min - 0.5*sample_span, sample_max + 0.5*sample_span, test_x.size()[0])

# create test_x with meshgrid
grid_size = int(samples ** 0.5) * 2 
x1 = torch.linspace(sample_min - 0.5*sample_span, sample_max + 0.5*sample_span, 2*samples)
x2 = torch.linspace(sample_min - 0.5*sample_span, sample_max + 0.5*sample_span, 2*samples)
x1, x2 = torch.meshgrid(x1, x2)
test_x = torch.zeros(2*samples*2*samples, 2)
test_x[:, 0] = x1.reshape(-1)
test_x[:, 1] = x2.reshape(-1)
test_y = torch.sin(test_x[:, 0]) + torch.cos(test_x[:, 1]) ##torch.pow(test_x, 2)

## We want a DataLoader to handle batching and shuffling of the training data for us.
## The DataLoader needs a TensorDataset, hence we create one from the Training data.
train_data = TensorDataset(train_x, train_y)
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, drop_last=False)


## This class creates the actual Neural Network.
class MLNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MLNet, self).__init__()
        self.hidden_dim = hidden_dim

        ## In this case, I decided to pack the layers into a single container of type nn.Sequential
        ## This container is useful for Fully Connected NNs, where the output of each layer is just fed into the following layer.
        self.fcnn1 = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            #nn.Tanh(),
            nn.ReLU(),
            #nn.Linear(hidden_dim, hidden_dim),
            #nn.ReLU(),
            #nn.Linear(hidden_dim, hidden_dim),
            #nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
        ) ## That network here has exactly 1 hidden layer (comment out some lines or write new ones to add more layers)
        ## nn.Linear is in the pictures represented by the arrows and has the weights (and biases) which are the
        ## parameters of the NN.
        ## nn.ReLU and Tanh are examples for activation functions - in the pictures, these are the bubbles / neurons.
        ## Usually, the pattern is interchanging between one linear layer, one activation function, one linear layer, one activation function and so on

    ## It is required to write a function that is executed when calling the NN model.
    ## Usually, it takes the input data and passes it through the layers.
    ## Here, it is sufficient to call the sequential container since this container does exactly this job.
    ## But this function "forward" could also be used to set up more complex NN architectures with more complex data flows
    def forward(self, x):
        out = self.fcnn1(x)
        return out

## This function performs a test run with the NN.
## It takes the NN model and the test data, passes the test inputs through the network and
## compares it with the target values = test outputs = targets
## and based on that calculates the loss value
def evaluate(model, test_x, test_y):
    ## For testing, we don't need the autograd feature/ protocol of all calculation steps
    ## So, save some time and disable grad tracking.
    with torch.no_grad():
        model.eval() ## Set the NN model into evaluation mode
        outputs = [] ## Create empty lists to store the results
        targets = []
        testlosses = []

        out = model(test_x.to(device)) ## Call the model, i.e. perform the actual inference

        ## Move the output quantities to the CPU, detach them from the tensor operation book-keeping and convert them to numpy arrays/ vectors.
        ## This is all necessary for plotting
        outputs.append(out.cpu().detach().numpy())
        targets.append(test_y.cpu().detach().numpy())
        testlosses.append(criterion(out, test_y.to(device)).item())

    ## Now return that in form of a triple of variables
    return outputs, targets, testlosses

## This calls the evaluate function and takes care of the plotting.
def eval_and_plot(model):
        ## matplotlib tries to be similar to the plot functions of matlab  (admittedly, the commands have to begin with "plt.", but the rest
        ## is quite similar.)
        '''
        plt.subplot(1, 1, 1)

        ## Call the network on the test data
        net_outputs_test, targets_test, testlosses = evaluate(model, test_x, test_y)
        # Plot the targets first in blue (which means to plot the actual function over the whole test interval)
        plt.plot(test_x, targets_test[0], "-x", color="b", label="Target")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.legend()

        ## Call the network on the training data
        net_outputs_train, targets_train, testlosses = evaluate(model, train_x, train_y)
        ## First, plot the targets in red, i.e. plot the training data set
        plt.plot(train_x, targets_train[0], "^", color="r", label="Target")

        ## Now, plot the output of the NN on the whole test interval in green
        ## This allows us to see how the NN performs for interpolation as well as for extrapolation
        plt.plot(test_x, net_outputs_test[0], "-o", color="g", label="Learned")

        ## All plotting is done, open the plot window
        plt.show()
        '''
        # create a 3D plot
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')

        ## Call the network on the test data
        net_outputs_test, targets_test, testlosses = evaluate(model, test_x, test_y)   
        # Plot the targets first in blue (which means to plot the actual function over the whole test interval)
        #ax.plot(test_x[:, 0], test_x[:, 1], targets_test[0], color="-b", label="Target")
        ax.scatter(test_x[:, 0], test_x[:, 1], targets_test[0], c='b', marker='x', label='Target')
        ax.set_xlabel('x1')
        ax.set_ylabel('x2')
        ax.set_zlabel('y')

        ## Call the network on the training data
        net_outputs_train, targets_train, testlosses = evaluate(model, train_x, train_y)
        ## First, plot the targets in red, i.e. plot the training data set
        ax.scatter(train_x[:, 0], train_x[:, 1], targets_train[0], c='r', s=100, marker='^', label='Target')

        ## Now, plot the output of the NN on the whole test interval in green
        ## This allows us to see how the NN performs for interpolation as well as for extrapolation
        ax.scatter(test_x[:, 0], test_x[:, 1], net_outputs_test[0].reshape(-1), c='g', marker='o', label='Learned')
        print("net_outputs_test[0]", net_outputs_test[0].reshape(-1))

        ## All plotting is done, open the plot window
        plt.show()



## That function takes care of the whole training
def train(train_loader, learn_rate, EPOCHS):  # 10):

    # Instantiate the NN
    model = MLNet(input_dim, hidden_dim, output_dim)
    model.to(device) # and move it to the "device" (in case we use a GPU)

    ## Choose an optimizer. Adam is quite robust and thus very popular. Technically, it's based on
    ## gradient descent, but mixes in the gradient of the last time step to improve robustness.
    ## It is given the model parameters, which are the weights and biases of the Linear layers
    ## and the learn_rate.
    optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)
    print("Starting Training of the model")

    # We want to keep track of the losses averaged over each epoch, to plot them in those famous
    # decreasing graphs
    avg_losses = torch.zeros(EPOCHS)

    ## In the end, epoch is just another word for "training iteration", so we have a simple for loop.
    for epoch in range(EPOCHS):
        model.train() # Set the model into train mode
        avg_loss = 0. # initializations
        counter = 0

        ## DataLoader is iterable so that this for-loop loops over the batches of the training data set
        ## and the DataLoader gives us readily paired combinations of training inputs and targets (which are called x and label, here).
        ## The term "label" is more common in classification, but used for all supervised training tasks
        for x, label in train_loader:
            counter += 1 # We count, how many batches we did within the current epoch
            model.zero_grad() # Important: reset the gradients of the NN before passing the training inputs.
            # Otherwise, we would accumulate the gradient information which might ruin the results
            # or simply run into PyTorch exceptions

            ## Now, we can call the model on the training inputs.
            ## Therefor, we move that data to the device (just in case we use a GPU).
            out = model(x.to(device))
            out = out.squeeze(-1) ## The output is a tensor of shape (batch_size, 1), but we want to have a tensor of shape (batch_size)
            loss = criterion(out, label.to(device)) # Now, calculate the loss value

            ## Here, the whole magic happens:
            ## PyTorch offers the autograd feature, i.e. calculations on tensors are tracked (there are exceptions, e.g.
            ## this is not possible for in-place operations). This allows to calculate the derivative of each output value
            ## w.r.t. all input values (its "gradient").
            ## In this case, we want to know the derivatives of the loss value w.r.t. all the NN parameters (weights and biases).
            ## Our optimizers are usually based on "Gradient Descent", so we need the gradients...
            loss.backward()
            ## Alright, now let the optimizer do the magic.
            ## We passed the optimizer the NN parameters by reference when we initialized the optimizer.
            ## And the gradient information is stored in the tensors of the parameters, too (not in the loss or so).
            ## That's why the step() function does not require any arguments.
            optimizer.step()

            ## For the plot at the end, save the loss values
            avg_loss += loss.item()

            if counter % 20 == 0:
                print("Epoch {}......Step: {}/{}....... Average Loss for Epoch: {} = {} + {}".format(epoch, counter,
                                                                                                len(train_loader),
                                                                                                avg_loss / counter, loss.item(), 0))
        print("Epoch {}/{} Done, Total Loss: {}".format(epoch, EPOCHS, avg_loss / len(train_loader)))
        ## It's an average loss, so divide by the number of samples/ size of the training data set
        avg_losses[epoch] = avg_loss / len(train_loader)

        ## To understand how the NN learns, all 500 epochs a plot is shown (Close the plot window and wait for the next plot)
        if epoch%500 == 0:
            eval_and_plot(model)

    ## This plots the loss curve
    plt.figure(figsize=(12, 8))
    plt.plot(avg_losses, "x-")
    plt.title("Train loss (MSE, reduction=mean, averaged over epoch)")
    plt.xlabel("Epoch")
    plt.ylabel("loss")
    plt.grid(visible=True, which='both', axis='both')
    plt.show()

    ## Now save the trained model with all its properties to the model_file
    torch.save(model, model_file)

    ## And return the model in case we want to use it for other tasks
    return model


## As the functions written before are just function definitions,
## those functions still have to be called.
## This is done here.
## Train the model
model = train(train_loader, lr, epochs)

## Test that saving the model worked: load it from file
model = torch.load(model_file)
## and evaluate and plot once
eval_and_plot(model)

print(model)
'''
print("layer1, weights: ", model.layer1.weight)
print("layer1, bias: ", model.layer1.bias)
#print(model.layer2.weight)
#print(model.layer2.bias)
print("layer3, weights: ", model.layer3.weight)
print("layer3, bias: ", model.layer3.bias)
'''

print("layer1, weights: ", model.fcnn1[0].weight)
print("layer1, bias: ", model.fcnn1[0].bias)
# Uncomment and adapt these for additional layers if needed
# print("layer2, weights: ", model.fcnn1[2].weight)
# print("layer2, bias: ", model.fcnn1[2].bias)
print("layer3, weights: ", model.fcnn1[-1].weight)
print("layer3, bias: ", model.fcnn1[-1].bias)
# Out:
# Using cpu device
# train_x tensor([[ 0.0099,  0.2430],
#         [-2.4512,  0.7878],
#         [-3.5710,  0.9390],
#         [ 0.5262, -0.8688],
#         [ 1.5223,  1.7019],
#         [-3.7838,  3.3796],
#         [-3.7818, -2.7541],
#         [-3.2159,  4.2055],
#         [ 0.3394,  1.8394],
#         [-0.0240,  0.1823],
#         [-1.4679, -0.0934],
#         [ 4.4912, -1.3345],
#         [-0.7395, -0.4608],
#         [-0.6926,  1.7499],
#         [ 4.0742, -4.3001],
#         [ 4.2997, -3.7344]])
# train_y tensor([ 9.8054e-01,  6.8526e-02,  1.0069e+00,  1.1480e+00,  8.6811e-01,
#         -3.7287e-01, -3.2853e-01, -4.1126e-01,  6.7608e-02,  9.5948e-01,
#          9.3293e-04, -7.4153e-01,  2.2173e-01, -8.1668e-01, -1.2039e+00,
#         -1.7454e+00])
# Starting Training of the model
# Epoch 0/1600 Done, Total Loss: 1.0183522701263428
# net_outputs_test[0] [-0.35421503 -0.22612894 -0.09804296 ...  1.381519    1.4795855
#   1.5824754 ]
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_581jc0ddx6/croot/pytorch-select_1730848714937/work/aten/src/ATen/native/TensorShape.cpp:3588.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1024])) that is different to the input size (torch.Size([1024, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/1600 Done, Total Loss: 0.977780357003212
# Epoch 2/1600 Done, Total Loss: 0.9358969032764435
# Epoch 3/1600 Done, Total Loss: 0.9055965095758438
# Epoch 4/1600 Done, Total Loss: 0.8677418828010559
# Epoch 5/1600 Done, Total Loss: 0.8394968211650848
# Epoch 6/1600 Done, Total Loss: 0.8145428001880646
# Epoch 7/1600 Done, Total Loss: 0.7827876806259155
# Epoch 8/1600 Done, Total Loss: 0.7565325200557709
# Epoch 9/1600 Done, Total Loss: 0.7403048127889633
# Epoch 10/1600 Done, Total Loss: 0.7121182382106781
# Epoch 11/1600 Done, Total Loss: 0.6895551681518555
# Epoch 12/1600 Done, Total Loss: 0.6696915626525879
# Epoch 13/1600 Done, Total Loss: 0.6514735519886017
# Epoch 14/1600 Done, Total Loss: 0.6331761181354523
# Epoch 15/1600 Done, Total Loss: 0.6222288012504578
# Epoch 16/1600 Done, Total Loss: 0.6065074503421783
# Epoch 17/1600 Done, Total Loss: 0.5956926345825195
# Epoch 18/1600 Done, Total Loss: 0.5833255052566528
# Epoch 19/1600 Done, Total Loss: 0.5731412768363953
# Epoch 20/1600 Done, Total Loss: 0.5590401738882065
# Epoch 21/1600 Done, Total Loss: 0.5528029948472977
# Epoch 22/1600 Done, Total Loss: 0.5448275655508041
# Epoch 23/1600 Done, Total Loss: 0.537565067410469
# Epoch 24/1600 Done, Total Loss: 0.5255146026611328
# Epoch 25/1600 Done, Total Loss: 0.5177116096019745
# Epoch 26/1600 Done, Total Loss: 0.5124754011631012
# Epoch 27/1600 Done, Total Loss: 0.5035733431577682
# Epoch 28/1600 Done, Total Loss: 0.4977602958679199
# Epoch 29/1600 Done, Total Loss: 0.49177388846874237
# Epoch 30/1600 Done, Total Loss: 0.4869154393672943
# Epoch 31/1600 Done, Total Loss: 0.48114198446273804
# Epoch 32/1600 Done, Total Loss: 0.4743717312812805
# Epoch 33/1600 Done, Total Loss: 0.46889999508857727
# Epoch 34/1600 Done, Total Loss: 0.46471405029296875
# Epoch 35/1600 Done, Total Loss: 0.45865069329738617
# Epoch 36/1600 Done, Total Loss: 0.454613134264946
# Epoch 37/1600 Done, Total Loss: 0.44969572126865387
# Epoch 38/1600 Done, Total Loss: 0.4452814310789108
# Epoch 39/1600 Done, Total Loss: 0.44060617685317993
# Epoch 40/1600 Done, Total Loss: 0.4363969713449478
# Epoch 41/1600 Done, Total Loss: 0.4319518953561783
# Epoch 42/1600 Done, Total Loss: 0.4292561262845993
# Epoch 43/1600 Done, Total Loss: 0.4240615963935852
# Epoch 44/1600 Done, Total Loss: 0.4203772395849228
# Epoch 45/1600 Done, Total Loss: 0.4175163060426712
# Epoch 46/1600 Done, Total Loss: 0.4129662662744522
# Epoch 47/1600 Done, Total Loss: 0.41049376130104065
# Epoch 48/1600 Done, Total Loss: 0.40589678287506104
# Epoch 49/1600 Done, Total Loss: 0.40285487473011017
# Epoch 50/1600 Done, Total Loss: 0.3996451795101166
# Epoch 51/1600 Done, Total Loss: 0.39659638702869415
# Epoch 52/1600 Done, Total Loss: 0.39281633496284485
# Epoch 53/1600 Done, Total Loss: 0.38964326679706573
# Epoch 54/1600 Done, Total Loss: 0.3865419924259186
# Epoch 55/1600 Done, Total Loss: 0.3833628296852112
# Epoch 56/1600 Done, Total Loss: 0.3803325593471527
# Epoch 57/1600 Done, Total Loss: 0.37784990668296814
# Epoch 58/1600 Done, Total Loss: 0.3752559423446655
# Epoch 59/1600 Done, Total Loss: 0.37248463928699493
# Epoch 60/1600 Done, Total Loss: 0.36994271725416183
# Epoch 61/1600 Done, Total Loss: 0.3672402799129486
# Epoch 62/1600 Done, Total Loss: 0.36486008763313293
# Epoch 63/1600 Done, Total Loss: 0.3624233268201351
# Epoch 64/1600 Done, Total Loss: 0.35992030799388885
# Epoch 65/1600 Done, Total Loss: 0.3571871966123581
# Epoch 66/1600 Done, Total Loss: 0.35478486120700836
# Epoch 67/1600 Done, Total Loss: 0.3531128466129303
# Epoch 68/1600 Done, Total Loss: 0.350690022110939
# Epoch 69/1600 Done, Total Loss: 0.34884462505578995
# Epoch 70/1600 Done, Total Loss: 0.34666258096694946
# Epoch 71/1600 Done, Total Loss: 0.34484878182411194
# Epoch 72/1600 Done, Total Loss: 0.3429293632507324
# Epoch 73/1600 Done, Total Loss: 0.34087975323200226
# Epoch 74/1600 Done, Total Loss: 0.3388662487268448
# Epoch 75/1600 Done, Total Loss: 0.3370738625526428
# Epoch 76/1600 Done, Total Loss: 0.33501283824443817
# Epoch 77/1600 Done, Total Loss: 0.33328618109226227
# Epoch 78/1600 Done, Total Loss: 0.3313683941960335
# Epoch 79/1600 Done, Total Loss: 0.3301890641450882
# Epoch 80/1600 Done, Total Loss: 0.3280148059129715
# Epoch 81/1600 Done, Total Loss: 0.32653510570526123
# Epoch 82/1600 Done, Total Loss: 0.3250102996826172
# Epoch 83/1600 Done, Total Loss: 0.32328277826309204
# Epoch 84/1600 Done, Total Loss: 0.3216020315885544
# Epoch 85/1600 Done, Total Loss: 0.3196933940052986
# Epoch 86/1600 Done, Total Loss: 0.31790217012166977
# Epoch 87/1600 Done, Total Loss: 0.3166390508413315
# Epoch 88/1600 Done, Total Loss: 0.3155529126524925
# Epoch 89/1600 Done, Total Loss: 0.3135765641927719
# Epoch 90/1600 Done, Total Loss: 0.3120482265949249
# Epoch 91/1600 Done, Total Loss: 0.3109769895672798
# Epoch 92/1600 Done, Total Loss: 0.3093988448381424
# Epoch 93/1600 Done, Total Loss: 0.30786895751953125
# Epoch 94/1600 Done, Total Loss: 0.30668503046035767
# Epoch 95/1600 Done, Total Loss: 0.30528518557548523
# Epoch 96/1600 Done, Total Loss: 0.3035633824765682
# Epoch 97/1600 Done, Total Loss: 0.30256175994873047
# Epoch 98/1600 Done, Total Loss: 0.30137114226818085
# Epoch 99/1600 Done, Total Loss: 0.2995401471853256
# Epoch 100/1600 Done, Total Loss: 0.29860618710517883
# Epoch 101/1600 Done, Total Loss: 0.2975558787584305
# Epoch 102/1600 Done, Total Loss: 0.29620298743247986
# Epoch 103/1600 Done, Total Loss: 0.2947179786860943
# Epoch 104/1600 Done, Total Loss: 0.2935134842991829
# Epoch 105/1600 Done, Total Loss: 0.2922009155154228
# Epoch 106/1600 Done, Total Loss: 0.2913988083600998
# Epoch 107/1600 Done, Total Loss: 0.2898608148097992
# Epoch 108/1600 Done, Total Loss: 0.2886853441596031
# Epoch 109/1600 Done, Total Loss: 0.28743376582860947
# Epoch 110/1600 Done, Total Loss: 0.28636762499809265
# Epoch 111/1600 Done, Total Loss: 0.28550609946250916
# Epoch 112/1600 Done, Total Loss: 0.2842158079147339
# Epoch 113/1600 Done, Total Loss: 0.28316637873649597
# Epoch 114/1600 Done, Total Loss: 0.2818175405263901
# Epoch 115/1600 Done, Total Loss: 0.28056080639362335
# Epoch 116/1600 Done, Total Loss: 0.27963627874851227
# Epoch 117/1600 Done, Total Loss: 0.278225302696228
# Epoch 118/1600 Done, Total Loss: 0.2774302288889885
# Epoch 119/1600 Done, Total Loss: 0.27656129002571106
# Epoch 120/1600 Done, Total Loss: 0.2753562480211258
# Epoch 121/1600 Done, Total Loss: 0.27432963997125626
# Epoch 122/1600 Done, Total Loss: 0.2731216177344322
# Epoch 123/1600 Done, Total Loss: 0.272329680621624
# Epoch 124/1600 Done, Total Loss: 0.2713749259710312
# Epoch 125/1600 Done, Total Loss: 0.27009396627545357
# Epoch 126/1600 Done, Total Loss: 0.26920565217733383
# Epoch 127/1600 Done, Total Loss: 0.2682463452219963
# Epoch 128/1600 Done, Total Loss: 0.2673637419939041
# Epoch 129/1600 Done, Total Loss: 0.2662610039114952
# Epoch 130/1600 Done, Total Loss: 0.2652840241789818
# Epoch 131/1600 Done, Total Loss: 0.2641737163066864
# Epoch 132/1600 Done, Total Loss: 0.26330940425395966
# Epoch 133/1600 Done, Total Loss: 0.2624279707670212
# Epoch 134/1600 Done, Total Loss: 0.2613721489906311
# Epoch 135/1600 Done, Total Loss: 0.2605136036872864
# Epoch 136/1600 Done, Total Loss: 0.25944068282842636
# Epoch 137/1600 Done, Total Loss: 0.25857603549957275
# Epoch 138/1600 Done, Total Loss: 0.25812650471925735
# Epoch 139/1600 Done, Total Loss: 0.25677667558193207
# Epoch 140/1600 Done, Total Loss: 0.25566721707582474
# Epoch 141/1600 Done, Total Loss: 0.2549627982079983
# Epoch 142/1600 Done, Total Loss: 0.2543923780322075
# Epoch 143/1600 Done, Total Loss: 0.2533842697739601
# Epoch 144/1600 Done, Total Loss: 0.25246597081422806
# Epoch 145/1600 Done, Total Loss: 0.25170689821243286
# Epoch 146/1600 Done, Total Loss: 0.2507376968860626
# Epoch 147/1600 Done, Total Loss: 0.2498536854982376
# Epoch 148/1600 Done, Total Loss: 0.2492150440812111
# Epoch 149/1600 Done, Total Loss: 0.24824558198451996
# Epoch 150/1600 Done, Total Loss: 0.2476462423801422
# Epoch 151/1600 Done, Total Loss: 0.24675096571445465
# Epoch 152/1600 Done, Total Loss: 0.24566374346613884
# Epoch 153/1600 Done, Total Loss: 0.2449677586555481
# Epoch 154/1600 Done, Total Loss: 0.24395273625850677
# Epoch 155/1600 Done, Total Loss: 0.24340655654668808
# Epoch 156/1600 Done, Total Loss: 0.24274631589651108
# Epoch 157/1600 Done, Total Loss: 0.2419157475233078
# Epoch 158/1600 Done, Total Loss: 0.24120239913463593
# Epoch 159/1600 Done, Total Loss: 0.24021171033382416
# Epoch 160/1600 Done, Total Loss: 0.23937705159187317
# Epoch 161/1600 Done, Total Loss: 0.23863117396831512
# Epoch 162/1600 Done, Total Loss: 0.23783068358898163
# Epoch 163/1600 Done, Total Loss: 0.23743561655282974
# Epoch 164/1600 Done, Total Loss: 0.23650161176919937
# Epoch 165/1600 Done, Total Loss: 0.2356795370578766
# Epoch 166/1600 Done, Total Loss: 0.2350052148103714
# Epoch 167/1600 Done, Total Loss: 0.23409859091043472
# Epoch 168/1600 Done, Total Loss: 0.23355072736740112
# Epoch 169/1600 Done, Total Loss: 0.23285465687513351
# Epoch 170/1600 Done, Total Loss: 0.23228082805871964
# Epoch 171/1600 Done, Total Loss: 0.23160478472709656
# Epoch 172/1600 Done, Total Loss: 0.23054489493370056
# Epoch 173/1600 Done, Total Loss: 0.22989021986722946
# Epoch 174/1600 Done, Total Loss: 0.22924742847681046
# Epoch 175/1600 Done, Total Loss: 0.22851040959358215
# Epoch 176/1600 Done, Total Loss: 0.22797078639268875
# Epoch 177/1600 Done, Total Loss: 0.22770412266254425
# Epoch 178/1600 Done, Total Loss: 0.2267303615808487
# Epoch 179/1600 Done, Total Loss: 0.22569214925169945
# Epoch 180/1600 Done, Total Loss: 0.2254038229584694
# Epoch 181/1600 Done, Total Loss: 0.22484783083200455
# Epoch 182/1600 Done, Total Loss: 0.22411684691905975
# Epoch 183/1600 Done, Total Loss: 0.22341106086969376
# Epoch 184/1600 Done, Total Loss: 0.22246331721544266
# Epoch 185/1600 Done, Total Loss: 0.2219710797071457
# Epoch 186/1600 Done, Total Loss: 0.22124701738357544
# Epoch 187/1600 Done, Total Loss: 0.22060927748680115
# Epoch 188/1600 Done, Total Loss: 0.2201487496495247
# Epoch 189/1600 Done, Total Loss: 0.21939752250909805
# Epoch 190/1600 Done, Total Loss: 0.21894998848438263
# Epoch 191/1600 Done, Total Loss: 0.21801943704485893
# Epoch 192/1600 Done, Total Loss: 0.21758093684911728
# Epoch 193/1600 Done, Total Loss: 0.21699709445238113
# Epoch 194/1600 Done, Total Loss: 0.21621455252170563
# Epoch 195/1600 Done, Total Loss: 0.21551909297704697
# Epoch 196/1600 Done, Total Loss: 0.21519692242145538
# Epoch 197/1600 Done, Total Loss: 0.21433397382497787
# Epoch 198/1600 Done, Total Loss: 0.21396561712026596
# Epoch 199/1600 Done, Total Loss: 0.21319260448217392
# Epoch 200/1600 Done, Total Loss: 0.21261245757341385
# Epoch 201/1600 Done, Total Loss: 0.21221067011356354
# Epoch 202/1600 Done, Total Loss: 0.21161630004644394
# Epoch 203/1600 Done, Total Loss: 0.21085841953754425
# Epoch 204/1600 Done, Total Loss: 0.21039242297410965
# Epoch 205/1600 Done, Total Loss: 0.209926038980484
# Epoch 206/1600 Done, Total Loss: 0.20899857953190804
# Epoch 207/1600 Done, Total Loss: 0.20857983082532883
# Epoch 208/1600 Done, Total Loss: 0.20812251791357994
# Epoch 209/1600 Done, Total Loss: 0.20750734955072403
# Epoch 210/1600 Done, Total Loss: 0.20682191103696823
# Epoch 211/1600 Done, Total Loss: 0.20625713467597961
# Epoch 212/1600 Done, Total Loss: 0.2056807316839695
# Epoch 213/1600 Done, Total Loss: 0.20541396737098694
# Epoch 214/1600 Done, Total Loss: 0.20462773740291595
# Epoch 215/1600 Done, Total Loss: 0.20411645621061325
# Epoch 216/1600 Done, Total Loss: 0.20370537042617798
# Epoch 217/1600 Done, Total Loss: 0.20337536185979843
# Epoch 218/1600 Done, Total Loss: 0.20244190841913223
# Epoch 219/1600 Done, Total Loss: 0.20224998146295547
# Epoch 220/1600 Done, Total Loss: 0.20126621425151825
# Epoch 221/1600 Done, Total Loss: 0.201011061668396
# Epoch 222/1600 Done, Total Loss: 0.20042836666107178
# Epoch 223/1600 Done, Total Loss: 0.19972046464681625
# Epoch 224/1600 Done, Total Loss: 0.19933601468801498
# Epoch 225/1600 Done, Total Loss: 0.19874773174524307
# Epoch 226/1600 Done, Total Loss: 0.19812442362308502
# Epoch 227/1600 Done, Total Loss: 0.19774524122476578
# Epoch 228/1600 Done, Total Loss: 0.19714423641562462
# Epoch 229/1600 Done, Total Loss: 0.1966899037361145
# Epoch 230/1600 Done, Total Loss: 0.19602423161268234
# Epoch 231/1600 Done, Total Loss: 0.19564615935087204
# Epoch 232/1600 Done, Total Loss: 0.19507898204028606
# Epoch 233/1600 Done, Total Loss: 0.19483904540538788
# Epoch 234/1600 Done, Total Loss: 0.19412917271256447
# Epoch 235/1600 Done, Total Loss: 0.19337989389896393
# Epoch 236/1600 Done, Total Loss: 0.19295159727334976
# Epoch 237/1600 Done, Total Loss: 0.19275067001581192
# Epoch 238/1600 Done, Total Loss: 0.19214586168527603
# Epoch 239/1600 Done, Total Loss: 0.19188546389341354
# Epoch 240/1600 Done, Total Loss: 0.19132991135120392
# Epoch 241/1600 Done, Total Loss: 0.19044318795204163
# Epoch 242/1600 Done, Total Loss: 0.19010470807552338
# Epoch 243/1600 Done, Total Loss: 0.18955937027931213
# Epoch 244/1600 Done, Total Loss: 0.18900342658162117
# Epoch 245/1600 Done, Total Loss: 0.18861068040132523
# Epoch 246/1600 Done, Total Loss: 0.18819982931017876
# Epoch 247/1600 Done, Total Loss: 0.18758171796798706
# Epoch 248/1600 Done, Total Loss: 0.1872118040919304
# Epoch 249/1600 Done, Total Loss: 0.18663379549980164
# Epoch 250/1600 Done, Total Loss: 0.1863912269473076
# Epoch 251/1600 Done, Total Loss: 0.18602193146944046
# Epoch 252/1600 Done, Total Loss: 0.18547165393829346
# Epoch 253/1600 Done, Total Loss: 0.18483629450201988
# Epoch 254/1600 Done, Total Loss: 0.18451041728258133
# Epoch 255/1600 Done, Total Loss: 0.1836269497871399
# Epoch 256/1600 Done, Total Loss: 0.18326803296804428
# Epoch 257/1600 Done, Total Loss: 0.1827257238328457
# Epoch 258/1600 Done, Total Loss: 0.18235092610120773
# Epoch 259/1600 Done, Total Loss: 0.1818295568227768
# Epoch 260/1600 Done, Total Loss: 0.1813056729733944
# Epoch 261/1600 Done, Total Loss: 0.18084310367703438
# Epoch 262/1600 Done, Total Loss: 0.1805344894528389
# Epoch 263/1600 Done, Total Loss: 0.179877370595932
# Epoch 264/1600 Done, Total Loss: 0.17944790422916412
# Epoch 265/1600 Done, Total Loss: 0.17945367097854614
# Epoch 266/1600 Done, Total Loss: 0.17862196266651154
# Epoch 267/1600 Done, Total Loss: 0.17818988114595413
# Epoch 268/1600 Done, Total Loss: 0.17770252376794815
# Epoch 269/1600 Done, Total Loss: 0.17716337740421295
# Epoch 270/1600 Done, Total Loss: 0.17691131681203842
# Epoch 271/1600 Done, Total Loss: 0.1763656735420227
# Epoch 272/1600 Done, Total Loss: 0.17581254243850708
# Epoch 273/1600 Done, Total Loss: 0.1753062605857849
# Epoch 274/1600 Done, Total Loss: 0.17522043734788895
# Epoch 275/1600 Done, Total Loss: 0.1748846471309662
# Epoch 276/1600 Done, Total Loss: 0.1739346757531166
# Epoch 277/1600 Done, Total Loss: 0.17361418902873993
# Epoch 278/1600 Done, Total Loss: 0.17337100952863693
# Epoch 279/1600 Done, Total Loss: 0.1725393496453762
# Epoch 280/1600 Done, Total Loss: 0.1721825748682022
# Epoch 281/1600 Done, Total Loss: 0.17176294326782227
# Epoch 282/1600 Done, Total Loss: 0.17128222435712814
# Epoch 283/1600 Done, Total Loss: 0.17075404524803162
# Epoch 284/1600 Done, Total Loss: 0.17016195878386497
# Epoch 285/1600 Done, Total Loss: 0.1698962114751339
# Epoch 286/1600 Done, Total Loss: 0.16925212740898132
# Epoch 287/1600 Done, Total Loss: 0.1688486449420452
# Epoch 288/1600 Done, Total Loss: 0.16836588829755783
# Epoch 289/1600 Done, Total Loss: 0.16808028519153595
# Epoch 290/1600 Done, Total Loss: 0.1675744727253914
# Epoch 291/1600 Done, Total Loss: 0.1670193038880825
# Epoch 292/1600 Done, Total Loss: 0.16688929870724678
# Epoch 293/1600 Done, Total Loss: 0.16634375602006912
# Epoch 294/1600 Done, Total Loss: 0.16555114090442657
# Epoch 295/1600 Done, Total Loss: 0.16512389108538628
# Epoch 296/1600 Done, Total Loss: 0.1647597774863243
# Epoch 297/1600 Done, Total Loss: 0.16410956904292107
# Epoch 298/1600 Done, Total Loss: 0.16355393826961517
# Epoch 299/1600 Done, Total Loss: 0.162995595484972
# Epoch 300/1600 Done, Total Loss: 0.1625397801399231
# Epoch 301/1600 Done, Total Loss: 0.16231705248355865
# Epoch 302/1600 Done, Total Loss: 0.1616629809141159
# Epoch 303/1600 Done, Total Loss: 0.16119059175252914
# Epoch 304/1600 Done, Total Loss: 0.1608305349946022
# Epoch 305/1600 Done, Total Loss: 0.16054078936576843
# Epoch 306/1600 Done, Total Loss: 0.15974310040473938
# Epoch 307/1600 Done, Total Loss: 0.15923556685447693
# Epoch 308/1600 Done, Total Loss: 0.15896745026111603
# Epoch 309/1600 Done, Total Loss: 0.1583276316523552
# Epoch 310/1600 Done, Total Loss: 0.15822862088680267
# Epoch 311/1600 Done, Total Loss: 0.15746882557868958
# Epoch 312/1600 Done, Total Loss: 0.15714162588119507
# Epoch 313/1600 Done, Total Loss: 0.15680419653654099
# Epoch 314/1600 Done, Total Loss: 0.15625519305467606
# Epoch 315/1600 Done, Total Loss: 0.15591677278280258
# Epoch 316/1600 Done, Total Loss: 0.1551702432334423
# Epoch 317/1600 Done, Total Loss: 0.15487483888864517
# Epoch 318/1600 Done, Total Loss: 0.1541934534907341
# Epoch 319/1600 Done, Total Loss: 0.15406129509210587
# Epoch 320/1600 Done, Total Loss: 0.15333248674869537
# Epoch 321/1600 Done, Total Loss: 0.15328331291675568
# Epoch 322/1600 Done, Total Loss: 0.15243951976299286
# Epoch 323/1600 Done, Total Loss: 0.1520158387720585
# Epoch 324/1600 Done, Total Loss: 0.15157821774482727
# Epoch 325/1600 Done, Total Loss: 0.1515955924987793
# Epoch 326/1600 Done, Total Loss: 0.15075930580496788
# Epoch 327/1600 Done, Total Loss: 0.1506662778556347
# Epoch 328/1600 Done, Total Loss: 0.15040448307991028
# Epoch 329/1600 Done, Total Loss: 0.14980923384428024
# Epoch 330/1600 Done, Total Loss: 0.1494438573718071
# Epoch 331/1600 Done, Total Loss: 0.1489398404955864
# Epoch 332/1600 Done, Total Loss: 0.1488739624619484
# Epoch 333/1600 Done, Total Loss: 0.14831309020519257
# Epoch 334/1600 Done, Total Loss: 0.1480371206998825
# Epoch 335/1600 Done, Total Loss: 0.14750771969556808
# Epoch 336/1600 Done, Total Loss: 0.14713828638195992
# Epoch 337/1600 Done, Total Loss: 0.14669853076338768
# Epoch 338/1600 Done, Total Loss: 0.14637485891580582
# Epoch 339/1600 Done, Total Loss: 0.14587540179491043
# Epoch 340/1600 Done, Total Loss: 0.14568261802196503
# Epoch 341/1600 Done, Total Loss: 0.14537431299686432
# Epoch 342/1600 Done, Total Loss: 0.14478008821606636
# Epoch 343/1600 Done, Total Loss: 0.14442824572324753
# Epoch 344/1600 Done, Total Loss: 0.14425232261419296
# Epoch 345/1600 Done, Total Loss: 0.14380232244729996
# Epoch 346/1600 Done, Total Loss: 0.14330045133829117
# Epoch 347/1600 Done, Total Loss: 0.14292316138744354
# Epoch 348/1600 Done, Total Loss: 0.1431193519383669
# Epoch 349/1600 Done, Total Loss: 0.14217199757695198
# Epoch 350/1600 Done, Total Loss: 0.14192891120910645
# Epoch 351/1600 Done, Total Loss: 0.14170607179403305
# Epoch 352/1600 Done, Total Loss: 0.14118250645697117
# Epoch 353/1600 Done, Total Loss: 0.1410423405468464
# Epoch 354/1600 Done, Total Loss: 0.14035334438085556
# Epoch 355/1600 Done, Total Loss: 0.14040590822696686
# Epoch 356/1600 Done, Total Loss: 0.13969051837921143
# Epoch 357/1600 Done, Total Loss: 0.13935989886522293
# Epoch 358/1600 Done, Total Loss: 0.13925021141767502
# Epoch 359/1600 Done, Total Loss: 0.13842428103089333
# Epoch 360/1600 Done, Total Loss: 0.1384366899728775
# Epoch 361/1600 Done, Total Loss: 0.1378797236829996
# Epoch 362/1600 Done, Total Loss: 0.13793611526489258
# Epoch 363/1600 Done, Total Loss: 0.137434683740139
# Epoch 364/1600 Done, Total Loss: 0.13700717687606812
# Epoch 365/1600 Done, Total Loss: 0.13649839349091053
# Epoch 366/1600 Done, Total Loss: 0.13631554692983627
# Epoch 367/1600 Done, Total Loss: 0.13569162413477898
# Epoch 368/1600 Done, Total Loss: 0.13566603511571884
# Epoch 369/1600 Done, Total Loss: 0.13522935658693314
# Epoch 370/1600 Done, Total Loss: 0.13480690121650696
# Epoch 371/1600 Done, Total Loss: 0.1344701275229454
# Epoch 372/1600 Done, Total Loss: 0.13441931456327438
# Epoch 373/1600 Done, Total Loss: 0.13400599919259548
# Epoch 374/1600 Done, Total Loss: 0.13347388803958893
# Epoch 375/1600 Done, Total Loss: 0.13293123990297318
# Epoch 376/1600 Done, Total Loss: 0.132558673620224
# Epoch 377/1600 Done, Total Loss: 0.13250058889389038
# Epoch 378/1600 Done, Total Loss: 0.1320434957742691
# Epoch 379/1600 Done, Total Loss: 0.13181975483894348
# Epoch 380/1600 Done, Total Loss: 0.13108110055327415
# Epoch 381/1600 Done, Total Loss: 0.13098186627030373
# Epoch 382/1600 Done, Total Loss: 0.13039379939436913
# Epoch 383/1600 Done, Total Loss: 0.13049005717039108
# Epoch 384/1600 Done, Total Loss: 0.12996074557304382
# Epoch 385/1600 Done, Total Loss: 0.12958340533077717
# Epoch 386/1600 Done, Total Loss: 0.12903180345892906
# Epoch 387/1600 Done, Total Loss: 0.1288192793726921
# Epoch 388/1600 Done, Total Loss: 0.12838836014270782
# Epoch 389/1600 Done, Total Loss: 0.12831944599747658
# Epoch 390/1600 Done, Total Loss: 0.12772176787257195
# Epoch 391/1600 Done, Total Loss: 0.12735163792967796
# Epoch 392/1600 Done, Total Loss: 0.12733913026750088
# Epoch 393/1600 Done, Total Loss: 0.12663555890321732
# Epoch 394/1600 Done, Total Loss: 0.126589335501194
# Epoch 395/1600 Done, Total Loss: 0.1263401135802269
# Epoch 396/1600 Done, Total Loss: 0.1260145604610443
# Epoch 397/1600 Done, Total Loss: 0.1256796084344387
# Epoch 398/1600 Done, Total Loss: 0.12502861395478249
# Epoch 399/1600 Done, Total Loss: 0.12469710782170296
# Epoch 400/1600 Done, Total Loss: 0.12479043379426003
# Epoch 401/1600 Done, Total Loss: 0.12426783889532089
# Epoch 402/1600 Done, Total Loss: 0.12366918474435806
# Epoch 403/1600 Done, Total Loss: 0.12360396236181259
# Epoch 404/1600 Done, Total Loss: 0.12337446957826614
# Epoch 405/1600 Done, Total Loss: 0.122638288885355
# Epoch 406/1600 Done, Total Loss: 0.12252578884363174
# Epoch 407/1600 Done, Total Loss: 0.1220915149897337
# Epoch 408/1600 Done, Total Loss: 0.12177054956555367
# Epoch 409/1600 Done, Total Loss: 0.1213318221271038
# Epoch 410/1600 Done, Total Loss: 0.1215474046766758
# Epoch 411/1600 Done, Total Loss: 0.12067071348428726
# Epoch 412/1600 Done, Total Loss: 0.12047461420297623
# Epoch 413/1600 Done, Total Loss: 0.12003162875771523
# Epoch 414/1600 Done, Total Loss: 0.11991709657013416
# Epoch 415/1600 Done, Total Loss: 0.11952561140060425
# Epoch 416/1600 Done, Total Loss: 0.1191302239894867
# Epoch 417/1600 Done, Total Loss: 0.1192326508462429
# Epoch 418/1600 Done, Total Loss: 0.11871439963579178
# Epoch 419/1600 Done, Total Loss: 0.11835113167762756
# Epoch 420/1600 Done, Total Loss: 0.11828971654176712
# Epoch 421/1600 Done, Total Loss: 0.1179007925093174
# Epoch 422/1600 Done, Total Loss: 0.11730452068150043
# Epoch 423/1600 Done, Total Loss: 0.11693334951996803
# Epoch 424/1600 Done, Total Loss: 0.11677088961005211
# Epoch 425/1600 Done, Total Loss: 0.11663604900240898
# Epoch 426/1600 Done, Total Loss: 0.11606671661138535
# Epoch 427/1600 Done, Total Loss: 0.11604736372828484
# Epoch 428/1600 Done, Total Loss: 0.11592128872871399
# Epoch 429/1600 Done, Total Loss: 0.11522569507360458
# Epoch 430/1600 Done, Total Loss: 0.11535098403692245
# Epoch 431/1600 Done, Total Loss: 0.11499036476016045
# Epoch 432/1600 Done, Total Loss: 0.1146850660443306
# Epoch 433/1600 Done, Total Loss: 0.1142033189535141
# Epoch 434/1600 Done, Total Loss: 0.11370047181844711
# Epoch 435/1600 Done, Total Loss: 0.11388175934553146
# Epoch 436/1600 Done, Total Loss: 0.11313426867127419
# Epoch 437/1600 Done, Total Loss: 0.11327291280031204
# Epoch 438/1600 Done, Total Loss: 0.11274012923240662
# Epoch 439/1600 Done, Total Loss: 0.11226103827357292
# Epoch 440/1600 Done, Total Loss: 0.11226564645767212
# Epoch 441/1600 Done, Total Loss: 0.11186030879616737
# Epoch 442/1600 Done, Total Loss: 0.11169896647334099
# Epoch 443/1600 Done, Total Loss: 0.11132165417075157
# Epoch 444/1600 Done, Total Loss: 0.11106651276350021
# Epoch 445/1600 Done, Total Loss: 0.11089924350380898
# Epoch 446/1600 Done, Total Loss: 0.11050868779420853
# Epoch 447/1600 Done, Total Loss: 0.11033299937844276
# Epoch 448/1600 Done, Total Loss: 0.10966665297746658
# Epoch 449/1600 Done, Total Loss: 0.10966441407799721
# Epoch 450/1600 Done, Total Loss: 0.10928203910589218
# Epoch 451/1600 Done, Total Loss: 0.10896402969956398
# Epoch 452/1600 Done, Total Loss: 0.10859030671417713
# Epoch 453/1600 Done, Total Loss: 0.10869280993938446
# Epoch 454/1600 Done, Total Loss: 0.10800560191273689
# Epoch 455/1600 Done, Total Loss: 0.10799447447061539
# Epoch 456/1600 Done, Total Loss: 0.10771281458437443
# Epoch 457/1600 Done, Total Loss: 0.10737732797861099
# Epoch 458/1600 Done, Total Loss: 0.106828223913908
# Epoch 459/1600 Done, Total Loss: 0.10676083713769913
# Epoch 460/1600 Done, Total Loss: 0.10634882748126984
# Epoch 461/1600 Done, Total Loss: 0.10628276690840721
# Epoch 462/1600 Done, Total Loss: 0.10629407688975334
# Epoch 463/1600 Done, Total Loss: 0.10580339282751083
# Epoch 464/1600 Done, Total Loss: 0.10551303997635841
# Epoch 465/1600 Done, Total Loss: 0.10506807640194893
# Epoch 466/1600 Done, Total Loss: 0.10482607409358025
# Epoch 467/1600 Done, Total Loss: 0.10452772676944733
# Epoch 468/1600 Done, Total Loss: 0.10413873940706253
# Epoch 469/1600 Done, Total Loss: 0.10402391478419304
# Epoch 470/1600 Done, Total Loss: 0.10384910926222801
# Epoch 471/1600 Done, Total Loss: 0.10336833447217941
# Epoch 472/1600 Done, Total Loss: 0.10350174456834793
# Epoch 473/1600 Done, Total Loss: 0.10285350680351257
# Epoch 474/1600 Done, Total Loss: 0.10247459448873997
# Epoch 475/1600 Done, Total Loss: 0.10240176133811474
# Epoch 476/1600 Done, Total Loss: 0.10220243036746979
# Epoch 477/1600 Done, Total Loss: 0.1020183190703392
# Epoch 478/1600 Done, Total Loss: 0.10147818550467491
# Epoch 479/1600 Done, Total Loss: 0.10142109170556068
# Epoch 480/1600 Done, Total Loss: 0.1008566077798605
# Epoch 481/1600 Done, Total Loss: 0.10080274008214474
# Epoch 482/1600 Done, Total Loss: 0.1004277877509594
# Epoch 483/1600 Done, Total Loss: 0.10023338347673416
# Epoch 484/1600 Done, Total Loss: 0.10014140047132969
# Epoch 485/1600 Done, Total Loss: 0.09978417307138443
# Epoch 486/1600 Done, Total Loss: 0.09944158792495728
# Epoch 487/1600 Done, Total Loss: 0.09905730187892914
# Epoch 488/1600 Done, Total Loss: 0.09875362366437912
# Epoch 489/1600 Done, Total Loss: 0.09881549514830112
# Epoch 490/1600 Done, Total Loss: 0.09831175580620766
# Epoch 491/1600 Done, Total Loss: 0.09796936064958572
# Epoch 492/1600 Done, Total Loss: 0.09798821806907654
# Epoch 493/1600 Done, Total Loss: 0.09813936427235603
# Epoch 494/1600 Done, Total Loss: 0.09760367125272751
# Epoch 495/1600 Done, Total Loss: 0.09706489741802216
# Epoch 496/1600 Done, Total Loss: 0.09691105224192142
# Epoch 497/1600 Done, Total Loss: 0.09675578027963638
# Epoch 498/1600 Done, Total Loss: 0.09624107368290424
# Epoch 499/1600 Done, Total Loss: 0.09595741704106331
# Epoch 500/1600 Done, Total Loss: 0.0958196185529232
# net_outputs_test[0] [-1.7113396 -1.548122  -1.3926666 ... -1.1442459 -1.0944248 -1.0724053]
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1024])) that is different to the input size (torch.Size([1024, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 501/1600 Done, Total Loss: 0.09541743248701096
# Epoch 502/1600 Done, Total Loss: 0.09545358642935753
# Epoch 503/1600 Done, Total Loss: 0.09523370675742626
# Epoch 504/1600 Done, Total Loss: 0.0948684774339199
# Epoch 505/1600 Done, Total Loss: 0.09445247426629066
# Epoch 506/1600 Done, Total Loss: 0.09419369883835316
# Epoch 507/1600 Done, Total Loss: 0.09397837147116661
# Epoch 508/1600 Done, Total Loss: 0.09394321218132973
# Epoch 509/1600 Done, Total Loss: 0.093598872423172
# Epoch 510/1600 Done, Total Loss: 0.09342644922435284
# Epoch 511/1600 Done, Total Loss: 0.09318174421787262
# Epoch 512/1600 Done, Total Loss: 0.09275005012750626
# Epoch 513/1600 Done, Total Loss: 0.09277951344847679
# Epoch 514/1600 Done, Total Loss: 0.09234070405364037
# Epoch 515/1600 Done, Total Loss: 0.09195657074451447
# Epoch 516/1600 Done, Total Loss: 0.09173177555203438
# Epoch 517/1600 Done, Total Loss: 0.0913739837706089
# Epoch 518/1600 Done, Total Loss: 0.09106160141527653
# Epoch 519/1600 Done, Total Loss: 0.09081951715052128
# Epoch 520/1600 Done, Total Loss: 0.09097374975681305
# Epoch 521/1600 Done, Total Loss: 0.09064786694943905
# Epoch 522/1600 Done, Total Loss: 0.09015510603785515
# Epoch 523/1600 Done, Total Loss: 0.08991790935397148
# Epoch 524/1600 Done, Total Loss: 0.08983688428997993
# Epoch 525/1600 Done, Total Loss: 0.08947710692882538
# Epoch 526/1600 Done, Total Loss: 0.0892118327319622
# Epoch 527/1600 Done, Total Loss: 0.08888474851846695
# Epoch 528/1600 Done, Total Loss: 0.08889657817780972
# Epoch 529/1600 Done, Total Loss: 0.08867383375763893
# Epoch 530/1600 Done, Total Loss: 0.08846990019083023
# Epoch 531/1600 Done, Total Loss: 0.08803592622280121
# Epoch 532/1600 Done, Total Loss: 0.08760972693562508
# Epoch 533/1600 Done, Total Loss: 0.08740412257611752
# Epoch 534/1600 Done, Total Loss: 0.08742646314203739
# Epoch 535/1600 Done, Total Loss: 0.08732368238270283
# Epoch 536/1600 Done, Total Loss: 0.08692529425024986
# Epoch 537/1600 Done, Total Loss: 0.08649331331253052
# Epoch 538/1600 Done, Total Loss: 0.08633242920041084
# Epoch 539/1600 Done, Total Loss: 0.08591854758560658
# Epoch 540/1600 Done, Total Loss: 0.08587463200092316
# Epoch 541/1600 Done, Total Loss: 0.08556725643575191
# Epoch 542/1600 Done, Total Loss: 0.08522821217775345
# Epoch 543/1600 Done, Total Loss: 0.08500848338007927
# Epoch 544/1600 Done, Total Loss: 0.08511042222380638
# Epoch 545/1600 Done, Total Loss: 0.084694754332304
# Epoch 546/1600 Done, Total Loss: 0.08459164947271347
# Epoch 547/1600 Done, Total Loss: 0.08418693207204342
# Epoch 548/1600 Done, Total Loss: 0.08396194875240326
# Epoch 549/1600 Done, Total Loss: 0.08400436490774155
# Epoch 550/1600 Done, Total Loss: 0.0836663506925106
# Epoch 551/1600 Done, Total Loss: 0.08307839184999466
# Epoch 552/1600 Done, Total Loss: 0.08302769064903259
# Epoch 553/1600 Done, Total Loss: 0.0830148458480835
# Epoch 554/1600 Done, Total Loss: 0.08279380947351456
# Epoch 555/1600 Done, Total Loss: 0.08219918608665466
# Epoch 556/1600 Done, Total Loss: 0.0820368267595768
# Epoch 557/1600 Done, Total Loss: 0.08175931870937347
# Epoch 558/1600 Done, Total Loss: 0.08143365196883678
# Epoch 559/1600 Done, Total Loss: 0.08119497448205948
# Epoch 560/1600 Done, Total Loss: 0.08120162412524223
# Epoch 561/1600 Done, Total Loss: 0.08113306388258934
# Epoch 562/1600 Done, Total Loss: 0.08063947968184948
# Epoch 563/1600 Done, Total Loss: 0.08075986057519913
# Epoch 564/1600 Done, Total Loss: 0.08050232380628586
# Epoch 565/1600 Done, Total Loss: 0.08013200759887695
# Epoch 566/1600 Done, Total Loss: 0.07967875339090824
# Epoch 567/1600 Done, Total Loss: 0.07973072864115238
# Epoch 568/1600 Done, Total Loss: 0.07961070351302624
# Epoch 569/1600 Done, Total Loss: 0.0791160836815834
# Epoch 570/1600 Done, Total Loss: 0.07935376465320587
# Epoch 571/1600 Done, Total Loss: 0.07870529219508171
# Epoch 572/1600 Done, Total Loss: 0.07863454706966877
# Epoch 573/1600 Done, Total Loss: 0.0782364271581173
# Epoch 574/1600 Done, Total Loss: 0.0782897137105465
# Epoch 575/1600 Done, Total Loss: 0.07765515521168709
# Epoch 576/1600 Done, Total Loss: 0.0778336450457573
# Epoch 577/1600 Done, Total Loss: 0.07717211171984673
# Epoch 578/1600 Done, Total Loss: 0.07742326334118843
# Epoch 579/1600 Done, Total Loss: 0.07691962644457817
# Epoch 580/1600 Done, Total Loss: 0.07700809836387634
# Epoch 581/1600 Done, Total Loss: 0.07672712579369545
# Epoch 582/1600 Done, Total Loss: 0.07610270194709301
# Epoch 583/1600 Done, Total Loss: 0.07583670318126678
# Epoch 584/1600 Done, Total Loss: 0.07566766440868378
# Epoch 585/1600 Done, Total Loss: 0.07539389841258526
# Epoch 586/1600 Done, Total Loss: 0.07550907135009766
# Epoch 587/1600 Done, Total Loss: 0.07505412213504314
# Epoch 588/1600 Done, Total Loss: 0.07509737089276314
# Epoch 589/1600 Done, Total Loss: 0.07468710839748383
# Epoch 590/1600 Done, Total Loss: 0.07442831061780453
# Epoch 591/1600 Done, Total Loss: 0.07445043697953224
# Epoch 592/1600 Done, Total Loss: 0.07401130348443985
# Epoch 593/1600 Done, Total Loss: 0.07403755187988281
# Epoch 594/1600 Done, Total Loss: 0.07354567386209965
# Epoch 595/1600 Done, Total Loss: 0.0732989776879549
# Epoch 596/1600 Done, Total Loss: 0.07322902046144009
# Epoch 597/1600 Done, Total Loss: 0.07307864353060722
# Epoch 598/1600 Done, Total Loss: 0.07293099164962769
# Epoch 599/1600 Done, Total Loss: 0.07264945097267628
# Epoch 600/1600 Done, Total Loss: 0.07234041951596737
# Epoch 601/1600 Done, Total Loss: 0.07244733721017838
# Epoch 602/1600 Done, Total Loss: 0.07213498279452324
# Epoch 603/1600 Done, Total Loss: 0.07186398468911648
# Epoch 604/1600 Done, Total Loss: 0.07157561928033829
# Epoch 605/1600 Done, Total Loss: 0.07139727100729942
# Epoch 606/1600 Done, Total Loss: 0.07151279971003532
# Epoch 607/1600 Done, Total Loss: 0.07095901109278202
# Epoch 608/1600 Done, Total Loss: 0.0705618318170309
# Epoch 609/1600 Done, Total Loss: 0.07069869711995125
# Epoch 610/1600 Done, Total Loss: 0.07048806548118591
# Epoch 611/1600 Done, Total Loss: 0.07016608864068985
# Epoch 612/1600 Done, Total Loss: 0.06976169720292091
# Epoch 613/1600 Done, Total Loss: 0.06944543495774269
# Epoch 614/1600 Done, Total Loss: 0.0695149227976799
# Epoch 615/1600 Done, Total Loss: 0.06900369934737682
# Epoch 616/1600 Done, Total Loss: 0.06889060512185097
# Epoch 617/1600 Done, Total Loss: 0.068516306579113
# Epoch 618/1600 Done, Total Loss: 0.0684107095003128
# Epoch 619/1600 Done, Total Loss: 0.0680350698530674
# Epoch 620/1600 Done, Total Loss: 0.06843378767371178
# Epoch 621/1600 Done, Total Loss: 0.06761384010314941
# Epoch 622/1600 Done, Total Loss: 0.0677586980164051
# Epoch 623/1600 Done, Total Loss: 0.0671960599720478
# Epoch 624/1600 Done, Total Loss: 0.06681212410330772
# Epoch 625/1600 Done, Total Loss: 0.0666586235165596
# Epoch 626/1600 Done, Total Loss: 0.06638883426785469
# Epoch 627/1600 Done, Total Loss: 0.0665062926709652
# Epoch 628/1600 Done, Total Loss: 0.06631768122315407
# Epoch 629/1600 Done, Total Loss: 0.06570075266063213
# Epoch 630/1600 Done, Total Loss: 0.06546304002404213
# Epoch 631/1600 Done, Total Loss: 0.06564260646700859
# Epoch 632/1600 Done, Total Loss: 0.06502131372690201
# Epoch 633/1600 Done, Total Loss: 0.06506010517477989
# Epoch 634/1600 Done, Total Loss: 0.06479333713650703
# Epoch 635/1600 Done, Total Loss: 0.06444878317415714
# Epoch 636/1600 Done, Total Loss: 0.0641067735850811
# Epoch 637/1600 Done, Total Loss: 0.06382352206856012
# Epoch 638/1600 Done, Total Loss: 0.06381639093160629
# Epoch 639/1600 Done, Total Loss: 0.06341616809368134
# Epoch 640/1600 Done, Total Loss: 0.06336494069546461
# Epoch 641/1600 Done, Total Loss: 0.06306293047964573
# Epoch 642/1600 Done, Total Loss: 0.06278298795223236
# Epoch 643/1600 Done, Total Loss: 0.06253275088965893
# Epoch 644/1600 Done, Total Loss: 0.062403447926044464
# Epoch 645/1600 Done, Total Loss: 0.06210651807487011
# Epoch 646/1600 Done, Total Loss: 0.061915548518300056
# Epoch 647/1600 Done, Total Loss: 0.06178046390414238
# Epoch 648/1600 Done, Total Loss: 0.06156943365931511
# Epoch 649/1600 Done, Total Loss: 0.06156265735626221
# Epoch 650/1600 Done, Total Loss: 0.06100551784038544
# Epoch 651/1600 Done, Total Loss: 0.06079774349927902
# Epoch 652/1600 Done, Total Loss: 0.06058894470334053
# Epoch 653/1600 Done, Total Loss: 0.06074080243706703
# Epoch 654/1600 Done, Total Loss: 0.06038340926170349
# Epoch 655/1600 Done, Total Loss: 0.06044433265924454
# Epoch 656/1600 Done, Total Loss: 0.05986668914556503
# Epoch 657/1600 Done, Total Loss: 0.06007458083331585
# Epoch 658/1600 Done, Total Loss: 0.05964506417512894
# Epoch 659/1600 Done, Total Loss: 0.0593736469745636
# Epoch 660/1600 Done, Total Loss: 0.05894537828862667
# Epoch 661/1600 Done, Total Loss: 0.05895191989839077
# Epoch 662/1600 Done, Total Loss: 0.059135839343070984
# Epoch 663/1600 Done, Total Loss: 0.05877465754747391
# Epoch 664/1600 Done, Total Loss: 0.05825085751712322
# Epoch 665/1600 Done, Total Loss: 0.0584570225328207
# Epoch 666/1600 Done, Total Loss: 0.05801761895418167
# Epoch 667/1600 Done, Total Loss: 0.05783984623849392
# Epoch 668/1600 Done, Total Loss: 0.05775521695613861
# Epoch 669/1600 Done, Total Loss: 0.05757148191332817
# Epoch 670/1600 Done, Total Loss: 0.05698418989777565
# Epoch 671/1600 Done, Total Loss: 0.05699547566473484
# Epoch 672/1600 Done, Total Loss: 0.05660984572023153
# Epoch 673/1600 Done, Total Loss: 0.056414936669170856
# Epoch 674/1600 Done, Total Loss: 0.056599557399749756
# Epoch 675/1600 Done, Total Loss: 0.05619764141738415
# Epoch 676/1600 Done, Total Loss: 0.0558284055441618
# Epoch 677/1600 Done, Total Loss: 0.055977800861001015
# Epoch 678/1600 Done, Total Loss: 0.05542071349918842
# Epoch 679/1600 Done, Total Loss: 0.05548534356057644
# Epoch 680/1600 Done, Total Loss: 0.055043596774339676
# Epoch 681/1600 Done, Total Loss: 0.05517136491835117
# Epoch 682/1600 Done, Total Loss: 0.05467161908745766
# Epoch 683/1600 Done, Total Loss: 0.05482068285346031
# Epoch 684/1600 Done, Total Loss: 0.05436511151492596
# Epoch 685/1600 Done, Total Loss: 0.05417180061340332
# Epoch 686/1600 Done, Total Loss: 0.054006013087928295
# Epoch 687/1600 Done, Total Loss: 0.05417030490934849
# Epoch 688/1600 Done, Total Loss: 0.0537775969132781
# Epoch 689/1600 Done, Total Loss: 0.053866930305957794
# Epoch 690/1600 Done, Total Loss: 0.05328857898712158
# Epoch 691/1600 Done, Total Loss: 0.05312528647482395
# Epoch 692/1600 Done, Total Loss: 0.053008049726486206
# Epoch 693/1600 Done, Total Loss: 0.05313621461391449
# Epoch 694/1600 Done, Total Loss: 0.0529471505433321
# Epoch 695/1600 Done, Total Loss: 0.05293506383895874
# Epoch 696/1600 Done, Total Loss: 0.05255129747092724
# Epoch 697/1600 Done, Total Loss: 0.052316660061478615
# Epoch 698/1600 Done, Total Loss: 0.05225657299160957
# Epoch 699/1600 Done, Total Loss: 0.051802776753902435
# Epoch 700/1600 Done, Total Loss: 0.051639700308442116
# Epoch 701/1600 Done, Total Loss: 0.05192880891263485
# Epoch 702/1600 Done, Total Loss: 0.05161461606621742
# Epoch 703/1600 Done, Total Loss: 0.05135738477110863
# Epoch 704/1600 Done, Total Loss: 0.05105628818273544
# Epoch 705/1600 Done, Total Loss: 0.05079617165029049
# Epoch 706/1600 Done, Total Loss: 0.050887925550341606
# Epoch 707/1600 Done, Total Loss: 0.05089365504682064
# Epoch 708/1600 Done, Total Loss: 0.05066826939582825
# Epoch 709/1600 Done, Total Loss: 0.05060193128883839
# Epoch 710/1600 Done, Total Loss: 0.05000717751681805
# Epoch 711/1600 Done, Total Loss: 0.04998333007097244
# Epoch 712/1600 Done, Total Loss: 0.0501134991645813
# Epoch 713/1600 Done, Total Loss: 0.04961785860359669
# Epoch 714/1600 Done, Total Loss: 0.04937240108847618
# Epoch 715/1600 Done, Total Loss: 0.04929031990468502
# Epoch 716/1600 Done, Total Loss: 0.04956299252808094
# Epoch 717/1600 Done, Total Loss: 0.04907023347914219
# Epoch 718/1600 Done, Total Loss: 0.04915517009794712
# Epoch 719/1600 Done, Total Loss: 0.04877989552915096
# Epoch 720/1600 Done, Total Loss: 0.04893373139202595
# Epoch 721/1600 Done, Total Loss: 0.04864422604441643
# Epoch 722/1600 Done, Total Loss: 0.04826764762401581
# Epoch 723/1600 Done, Total Loss: 0.04804741870611906
# Epoch 724/1600 Done, Total Loss: 0.048290375620126724
# Epoch 725/1600 Done, Total Loss: 0.047778159379959106
# Epoch 726/1600 Done, Total Loss: 0.04799148254096508
# Epoch 727/1600 Done, Total Loss: 0.04757982864975929
# Epoch 728/1600 Done, Total Loss: 0.04738069884479046
# Epoch 729/1600 Done, Total Loss: 0.04722404293715954
# Epoch 730/1600 Done, Total Loss: 0.04731965996325016
# Epoch 731/1600 Done, Total Loss: 0.04687653109431267
# Epoch 732/1600 Done, Total Loss: 0.04677263833582401
# Epoch 733/1600 Done, Total Loss: 0.04663745127618313
# Epoch 734/1600 Done, Total Loss: 0.04687483794987202
# Epoch 735/1600 Done, Total Loss: 0.04633769765496254
# Epoch 736/1600 Done, Total Loss: 0.04629777371883392
# Epoch 737/1600 Done, Total Loss: 0.04616953246295452
# Epoch 738/1600 Done, Total Loss: 0.045944313518702984
# Epoch 739/1600 Done, Total Loss: 0.04609859921038151
# Epoch 740/1600 Done, Total Loss: 0.04616115801036358
# Epoch 741/1600 Done, Total Loss: 0.04554568976163864
# Epoch 742/1600 Done, Total Loss: 0.04543451685458422
# Epoch 743/1600 Done, Total Loss: 0.0452499408274889
# Epoch 744/1600 Done, Total Loss: 0.04514448530972004
# Epoch 745/1600 Done, Total Loss: 0.04536814242601395
# Epoch 746/1600 Done, Total Loss: 0.04533366858959198
# Epoch 747/1600 Done, Total Loss: 0.04505320079624653
# Epoch 748/1600 Done, Total Loss: 0.04492918774485588
# Epoch 749/1600 Done, Total Loss: 0.0447065643966198
# Epoch 750/1600 Done, Total Loss: 0.044467709958553314
# Epoch 751/1600 Done, Total Loss: 0.04450894705951214
# Epoch 752/1600 Done, Total Loss: 0.044623732566833496
# Epoch 753/1600 Done, Total Loss: 0.044417133554816246
# Epoch 754/1600 Done, Total Loss: 0.04397735744714737
# Epoch 755/1600 Done, Total Loss: 0.04403471574187279
# Epoch 756/1600 Done, Total Loss: 0.04415277112275362
# Epoch 757/1600 Done, Total Loss: 0.04367911070585251
# Epoch 758/1600 Done, Total Loss: 0.043417894281446934
# Epoch 759/1600 Done, Total Loss: 0.04327985271811485
# Epoch 760/1600 Done, Total Loss: 0.04312004894018173
# Epoch 761/1600 Done, Total Loss: 0.04348905384540558
# Epoch 762/1600 Done, Total Loss: 0.04331822134554386
# Epoch 763/1600 Done, Total Loss: 0.0429309094324708
# Epoch 764/1600 Done, Total Loss: 0.042964388616383076
# Epoch 765/1600 Done, Total Loss: 0.042677389457821846
# Epoch 766/1600 Done, Total Loss: 0.04290609247982502
# Epoch 767/1600 Done, Total Loss: 0.042690813541412354
# Epoch 768/1600 Done, Total Loss: 0.042520507238805294
# Epoch 769/1600 Done, Total Loss: 0.04208613559603691
# Epoch 770/1600 Done, Total Loss: 0.04221220314502716
# Epoch 771/1600 Done, Total Loss: 0.0419020289555192
# Epoch 772/1600 Done, Total Loss: 0.04206142574548721
# Epoch 773/1600 Done, Total Loss: 0.041752785444259644
# Epoch 774/1600 Done, Total Loss: 0.04151412099599838
# Epoch 775/1600 Done, Total Loss: 0.04195831157267094
# Epoch 776/1600 Done, Total Loss: 0.04131179861724377
# Epoch 777/1600 Done, Total Loss: 0.041175403632223606
# Epoch 778/1600 Done, Total Loss: 0.04110305197536945
# Epoch 779/1600 Done, Total Loss: 0.041317266412079334
# Epoch 780/1600 Done, Total Loss: 0.04127570055425167
# Epoch 781/1600 Done, Total Loss: 0.04079070966690779
# Epoch 782/1600 Done, Total Loss: 0.04063701443374157
# Epoch 783/1600 Done, Total Loss: 0.0405575055629015
# Epoch 784/1600 Done, Total Loss: 0.04041890986263752
# Epoch 785/1600 Done, Total Loss: 0.04036696720868349
# Epoch 786/1600 Done, Total Loss: 0.040543084032833576
# Epoch 787/1600 Done, Total Loss: 0.040163978934288025
# Epoch 788/1600 Done, Total Loss: 0.04033482261002064
# Epoch 789/1600 Done, Total Loss: 0.040242183953523636
# Epoch 790/1600 Done, Total Loss: 0.040146367624402046
# Epoch 791/1600 Done, Total Loss: 0.03989952243864536
# Epoch 792/1600 Done, Total Loss: 0.03992972895503044
# Epoch 793/1600 Done, Total Loss: 0.039700962603092194
# Epoch 794/1600 Done, Total Loss: 0.039694976061582565
# Epoch 795/1600 Done, Total Loss: 0.039544740691781044
# Epoch 796/1600 Done, Total Loss: 0.03966267965734005
# Epoch 797/1600 Done, Total Loss: 0.03922711871564388
# Epoch 798/1600 Done, Total Loss: 0.03913295827805996
# Epoch 799/1600 Done, Total Loss: 0.039383682422339916
# Epoch 800/1600 Done, Total Loss: 0.03921566344797611
# Epoch 801/1600 Done, Total Loss: 0.03894863557070494
# Epoch 802/1600 Done, Total Loss: 0.0392684880644083
# Epoch 803/1600 Done, Total Loss: 0.03881319984793663
# Epoch 804/1600 Done, Total Loss: 0.03858272358775139
# Epoch 805/1600 Done, Total Loss: 0.03883095644414425
# Epoch 806/1600 Done, Total Loss: 0.03888627700507641
# Epoch 807/1600 Done, Total Loss: 0.03842892870306969
# Epoch 808/1600 Done, Total Loss: 0.03870424069464207
# Epoch 809/1600 Done, Total Loss: 0.03857054002583027
# Epoch 810/1600 Done, Total Loss: 0.03857945278286934
# Epoch 811/1600 Done, Total Loss: 0.038011085242033005
# Epoch 812/1600 Done, Total Loss: 0.03810944128781557
# Epoch 813/1600 Done, Total Loss: 0.03782185260206461
# Epoch 814/1600 Done, Total Loss: 0.037700421176850796
# Epoch 815/1600 Done, Total Loss: 0.03778400458395481
# Epoch 816/1600 Done, Total Loss: 0.03751839976757765
# Epoch 817/1600 Done, Total Loss: 0.037484778091311455
# Epoch 818/1600 Done, Total Loss: 0.03748363256454468
# Epoch 819/1600 Done, Total Loss: 0.037393998354673386
# Epoch 820/1600 Done, Total Loss: 0.03756566159427166
# Epoch 821/1600 Done, Total Loss: 0.03718542447313666
# Epoch 822/1600 Done, Total Loss: 0.03704975172877312
# Epoch 823/1600 Done, Total Loss: 0.037254005670547485
# Epoch 824/1600 Done, Total Loss: 0.03688378259539604
# Epoch 825/1600 Done, Total Loss: 0.037191702984273434
# Epoch 826/1600 Done, Total Loss: 0.037367502227425575
# Epoch 827/1600 Done, Total Loss: 0.03721207845956087
# Epoch 828/1600 Done, Total Loss: 0.036704737693071365
# Epoch 829/1600 Done, Total Loss: 0.03679471369832754
# Epoch 830/1600 Done, Total Loss: 0.03640620596706867
# Epoch 831/1600 Done, Total Loss: 0.03655219450592995
# Epoch 832/1600 Done, Total Loss: 0.03626581281423569
# Epoch 833/1600 Done, Total Loss: 0.03657720237970352
# Epoch 834/1600 Done, Total Loss: 0.03633057698607445
# Epoch 835/1600 Done, Total Loss: 0.036004453897476196
# Epoch 836/1600 Done, Total Loss: 0.03626582212746143
# Epoch 837/1600 Done, Total Loss: 0.03622044529765844
# Epoch 838/1600 Done, Total Loss: 0.03582493029534817
# Epoch 839/1600 Done, Total Loss: 0.03622434847056866
# Epoch 1575/1600 Done, Total Loss: 0.018492495641112328
# Epoch 1576/1600 Done, Total Loss: 0.018621953669935465
# Epoch 1577/1600 Done, Total Loss: 0.018670210614800453
# Epoch 1578/1600 Done, Total Loss: 0.018678746186196804
# Epoch 1579/1600 Done, Total Loss: 0.01853950647637248
# Epoch 1580/1600 Done, Total Loss: 0.018444875488057733
# Epoch 1581/1600 Done, Total Loss: 0.01891323085874319
# Epoch 1582/1600 Done, Total Loss: 0.01870374847203493
# Epoch 1583/1600 Done, Total Loss: 0.01871847454458475
# Epoch 1584/1600 Done, Total Loss: 0.018360267742536962
# Epoch 1585/1600 Done, Total Loss: 0.018387816846370697
# Epoch 1586/1600 Done, Total Loss: 0.018775551579892635
# Epoch 1587/1600 Done, Total Loss: 0.018740182742476463
# Epoch 1588/1600 Done, Total Loss: 0.018602903932332993
# Epoch 1589/1600 Done, Total Loss: 0.01863016188144684
# Epoch 1590/1600 Done, Total Loss: 0.01827691402286291
# Epoch 1591/1600 Done, Total Loss: 0.018333954736590385
# Epoch 1592/1600 Done, Total Loss: 0.018458793871104717
# Epoch 1593/1600 Done, Total Loss: 0.01828943332657218
# Epoch 1594/1600 Done, Total Loss: 0.01824645884335041
# Epoch 1595/1600 Done, Total Loss: 0.01845159102231264
# Epoch 1596/1600 Done, Total Loss: 0.01848960667848587
# Epoch 1597/1600 Done, Total Loss: 0.018589026294648647
# Epoch 1598/1600 Done, Total Loss: 0.018606124445796013
# Epoch 1599/1600 Done, Total Loss: 0.01842807698994875
# net_outputs_test[0] [-0.76486826 -0.52983725 -0.29480523 ... -3.6722808  -3.762607
#  -3.8529332 ]
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1024])) that is different to the input size (torch.Size([1024, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/chexuanyou/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# MLNet(
#   (fcnn1): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=1, bias=True)
#   )
# )
# layer1, weights:  Parameter containing:
# tensor([[-0.0704, -0.8745],
#         [-0.9435,  0.4136],
#         [-0.4288,  0.3065],
#         [-0.7360,  0.2659],
#         [-0.8429,  0.3876],
#         [-0.1357, -0.7604],
#         [ 0.8374,  0.2420],
#         [-0.6081, -0.5978],
#         [-0.3595, -0.5954],
#         [ 0.6039, -0.1501],
#         [ 0.6737, -0.1451],
#         [ 0.8001, -0.4355],
#         [ 1.0157, -0.0891],
#         [-0.3228, -0.3360],
#         [ 0.7308, -0.1131],
#         [-0.4458,  0.5867]], requires_grad=True)
# layer1, bias:  Parameter containing:
# tensor([ 0.2132,  0.6339,  0.0872,  0.7582, -1.3500,  0.1860, -0.3474,  0.6489,
#          0.6504, -0.5903,  0.6080,  1.3754,  0.8718, -0.1295, -0.8523,  0.1557],
#        requires_grad=True)
# layer3, weights:  Parameter containing:
# tensor([[-0.4435, -0.1577, -0.2315, -0.2330,  0.6105, -0.5770, -0.4769,  0.2810,
#           0.5812, -0.2800,  0.0896,  0.2237,  0.4088, -0.0396, -0.6906,  0.0037]],
#        requires_grad=True)
# layer3, bias:  Parameter containing:
# tensor([0.1102], requires_grad=True)
